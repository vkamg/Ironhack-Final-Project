# %%
import pandas as pd
import Levenshtein
import itertools
from fuzzywuzzy import process, fuzz
import ast

# %%
recipe_df = pd.read_csv('../data/processed/recipe_df.csv')

recipe_df.head()
# Out:
#                                     recipe_image_url  \
# 0  https://content-recetas.lecturas.com/medio/201...
# 1  https://content-recetas.lecturas.com/medio/201...
# 2  https://content-recetas.lecturas.com/medio/202...
# 3  https://content-recetas.lecturas.com/medio/201...
# 4  https://content-recetas.lecturas.com/medio/201...
#
#                                     recipe_name  \
# 0                              Ensalada niçoise
# 1                         Ensalada del périgord
# 2                        Xató con salsa romesco
# 3  Ensalada de ceviche de langostinos y cebolla
# 4        Ensalada de pollo, remolacha y manzana
#
#                                           recipe_url  \
# 0  https://www.lecturas.com/recetas/ensalada-nico...
# 1  https://www.lecturas.com/recetas/ensalada-peri...
# 2  https://www.lecturas.com/recetas/xato-salsa-ro...
# 3  https://www.lecturas.com/recetas/ensalada-cevi...
# 4  https://www.lecturas.com/recetas/ensalada-poll...
#
#                                     ingredients_list  time_preparation(min)  \
# 0  ['patatas pequeñas rojas', 'huevos', 'judías v...                   60.0
# 1  ['foie micuit', 'beicon gruesas', 'champiñones...                   25.0
# 2  ['bacalao desalado', 'cebolleta', 'escarolas',...                   35.0
# 3  ['langostinos', 'pimienta', 'limas', 'tomates'...                   25.0
# 4  ['pechugas de pollo', 'manzanas ácida', 'col l...                   40.0
#
#    calories(kcal)  gluten_free  egg_free  sucrose_fructose_free  low_sodium  \
# 0           252.0            0         0                      0           0
# 1           386.0            0         0                      0           0
# 2             NaN            0         0                      0           0
# 3           176.0            0         0                      0           0
# 4           203.0            0         0                      0           0
#
#    lactose_free                       tipo_plato main_category   category  \
# 0             0  ['Primeros platos y entrantes']     principal  ensaladas
# 1             0  ['Primeros platos y entrantes']     principal  ensaladas
# 2             0  ['Primeros platos y entrantes']     principal  ensaladas
# 3             0  ['Primeros platos y entrantes']     principal  ensaladas
# 4             0  ['Primeros platos y entrantes']     principal  ensaladas
#
#    num_ingredients
# 0               12
# 1                9
# 2               16
# 3               12
# 4               16

# %%
#recipe_df["ingredient"].value_counts()

# %% [raw]
# Levenshtein.distance("hola", "ola")

# %% [raw]
# x = lambda i: Levenshtein(*i), itertools.product(list1, list2)

# %% [raw]
# x

# %%
hr['exists'] = hr.apply(lambda x: x.gen_email in list(it.email), axis=1)

# %%
input_ing = input('¿Qué tienes hoy en la nevera?')
# Out:
# ¿Qué tienes hoy en la nevera? brecol, jamón cocido, queso, arroz, huevos, aceite, sal, pimienta

# %%
input_ing
# Out:
# 'brecol, jamón cocido, queso, arroz, huevos, aceite, sal, pimienta'

# %%
def input_list(string):
    input_list = []
    str_split = string.split(", ")
    for x in str_split:
        input_list.append(x)
    return input_list

input_ingred = input_list(input_ing)

# %%
def fuzzy_columns(column, input_string):
    ingred_list = ast.literal_eval(column)
    for ingred in ingred_list:
        dif = fuzz.token_set_ratio(column, input_string)
    if dif > 70:
        return True
    else:
        return False

# %%
for ingred in input_ingred:
    recipe_df[ingred] = recipe_df.apply(lambda x: fuzzy_columns(x["ingredients_list"], ingred), axis=1)

# %%
recipe_df.head()
# Out:
#                                     recipe_image_url  \
# 0  https://content-recetas.lecturas.com/medio/201...
# 1  https://content-recetas.lecturas.com/medio/201...
# 2  https://content-recetas.lecturas.com/medio/202...
# 3  https://content-recetas.lecturas.com/medio/201...
# 4  https://content-recetas.lecturas.com/medio/201...
#
#                                     recipe_name  \
# 0                              Ensalada niçoise
# 1                         Ensalada del périgord
# 2                        Xató con salsa romesco
# 3  Ensalada de ceviche de langostinos y cebolla
# 4        Ensalada de pollo, remolacha y manzana
#
#                                           recipe_url  \
# 0  https://www.lecturas.com/recetas/ensalada-nico...
# 1  https://www.lecturas.com/recetas/ensalada-peri...
# 2  https://www.lecturas.com/recetas/xato-salsa-ro...
# 3  https://www.lecturas.com/recetas/ensalada-cevi...
# 4  https://www.lecturas.com/recetas/ensalada-poll...
#
#                                     ingredients_list  time_preparation(min)  \
# 0  ['patatas pequeñas rojas', 'huevos', 'judías v...                   60.0
# 1  ['foie micuit', 'beicon gruesas', 'champiñones...                   25.0
# 2  ['bacalao desalado', 'cebolleta', 'escarolas',...                   35.0
# 3  ['langostinos', 'pimienta', 'limas', 'tomates'...                   25.0
# 4  ['pechugas de pollo', 'manzanas ácida', 'col l...                   40.0
#
#    calories(kcal)  gluten_free  egg_free  sucrose_fructose_free  low_sodium  \
# 0           252.0            0         0                      0           0
# 1           386.0            0         0                      0           0
# 2             NaN            0         0                      0           0
# 3           176.0            0         0                      0           0
# 4           203.0            0         0                      0           0
#
#    ...   category num_ingredients brecol jamón cocido  queso  arroz  huevos  \
# 0  ...  ensaladas              12  False        False  False  False    True
# 1  ...  ensaladas               9  False        False  False  False   False
# 2  ...  ensaladas              16  False        False  False  False   False
# 3  ...  ensaladas              12  False        False  False  False   False
# 4  ...  ensaladas              16  False        False  False  False   False
#
#    aceite    sal  pimienta
# 0    True   True      True
# 1    True  False     False
# 2    True   True     False
# 3   False   True      True
# 4    True   True      True
#
# [5 rows x 23 columns]

# %%
recipe_df["active_ingred"] = recipe_df.select_dtypes(include=['bool']).sum(axis=1)

# %%
def num_missing_ingred(recipe_ingred, active_ingred):
    missing_ingred = recipe_ingred - active_ingred
    return missing_ingred

recipe_df["num_missing_ingred"] = recipe_df.apply(lambda x: num_missing_ingred(x["num_ingredients"], x["active_ingred"]), axis=1)

# %%
recipe_df.head(3)
# Out:
#                                     recipe_image_url             recipe_name  \
# 0  https://content-recetas.lecturas.com/medio/201...        Ensalada niçoise
# 1  https://content-recetas.lecturas.com/medio/201...   Ensalada del périgord
# 2  https://content-recetas.lecturas.com/medio/202...  Xató con salsa romesco
#
#                                           recipe_url  \
# 0  https://www.lecturas.com/recetas/ensalada-nico...
# 1  https://www.lecturas.com/recetas/ensalada-peri...
# 2  https://www.lecturas.com/recetas/xato-salsa-ro...
#
#                                     ingredients_list  time_preparation(min)  \
# 0  ['patatas pequeñas rojas', 'huevos', 'judías v...                   60.0
# 1  ['foie micuit', 'beicon gruesas', 'champiñones...                   25.0
# 2  ['bacalao desalado', 'cebolleta', 'escarolas',...                   35.0
#
#    calories(kcal)  gluten_free  egg_free  sucrose_fructose_free  low_sodium  \
# 0           252.0            0         0                      0           0
# 1           386.0            0         0                      0           0
# 2             NaN            0         0                      0           0
#
#    ...  brecol jamón cocido  queso  arroz  huevos  aceite    sal  pimienta  \
# 0  ...   False        False  False  False    True    True   True      True
# 1  ...   False        False  False  False   False    True  False     False
# 2  ...   False        False  False  False   False    True   True     False
#
#    active_ingred  num_missing_ingred
# 0              4                   8
# 1              1                   8
# 2              2                  14
#
# [3 rows x 25 columns]

# %%
def rating(match, missing):
    result = 0.75*match-0.25*missing
    return result

recipe_df["recipe_rate"] = recipe_df.apply(lambda x: rating(x["active_ingred"], x["num_missing_ingred"]), axis=1)

# %%
recipe_df.head(3)
# Out:
#                                     recipe_image_url             recipe_name  \
# 0  https://content-recetas.lecturas.com/medio/201...        Ensalada niçoise
# 1  https://content-recetas.lecturas.com/medio/201...   Ensalada del périgord
# 2  https://content-recetas.lecturas.com/medio/202...  Xató con salsa romesco
#
#                                           recipe_url  \
# 0  https://www.lecturas.com/recetas/ensalada-nico...
# 1  https://www.lecturas.com/recetas/ensalada-peri...
# 2  https://www.lecturas.com/recetas/xato-salsa-ro...
#
#                                     ingredients_list  time_preparation(min)  \
# 0  ['patatas pequeñas rojas', 'huevos', 'judías v...                   60.0
# 1  ['foie micuit', 'beicon gruesas', 'champiñones...                   25.0
# 2  ['bacalao desalado', 'cebolleta', 'escarolas',...                   35.0
#
#    calories(kcal)  gluten_free  egg_free  sucrose_fructose_free  low_sodium  \
# 0           252.0            0         0                      0           0
# 1           386.0            0         0                      0           0
# 2             NaN            0         0                      0           0
#
#    ...  jamón cocido  queso  arroz huevos  aceite    sal  pimienta  \
# 0  ...         False  False  False   True    True   True      True
# 1  ...         False  False  False  False    True  False     False
# 2  ...         False  False  False  False    True   True     False
#
#    active_ingred  num_missing_ingred  recipe_rate
# 0              4                   8          0.4
# 1              1                   8         -1.7
# 2              2                  14         -2.8
#
# [3 rows x 26 columns]

# %%
output_df = recipe_df.sort_values(by=['recipe_rate'], ascending=False).head(10)

# %%
top_recipes_df = output_df.sort_values(by=['num_missing_ingred'], ascending=True).head(3)

# %%
top_recipes_df
# Out:
#                                        recipe_image_url  \
# 1520  https://content-recetas.lecturas.com/medio/201...
# 1412  https://content-recetas.lecturas.com/medio/201...
# 5070  https://content-recetas.lecturas.com/medio/201...
#
#                          recipe_name  \
# 1520           Caracoles de tortilla
# 1412  Nidos de huevo, queso y beicon
# 5070       Éclairs con jamón y queso
#
#                                              recipe_url  \
# 1520  https://www.lecturas.com/recetas/caracoles-tor...
# 1412  https://www.lecturas.com/recetas/nidos-huevo-q...
# 5070  https://www.lecturas.com/recetas/eclairs-jamon...
#
#                                        ingredients_list  \
# 1520  ['huevos', 'jamón cocido', 'queso', 'zanahoria...
# 1412  ['huevos de codorniz', 'beicon ahumado', 'ques...
# 5070  ['pasta choux', 'jamón cocido en lonchas', 'qu...
#
#       time_preparation(min)  calories(kcal)  gluten_free  egg_free  \
# 1520                   35.0             NaN            0         0
# 1412                   35.0             NaN            0         0
# 5070                   30.0           196.0            0         0
#
#       sucrose_fructose_free  low_sodium  ...  jamón cocido queso  arroz  \
# 1520                      0           0  ...          True  True  False
# 1412                      0           0  ...         False  True  False
# 5070                      0           0  ...          True  True  False
#
#      huevos  aceite   sal  pimienta  active_ingred  num_missing_ingred  \
# 1520   True    True  True     False              5                   2
# 1412   True    True  True      True              5                   2
# 5070  False    True  True      True              5                   2
#
#       recipe_rate
# 1520         3.25
# 1412         3.25
# 5070         3.25
#
# [3 rows x 26 columns]
