# %%
from selenium import webdriver
from selenium.common.exceptions import TimeoutException
import time
import numpy as np
import pandas as pd
import json

# %%
# Opening the Chrome and going to the Web

recipe_link = "https://www.lecturas.com/recetas/pizzas-empanadas"
chromedriver = "/home/veronica/Ironhack/Final Project/Chrome Driver/chromedriver"
driver = webdriver.Chrome(chromedriver)
driver.get(recipe_link)


# Enabling cookies

time.sleep(3)
element = driver.find_elements_by_class_name('qc-cmp-button')
element[1].click()

recipes_list = []

while True:
    next_page_btn = driver.find_elements_by_class_name('next')
    if len(next_page_btn) < 1:
        recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
        for x in np.arange(len(recipe_sumup_scrap)-1):
            recipe_dict = {}
            time.sleep(2)
            recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
            driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
            time.sleep(3)
            #recipe name
            recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
            #ingredients
            ingredients_list = []
            recipe_ingred = driver.find_elements_by_tag_name('td')
            for x in np.arange(len(recipe_ingred)):
                if x % 2 != 0:
                    ingredients_list.append(recipe_ingred[x].text)
                else:
                    pass
            recipe_dict["ingredients"] = ingredients_list
            #time_preparation and calories
            time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
            try:
                recipe_dict["time_preparation"] = time_calor_scrap[1].text
            except:
                pass
            #calories
            try:
                recipe_dict["calories"] = time_calor_scrap[2].text
            except:
                pass
            #intolerances
            try:
                intolerances = driver.find_elements_by_class_name("intolerances-item")
                intolerances_list = [intolerance.text for intolerance in intolerances]
                recipe_dict["intolerances"] = intolerances_list
            except:
                recipe_dict["intolerances"] = None
            #recipe_url
            recipe_dict["recipe_url"] = driver.current_url
            #images_url
            images = driver.find_elements_by_tag_name('img')
            images_list = [image.get_attribute('src') for image in images]
            recipe_image_url = images_list[1]
            recipe_dict["recipe_image_url"] = images_list[1]
            #category
            recipe_dict["category"] = driver.find_element_by_tag_name('h2').text
            #recipe_list append
            recipes_list.append(recipe_dict)
            driver.back()
            time.sleep(2)
        print("No more pages left")
        break
    else:
        recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
        for x in np.arange(len(recipe_sumup_scrap)-1):
            recipe_dict = {}
            time.sleep(2)
            recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
            driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
            time.sleep(3)
            #recipe name
            recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
            #ingredients
            ingredients_list = []
            recipe_ingred = driver.find_elements_by_tag_name('td')
            for x in np.arange(len(recipe_ingred)):
                if x % 2 != 0:
                    ingredients_list.append(recipe_ingred[x].text)
                else:
                    pass
            recipe_dict["ingredients"] = ingredients_list
            #time_preparation and calories
            time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
            try:
                recipe_dict["time_preparation"] = time_calor_scrap[1].text
            except:
                pass
            #calories
            try:
                recipe_dict["calories"] = time_calor_scrap[2].text
            except:
                pass
            #intolerances
            try:
                intolerances = driver.find_elements_by_class_name("intolerances-item")
                intolerances_list = [intolerance.text for intolerance in intolerances]
                recipe_dict["intolerances"] = intolerances_list
            except:
                recipe_dict["intolerances"] = None
            #recipe_url
            recipe_dict["recipe_url"] = driver.current_url
            #images_url
            images = driver.find_elements_by_tag_name('img')
            images_list = [image.get_attribute('src') for image in images]
            recipe_image_url = images_list[1]
            recipe_dict["recipe_image_url"] = images_list[1]
            #category
            recipe_dict["category"] = driver.find_element_by_tag_name('h2').text
            #recipe_list append
            recipes_list.append(recipe_dict)
            driver.back()
            time.sleep(2)
        next_page_btn = driver.find_elements_by_css_selector(".next [href]")
        driver.execute_script("arguments[0].click()", next_page_btn[0])
        time.sleep(2)
# Out:
# No more pages left

# %%
df_recipes = pd.DataFrame(recipes_list)

df_recipes
# Out:
#                                        recipe_name  \
# 0             Empanadillas de pescadilla y verdura
# 1          Corona de hojaldre con crema y merengue
# 2          Mini canelones de queso brie con berros
# 3              Pizza con salmón y el borde relleno
# 4                              Salmón para invitar
# ..                                             ...
# 278          Tarta de chocolate blanco y frambuesa
# 279             Hojaldritos con fruta de temporada
# 280            Bastones de rosquilla con chocolate
# 281  Tirabuzones crujientes con hierbas aromáticas
# 282              Pizza de berenjenas y calabacines
#
#                                            ingredients time_preparation  \
# 0    [pescadillas, cebolla, pimiento rojo, calabací...           90 min
# 1    [hojaldre, azúcar glas, yemas de huevo para la...           65 min
# 2    [pasta filo, queso brie, eneldo, perejil, acei...           30 min
# 3    [harina de fuerza para la masa, sal para la ma...           50 min
# 4    [lomos de salmón sin piel, hojaldre, setas var...           60 min
# ..                                                 ...              ...
# 278  [harina para la pasta brisa, huevo para la pas...           50 min
# 279  [hojaldre, kiwi, mandarina, plátano, gelatina,...           30 min
# 280  [harina, azúcar, levadura, huevo, aceite de gi...           45 min
# 281  [pasta filo, mantequilla salada, albahaca seca...           30 min
# 282  [masa de pizza, calabacín, berenjena, queso te...           30 min
#
#     calories                  intolerances  \
# 0    432 Cal  [Preparación con antelación]
# 1        NaN                            []
# 2        NaN                            []
# 3        NaN  [Preparación con antelación]
# 4        NaN                            []
# ..       ...                           ...
# 278      NaN                            []
# 279  273 Cal                            []
# 280      NaN                            []
# 281  145 Cal                            []
# 282  295 Cal                            []
#
#                                             recipe_url  \
# 0    https://www.lecturas.com/recetas/empanadillas-...
# 1    https://www.lecturas.com/recetas/corona-hojald...
# 2    https://www.lecturas.com/recetas/mini-canelone...
# 3    https://www.lecturas.com/recetas/pizza-salmon-...
# 4    https://www.lecturas.com/recetas/salmon-para-i...
# ..                                                 ...
# 278  https://www.lecturas.com/recetas/tarta-chocola...
# 279  https://www.lecturas.com/recetas/hojaldritos-f...
# 280  https://www.lecturas.com/recetas/bastones-rosq...
# 281  https://www.lecturas.com/recetas/tirabuzones-c...
# 282  https://www.lecturas.com/recetas/pizza-berenje...
#
#                                       recipe_image_url            category
# 0    https://content-recetas.lecturas.com/medio/201...  PIZZAS Y EMPANADAS
# 1    https://content-recetas.lecturas.com/medio/201...  PIZZAS Y EMPANADAS
# 2    https://content-recetas.lecturas.com/medio/201...  PIZZAS Y EMPANADAS
# 3    https://content-recetas.lecturas.com/medio/201...  PIZZAS Y EMPANADAS
# 4    https://content-recetas.lecturas.com/medio/201...  PIZZAS Y EMPANADAS
# ..                                                 ...                 ...
# 278  https://content-recetas.lecturas.com/medio/201...  PIZZAS Y EMPANADAS
# 279  https://content-recetas.lecturas.com/medio/201...  PIZZAS Y EMPANADAS
# 280  https://content-recetas.lecturas.com/medio/201...  PIZZAS Y EMPANADAS
# 281  https://content-recetas.lecturas.com/medio/201...  PIZZAS Y EMPANADAS
# 282  https://content-recetas.lecturas.com/medio/201...  PIZZAS Y EMPANADAS
#
# [283 rows x 8 columns]

# %%
with open('../data/raw/web_scraping_recipes_5.json', 'w') as json_file:
    json.dump(recipes_list, json_file)

# %%
driver.quit()
