# %%
from selenium import webdriver
from selenium.common.exceptions import TimeoutException
import time
import numpy as np
import pandas as pd
import json

# %%
# Opening the Chrome and going to the Web

recipe_link = "https://www.lecturas.com/recetas/calzone-tomate-y-rucula_8232.html"
chromedriver = "/home/veronica/Ironhack/Final Project/Chrome Driver/chromedriver"
driver = webdriver.Chrome(chromedriver)
driver.get(recipe_link)


# Enabling cookies

time.sleep(3)
element = driver.find_elements_by_class_name('qc-cmp-button')
element[1].click()

# More_info

#more_info = driver.find_element_by_tag_name('span').text
more_info = driver.find_elements_by_xpath('(/html/body/form/main/article/div[1]/div[2]/div[2]/div/div/div/span)')
#dish_type = more_info[3].get_attribute('span').text
#recipe_dict["dish_type"] = dish_type[1]



more_info_list = [info.text for info in more_info]


print(len(more_info_list))
more_info_list
# Out:
# 14
# ['Dieta:',
#  'Mediterránea',
#  'Vegetariana',
#  'Temporada:',
#  'Todo el año',
#  'Técnica:',
#  'Técnica mixta',
#  'Tipo Plato:',
#  'Plato único',
#  'Segundos platos y platos principales',
#  'Precio:',
#  '€',
#  '€ €',
#  'Dificultad:']

# %%
# Opening the Chrome and going to the Web

recipe_link = "https://www.lecturas.com/recetas/calzone-tomate-y-rucula_8232.html"
chromedriver = "/home/veronica/Ironhack/Final Project/Chrome Driver/chromedriver"
driver = webdriver.Chrome(chromedriver)
driver.get(recipe_link)


# Enabling cookies

time.sleep(3)
element = driver.find_elements_by_class_name('qc-cmp-button')
element[1].click()

#steps

#more_info = driver.find_element_by_tag_name('span').text
steps = driver.find_elements_by_xpath('(/html/body/form/main/article/div[2]/div/div[3]/div[2]/div/figure/figcaption/div)')
#dish_type = more_info[3].get_attribute('span').text
#recipe_dict["dish_type"] = dish_type[1]



steps_list = [step.text for step in steps]


print(len(steps_list))
steps_list
# Out:
# 3
# ['Diluye la levadura en 250 ml de agua tibia. Mezcla en un bol la harina con 1 cucharadita de sal. Haz un volcán y vierte el agua con la levadura y 50 ml de aceite. Amasa hasta lograr una masa elástica. Haz una bola, tápala con un paño y déjala reposar 3 h para que doble su volumen.',
#  'Lava los tomates pélalos y trocéalos. Saltéalos con 4 cucharadas de aceite 5 min, hasta que se evapore el exceso de agua. Sazona, remueve y retira. Divide en 4 bolas iguales la masa, colócalas sobre una superficie de trabajo y estíralas, dándoles forma de disco.',
#  'Reparte los tomates, la mozzarella rallada y la rúcula lavada en los discos de masa. Ciérralos, doblándolos por la mitad, sella los bordes y haz unas incisiones en la superficie. Ponlos en la bandeja de horno, espolvoréalos con el parmesano rallado y hornéalos 20 min a 200°. Retira y sirve.']

# %%
<div class="step-container"><div class="recipe-step-title">
Elaboración:</div><div class="step-slider unslicked">
<div class="slide vertical" data-slide="0" id="slide-0">
<figure class="row step">
<img data-src="/Content/img/_blank.gif" src="/Content/img/_blank.gif" alt="_blank" class="col-xs-12 col-md-6 step-blank lazyaspectratio lazyloaded " data-aspectratio="400/300" sizes="57vw" style="height: 22.5px; width: 1.33333px;"><noscript><img src="/Content/img/_blank.gif" alt="_blank" /></noscript>
<figcaption class="stepInfo col-xs-12 col-md-6">
<h5 class="step-position">
Paso 1</h5>
<div>
Después de haber dejado los garbanzos en remojo durante toda la noche, colócalos en una olla junto a las dos hojas de laurel y una de las cebollas pelada. A continuación, agrega agua hasta cubrirlo todo y cuece durante 1 hora a fuego lento.</div>
</figcaption>
</figure>
</div>
<div class="slide vertical" data-slide="1" id="slide-1">
<figure class="row step">
<img data-src="/Content/img/_blank.gif" src="/Content/img/_blank.gif" alt="_blank" class="col-xs-12 col-md-6 step-blank lazyaspectratio lazyloaded " data-aspectratio="400/300" sizes="57vw" style="height: 22.5px; width: 1.33333px;"><noscript><img src="/Content/img/_blank.gif" alt="_blank" /></noscript>
<figcaption class="stepInfo col-xs-12 col-md-6">
<h5 class="step-position">
Paso 2
</h5>
<div>
Transcurrido ese tiempo, echa media cucharada de sal y deja que los garbanzos cuezan durante otros 20 minutos. Apaga y reserva.</div>
</figcaption>
</figure>
<div class="slide-ad">
<!-- AD DFP Manager --><div id="div-gpt-ad-r3-sad-1" data-appear-top-offset="400" data-mangiro-top-offset="2980.15625" data-google-query-id="CL-EnNWA4OgCFdRnGwod_hYPGw"><div id="google_ads_iframe_/1001866/LE_RE_2__container__" style="border: 0pt none; margin: auto; text-align: center;"><iframe id="google_ads_iframe_/1001866/LE_RE_2" title="3rd party ad content" name="google_ads_iframe_/1001866/LE_RE_2" width="300" height="600" scrolling="no" marginwidth="0" marginheight="0" frameborder="0" srcdoc="" style="border: 0px; vertical-align: bottom;" data-google-container-id="5" data-gtm-yt-inspected-8419756_100="true" data-load-complete="true"></iframe></div></div>
</div>
</div>
<div class="slide vertical" data-slide="2" id="slide-2">
<figure class="row step">
<img data-src="/Content/img/_blank.gif" src="/Content/img/_blank.gif" alt="_blank" class="col-xs-12 col-md-6 step-blank lazyaspectratio lazyloaded " data-aspectratio="400/300" sizes="57vw" style="height: 22.5px; width: 1.33333px;"><noscript><img src="/Content/img/_blank.gif" alt="_blank" /></noscript>
<figcaption class="stepInfo col-xs-12 col-md-6">
<h5 class="step-position">
Paso 3</h5>
<div>
Cuece los huevos 10 minutos aproximadamente en un cazo con agua. Retíralos y una vez que estén tibios, pélalos y reserva.</div>
</figcaption>
</figure>
</div>
<div class="slide vertical" data-slide="3" id="slide-3">
<figure class="row step">
<img data-src="/Content/img/_blank.gif" src="/Content/img/_blank.gif" alt="_blank" class="col-xs-12 col-md-6 step-blank lazyaspectratio lazyloaded " data-aspectratio="400/300" sizes="57vw" style="height: 22.5px; width: 1.33333px;"><noscript><img src="/Content/img/_blank.gif" alt="_blank" /></noscript>
<figcaption class="stepInfo col-xs-12 col-md-6">
<h5 class="step-position">
Paso 4</h5>
<div>
Lava muy bien las espinacas con abundante agua, porque habitualmente suelen tener mucha tierra tanto en el tallo como en las hojas. Luego, corta los primeros y separa las hojas. Mientras se escurren, pela y pica bien fina la otra cebolla y dos de los ajos.</div>
</figcaption>
</figure>
<div class="slide-ad">
<!-- AD DFP Manager --><div id="div-gpt-ad-r3-sad-3" data-appear-top-offset="400" data-mangiro-top-offset="4008.1875" data-google-query-id="CJX8qfuA4OgCFVHV1QodY4wLvQ"><div id="google_ads_iframe_/1001866/LE_RE_3__container__" style="border: 0pt none; margin: auto; text-align: center; width: 300px; height: 250px;"><iframe frameborder="0" src="https://tpc.googlesyndication.com/safeframe/1-0-37/html/container.html" id="google_ads_iframe_/1001866/LE_RE_3" title="3rd party ad content" name="" scrolling="no" marginwidth="0" marginheight="0" width="300" height="250" data-is-safeframe="true" sandbox="allow-forms allow-pointer-lock allow-popups allow-popups-to-escape-sandbox allow-same-origin allow-scripts allow-top-navigation-by-user-activation" data-google-container-id="6" style="border: 0px; vertical-align: bottom;" data-gtm-yt-inspected-8419756_100="true" data-load-complete="true"></iframe></div></div>
</div>
</div>
<div class="slide vertical" data-slide="4" id="slide-4">
<figure class="row step">
<img data-src="/Content/img/_blank.gif" src="/Content/img/_blank.gif" alt="_blank" class="col-xs-12 col-md-6 step-blank lazyaspectratio lazyloaded " data-aspectratio="400/300" sizes="57vw" style="height: 22.5px; width: 1.33333px;"><noscript><img src="/Content/img/_blank.gif" alt="_blank" /></noscript>
<figcaption class="stepInfo col-xs-12 col-md-6">
<h5 class="step-position">
Paso 5</h5>
<div>
Calienta una cazuela con unas tres cucharadas de aceite. Fríe en ella la rebanada de pan seco y el último diente de ajo entero, vigilando que no se queme. Retira del fuego el pan y el ajo y resérvalos. Después, echa la cebolla y los ajos que tienes picados y sofríe todo junto durante unos 5 minutos más o menos.</div>
</figcaption>
</figure>
</div>
<div class="slide vertical" data-slide="5" id="slide-5">
<figure class="row step">
<img data-src="/Content/img/_blank.gif" src="/Content/img/_blank.gif" alt="_blank" class="col-xs-12 col-md-6 step-blank lazyaspectratio lazyloaded " data-aspectratio="400/300" sizes="57vw" style="height: 22.5px; width: 1.33333px;"><noscript><img src="/Content/img/_blank.gif" alt="_blank" /></noscript>
<figcaption class="stepInfo col-xs-12 col-md-6">
<h5 class="step-position">
Paso 6</h5>
<div>
En seguida, incorpora el pimentón dulce y remueve solo unos segundos para evitar que se queme. Posteriormente, cúbrelo todo con un litro de agua.</div>
</figcaption>
</figure>
<div class="slide-ad">
<!-- AD DFP Manager --><div id="div-gpt-ad-r3-sad-5" data-appear-top-offset="400" data-mangiro-top-offset="4576.1875" data-google-query-id="CIzQ_vuA4OgCFUmnUQodswcBXg"><div id="google_ads_iframe_/1001866/LE_RE_4__container__" style="border: 0pt none; margin: auto; text-align: center; width: 300px; height: 250px;"><iframe frameborder="0" src="https://tpc.googlesyndication.com/safeframe/1-0-37/html/container.html" id="google_ads_iframe_/1001866/LE_RE_4" title="3rd party ad content" name="" scrolling="no" marginwidth="0" marginheight="0" width="300" height="250" data-is-safeframe="true" sandbox="allow-forms allow-pointer-lock allow-popups allow-popups-to-escape-sandbox allow-same-origin allow-scripts allow-top-navigation-by-user-activation" data-google-container-id="7" style="border: 0px; vertical-align: bottom;" data-gtm-yt-inspected-8419756_100="true" data-load-complete="true"></iframe></div></div>
</div>
</div>
<div class="slide vertical" data-slide="6" id="slide-6">
<figure class="row step">
<img data-src="/Content/img/_blank.gif" src="/Content/img/_blank.gif" alt="_blank" class="col-xs-12 col-md-6 step-blank lazyaspectratio lazyloaded " data-aspectratio="400/300" sizes="57vw" style="height: 22.5px; width: 1.33333px;"><noscript><img src="/Content/img/_blank.gif" alt="_blank" /></noscript>
<figcaption class="stepInfo col-xs-12 col-md-6">
<h5 class="step-position">
Paso 7</h5>
<div>
Incorpora las espinacas, tapa la cazuela y cuécelo todo a fuego lento durante unos 10 minutos, más o menos.</div>
</figcaption>
</figure>
</div>
<div class="slide vertical" data-slide="7" id="slide-7">
<figure class="row step">
<img data-src="/Content/img/_blank.gif" src="/Content/img/_blank.gif" alt="_blank" class="col-xs-12 col-md-6 step-blank lazyaspectratio lazyloaded " data-aspectratio="400/300" sizes="57vw" style="height: 22.5px; width: 1.33333px;"><noscript><img src="/Content/img/_blank.gif" alt="_blank" /></noscript>
<figcaption class="stepInfo col-xs-12 col-md-6">
<h5 class="step-position">
Paso 8</h5>
<div>
Echa los garbanzos cocidos y el bacalao desalado, que antes habrás cortado en dados, y deja que se cueza todo junto entre unos 8 y 10 minutos aproximadamente, siempre a fuego lento.</div>
</figcaption>
</figure>
<div class="slide-ad">
<!-- AD DFP Manager --><div id="div-gpt-ad-r3-sad-7" data-appear-top-offset="400" data-mangiro-top-offset="5121.1875" data-google-query-id="CMGd-PyA4OgCFY0WGwodmtAFUA"><div id="google_ads_iframe_/1001866/LE_RE_5__container__" style="border: 0pt none; margin: auto; text-align: center;"><iframe id="google_ads_iframe_/1001866/LE_RE_5" title="3rd party ad content" name="google_ads_iframe_/1001866/LE_RE_5" width="300" height="250" scrolling="no" marginwidth="0" marginheight="0" frameborder="0" srcdoc="" style="border: 0px; vertical-align: bottom;" data-google-container-id="8" data-gtm-yt-inspected-8419756_100="true" data-load-complete="true"></iframe></div></div>
</div>
</div>
<div class="slide vertical" data-slide="8" id="slide-8">
<figure class="row step">
<img data-src="/Content/img/_blank.gif" src="/Content/img/_blank.gif" alt="_blank" class="col-xs-12 col-md-6 step-blank lazyaspectratio lazyloaded " data-aspectratio="400/300" sizes="57vw" style="height: 22.5px; width: 1.33333px;"><noscript><img src="/Content/img/_blank.gif" alt="_blank" /></noscript>
<figcaption class="stepInfo col-xs-12 col-md-6">
<h5 class="step-position">
Paso 9</h5>
<div>
Mientras tanto, haz una picada con el pan y el ajo que has freído y agrégala al potaje al mismo tiempo que echas los huevos duros cortados a cuartos. Cuécelo  todo durante un par de minutos y apaga el fuego. Sirve el plato bien caliente.</div>
</figcaption>
</figure>
</div>
<div class="slide vertical" data-slide="9" id="slide-9">
<figure class="row step">
<img data-src="/Content/img/_blank.gif" src="/Content/img/_blank.gif" alt="_blank" class="col-xs-12 col-md-6 step-blank lazyaspectratio lazyloaded " data-aspectratio="400/300" sizes="57vw" style="height: 22.5px; width: 1.33333px;"><noscript><img src="/Content/img/_blank.gif" alt="_blank" /></noscript>
<figcaption class="stepInfo col-xs-12 col-md-6">
<h5 class="step-position">
Paso 10</h5>
<div>
TOMA NOTA . Esta receta, por su gran aporte de minerales, vitaminas y proteínas, puedes servirla como plato único.</div>
</figcaption>
</figure>
<div class="slide-ad">
<!-- AD DFP Manager --><div id="div-gpt-ad-r3-sad-9" data-appear-top-offset="400" data-mangiro-top-offset="5666.1875" data-google-query-id="CMiZ1v2A4OgCFZVIGwod4aUE-Q"><div id="google_ads_iframe_/1001866/LE_RE_6__container__" style="border: 0pt none; margin: auto; text-align: center;"><iframe id="google_ads_iframe_/1001866/LE_RE_6" title="3rd party ad content" name="google_ads_iframe_/1001866/LE_RE_6" width="300" height="250" scrolling="no" marginwidth="0" marginheight="0" frameborder="0" srcdoc="" style="border: 0px; vertical-align: bottom;" data-google-container-id="9" data-gtm-yt-inspected-8419756_100="true" data-load-complete="true"></iframe></div></div>
</div>
</div>
</div></div>

# %%
https://www.lecturas.com/recetas/crema-pollo-y-verduras-teja-parmesano_4601.html
    
https://www.lecturas.com/recetas/sopa-clasica-cebolla-gratinada-horno_4605.html

# %%
intolerances_list = [intolerance.text for intolerance in intolerances]

for x in np.arange(len(more_info)):
    more_info_list.append(more_info[x].text)



//*[@id="main8232"]/div[1]/div[2]/div[2]/div[4]/div/div/span[3]
//*[@id="main8234"]/div[1]/div[2]/div[2]/div[4]/div/div/span[2]

/html/body/form/main/article/div[1]/div[2]/div[2]/div[4]/div/div/span[2]

<div class="box-row group middle"

<span class="recipe-extra-item-title">Tipo Plato: </span>
    
//*[@id="main3311"]/div[1]/div[2]/div[2]/div[4]/div/div/span[2]
# Out:
# ''

# %%
more_info_list = []
for x in np.arange(len(more_info)):
    more_info_list.append(more_info[x].text)

print(len(more_info_list))
more_info_list

# %%
https://www.lecturas.com/recetas/torrijas-miel-clasicas_3311.html

# %%
recipes_list = []

while True:
    next_page_btn = driver.find_elements_by_class_name('next')
    if len(next_page_btn) < 1:
        recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
        for x in np.arange(len(recipe_sumup_scrap)-1):
            recipe_dict = {}
            time.sleep(2)
            recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
            driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
            time.sleep(3)
            #recipe name
            recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
            #ingredients
            ingredients_list = []
            recipe_ingred = driver.find_elements_by_tag_name('td')
            for x in np.arange(len(recipe_ingred)):
                if x % 2 != 0:
                    ingredients_list.append(recipe_ingred[x].text)
                else:
                    pass
            recipe_dict["ingredients"] = ingredients_list
            #time_preparation and calories
            time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
            try:
                recipe_dict["time_preparation"] = time_calor_scrap[1].text
            except:
                pass
            #calories
            try:
                recipe_dict["calories"] = time_calor_scrap[2].text
            except:
                pass
            #intolerances
            try:
                intolerances = driver.find_elements_by_class_name("intolerances-item")
                intolerances_list = [intolerance.text for intolerance in intolerances]
                recipe_dict["intolerances"] = intolerances_list
            except:
                recipe_dict["intolerances"] = None
            #recipe_url
            recipe_dict["recipe_url"] = driver.current_url
            #images_url
            images = driver.find_elements_by_tag_name('img')
            images_list = [image.get_attribute('src') for image in images]
            recipe_image_url = images_list[1]
            recipe_dict["recipe_image_url"] = images_list[1]
            #category
            recipe_dict["category"] = driver.find_element_by_tag_name('h2').text
            #dish_type
            more_info = driver.find_elements_by_class_name('recipe-extra-item-title')
            dish_type = more_info.get_attribute('span')
            recipe_dict["dish_type"] = dish_type[1]
            #recipe_list append
            recipes_list.append(recipe_dict)
            driver.back()
            time.sleep(2)
        print("No more pages left")
        break
    else:
        recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
        for x in np.arange(len(recipe_sumup_scrap)-1):
            recipe_dict = {}
            time.sleep(2)
            recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
            driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
            time.sleep(3)
            #recipe name
            recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
            #ingredients
            ingredients_list = []
            recipe_ingred = driver.find_elements_by_tag_name('td')
            for x in np.arange(len(recipe_ingred)):
                if x % 2 != 0:
                    ingredients_list.append(recipe_ingred[x].text)
                else:
                    pass
            recipe_dict["ingredients"] = ingredients_list
            #time_preparation and calories
            time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
            try:
                recipe_dict["time_preparation"] = time_calor_scrap[1].text
            except:
                pass
            #calories
            try:
                recipe_dict["calories"] = time_calor_scrap[2].text
            except:
                pass
            #intolerances
            try:
                intolerances = driver.find_elements_by_class_name("intolerances-item")
                intolerances_list = [intolerance.text for intolerance in intolerances]
                recipe_dict["intolerances"] = intolerances_list
            except:
                recipe_dict["intolerances"] = None
            #recipe_url
            recipe_dict["recipe_url"] = driver.current_url
            #images_url
            images = driver.find_elements_by_tag_name('img')
            images_list = [image.get_attribute('src') for image in images]
            recipe_image_url = images_list[1]
            recipe_dict["recipe_image_url"] = images_list[1]
            #category
            recipe_dict["category"] = driver.find_element_by_tag_name('h2').text
            #recipe_list append
            recipes_list.append(recipe_dict)
            driver.back()
            time.sleep(2)
        next_page_btn = driver.find_elements_by_css_selector(".next [href]")
        driver.execute_script("arguments[0].click()", next_page_btn[0])
        time.sleep(2)

# %%
df_recipes = pd.DataFrame(recipes_list)
df_recipes
# Out:
#                                          recipe_name  \
# 0  Raviolis fritos de cordero y cebolla caramelizada
# 1                             Enrollado de sobrasada
# 2                Tosta de queso con membrillo casero
#
#                                          ingredients time_preparation  \
# 0  [pasta wonton, cuello de cordero, cebollas dul...           60 min
# 1              [pan de molde sin corteza, sobrasada]           10 min
# 2  [queso manchego seco, pan finas, aceite de oli...            5 min
#
#                    intolerances  \
# 0                            []
# 1  [Preparación con antelación]
# 2  [Preparación con antelación]
#
#                                           recipe_url  \
# 0  https://www.lecturas.com/recetas/raviolis-frit...
# 1  https://www.lecturas.com/recetas/enrollado-sob...
# 2  https://www.lecturas.com/recetas/queso-seco-me...
#
#                                     recipe_image_url              category
# ...
