# %%
from selenium import webdriver
from selenium.common.exceptions import TimeoutException
import time
import numpy as np
import pandas as pd
import json

# %%
# Opening the Chrome and going to the Web

recipe_link = "https://www.lecturas.com/recetas/bocadillos-canapes"
chromedriver = "/home/veronica/Ironhack/Final Project/Chrome Driver/chromedriver"
driver = webdriver.Chrome(chromedriver)
driver.get(recipe_link)


# Enabling cookies

time.sleep(3)
element = driver.find_elements_by_class_name('qc-cmp-button')
element[1].click()

recipes_list = []

while True:
    next_page_btn = driver.find_elements_by_class_name('next')
    if len(next_page_btn) < 1:
        recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
        for x in np.arange(len(recipe_sumup_scrap)-1):
            recipe_dict = {}
            time.sleep(2)
            recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
            driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
            time.sleep(3)
            #recipe name
            recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
            #ingredients
            ingredients_list = []
            recipe_ingred = driver.find_elements_by_tag_name('td')
            for x in np.arange(len(recipe_ingred)):
                if x % 2 != 0:
                    ingredients_list.append(recipe_ingred[x].text)
                else:
                    pass
            recipe_dict["ingredients"] = ingredients_list
            #time_preparation and calories
            time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
            try:
                recipe_dict["time_preparation"] = time_calor_scrap[1].text
            except:
                pass
            #calories
            try:
                recipe_dict["calories"] = time_calor_scrap[2].text
            except:
                pass
            #intolerances
            try:
                intolerances = driver.find_elements_by_class_name("intolerances-item")
                intolerances_list = [intolerance.text for intolerance in intolerances]
                recipe_dict["intolerances"] = intolerances_list
            except:
                recipe_dict["intolerances"] = None
            #recipe_url
            recipe_dict["recipe_url"] = driver.current_url
            #images_url
            images = driver.find_elements_by_tag_name('img')
            images_list = [image.get_attribute('src') for image in images]
            recipe_image_url = images_list[1]
            recipe_dict["recipe_image_url"] = images_list[1]
            #category
            recipe_dict["category"] = driver.find_element_by_tag_name('h2').text
            #recipe_list append
            recipes_list.append(recipe_dict)
            driver.back()
            time.sleep(2)
        print("No more pages left")
        break
    else:
        recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
        for x in np.arange(len(recipe_sumup_scrap)-1):
            recipe_dict = {}
            time.sleep(2)
            recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
            driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
            time.sleep(3)
            #recipe name
            recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
            #ingredients
            ingredients_list = []
            recipe_ingred = driver.find_elements_by_tag_name('td')
            for x in np.arange(len(recipe_ingred)):
                if x % 2 != 0:
                    ingredients_list.append(recipe_ingred[x].text)
                else:
                    pass
            recipe_dict["ingredients"] = ingredients_list
            #time_preparation and calories
            time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
            try:
                recipe_dict["time_preparation"] = time_calor_scrap[1].text
            except:
                pass
            #calories
            try:
                recipe_dict["calories"] = time_calor_scrap[2].text
            except:
                pass
            #intolerances
            try:
                intolerances = driver.find_elements_by_class_name("intolerances-item")
                intolerances_list = [intolerance.text for intolerance in intolerances]
                recipe_dict["intolerances"] = intolerances_list
            except:
                recipe_dict["intolerances"] = None
            #recipe_url
            recipe_dict["recipe_url"] = driver.current_url
            #images_url
            images = driver.find_elements_by_tag_name('img')
            images_list = [image.get_attribute('src') for image in images]
            recipe_image_url = images_list[1]
            recipe_dict["recipe_image_url"] = images_list[1]
            #category
            recipe_dict["category"] = driver.find_element_by_tag_name('h2').text
            #recipe_list append
            recipes_list.append(recipe_dict)
            driver.back()
            time.sleep(2)
        next_page_btn = driver.find_elements_by_css_selector(".next [href]")
        driver.execute_script("arguments[0].click()", next_page_btn[0])
        time.sleep(2)
# Out:
# No more pages left

# %%
df_recipes = pd.DataFrame(recipes_list)

df_recipes
# Out:
#                                            recipe_name  \
# 0    Raviolis fritos de cordero y cebolla caramelizada
# 1                               Enrollado de sobrasada
# 2                  Tosta de queso con membrillo casero
# 3                                   Croquetas de pollo
# 4                        Delicias de salmón con caviar
# ..                                                 ...
# 192                   Torres de salmón, pepino y queso
# 193                   Sándwich de salchichas con huevo
# 194            Pinchos de secreto ibérico con pimiento
# 195                           Hamburguesitas con huevo
# 196                           Tosta de caballa ahumada
#
#                                            ingredients time_preparation  \
# 0    [pasta wonton, cuello de cordero, cebollas dul...           60 min
# 1                [pan de molde sin corteza, sobrasada]           10 min
# 2    [queso manchego seco, pan finas, aceite de oli...            5 min
# 3    [pollos, cebolla, harina, mantequilla, leche, ...           40 min
# 4    [salmón ahumado, queso blanco para untar, pan ...            5 min
# ..                                                 ...              ...
# 192  [pepinos, salmón ahumado, queso blanco para un...           10 min
# 193  [pan de molde, salchichas tipo viena, huevos, ...           30 min
# 194  [secreto ibérico, pan, diente de ajo, pimiento...           35 min
# 195  [carne picada de ternera, huevos de codorniz, ...           35 min
# 196  [filetes de caballa, pan de pueblo, cebolla, s...           20 min
#
#                      intolerances  \
# 0                              []
# 1    [Preparación con antelación]
# 2    [Preparación con antelación]
# 3    [Preparación con antelación]
# 4                              []
# ..                            ...
# 192                            []
# 193                            []
# 194                 [Sin lactosa]
# 195                            []
# 196  [Preparación con antelación]
#
#                                             recipe_url  \
# 0    https://www.lecturas.com/recetas/raviolis-frit...
# 1    https://www.lecturas.com/recetas/enrollado-sob...
# 2    https://www.lecturas.com/recetas/queso-seco-me...
# 3    https://www.lecturas.com/recetas/croquetas-pol...
# 4    https://www.lecturas.com/recetas/delicias-salm...
# ..                                                 ...
# 192  https://www.lecturas.com/recetas/torres-salmon...
# 193  https://www.lecturas.com/recetas/sandwich-salc...
# 194  https://www.lecturas.com/recetas/pinchos-secre...
# 195  https://www.lecturas.com/recetas/hamburguesita...
# 196  https://www.lecturas.com/recetas/tosta-caballa...
#
#                                       recipe_image_url              category  \
# 0    https://content-recetas.lecturas.com/medio/201...  BOCADILLOS Y CANAPÉS
# 1    https://content-recetas.lecturas.com/medio/201...  BOCADILLOS Y CANAPÉS
# 2    https://content-recetas.lecturas.com/medio/201...  BOCADILLOS Y CANAPÉS
# 3    https://content-recetas.lecturas.com/medio/201...  BOCADILLOS Y CANAPÉS
# 4    https://content-recetas.lecturas.com/medio/201...  BOCADILLOS Y CANAPÉS
# ..                                                 ...                   ...
# 192  https://content-recetas.lecturas.com/medio/201...  BOCADILLOS Y CANAPÉS
# 193  https://content-recetas.lecturas.com/medio/201...  BOCADILLOS Y CANAPÉS
# 194  https://content-recetas.lecturas.com/medio/201...  BOCADILLOS Y CANAPÉS
# 195  https://content-recetas.lecturas.com/medio/201...  BOCADILLOS Y CANAPÉS
# 196  https://content-recetas.lecturas.com/medio/201...  BOCADILLOS Y CANAPÉS
#
#     calories
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ..       ...
# 192      NaN
# 193      NaN
# 194      NaN
# 195      NaN
# 196      NaN
#
# [197 rows x 8 columns]

# %%
with open('../data/raw/web_scraping_recipes_6.json', 'w') as json_file:
    json.dump(recipes_list, json_file)

# %%
driver.quit()
