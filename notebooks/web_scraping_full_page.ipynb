# %%
from selenium import webdriver
from selenium.common.exceptions import TimeoutException
import time
import numpy as np
import pandas as pd
import json

# %%
# Opening the Chrome and going to the Web

recipe_link = 'https://www.lecturas.com/recetas/'
chromedriver = "/home/veronica/Ironhack/Final Project/Chrome Driver/chromedriver"
driver = webdriver.Chrome(chromedriver)
driver.get(recipe_link)

# %%
# Enabling cookies

time.sleep(3)
element = driver.find_elements_by_class_name('qc-cmp-button')
element[1].click()

# %%
# Selecting cat

time.sleep(3)
categories = driver.find_elements_by_tag_name('h4')

# %%
categories_list = []
for x in np.arange(len(categories)-1):
    categories_list.append(categories[x].text)

print(len(categories_list))
categories_list
# Out:
# 17
# ['Ensaladas',
#  'Sopas y cremas',
#  'Verduras',
#  'Legumbres',
#  'Arroces y cereales',
#  'Pastas',
#  'Huevos y tortillas',
#  'Potajes y cocidos',
#  'Carnes',
#  'Aves',
#  'Pescados y mariscos',
#  'Quiche, creps y pasteles salados',
#  'Postres y dulces',
#  'Pizzas y empanadas',
#  'Bocadillos y canapés',
#  'Mermeladas y confituras',
#  'Salsas']

# %%
# Looping throught the categories

recipes_list = []
driver.set_page_load_timeout(10)

for x in np.arange(len(categories)-1):
    try:
        categories = driver.find_elements_by_tag_name('h4')
        driver.execute_script("arguments[0].click()", categories[x])
        time.sleep(2)
        while True:
            next_page_btn = driver.find_elements_by_class_name('next')
            if len(next_page_btn) < 1:
                recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                for x in np.arange(len(recipe_sumup_scrap)-1):
                    recipe_dict = {}
                    time.sleep(2)
                    recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                    driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
                    time.sleep(3)
                    #recipe name
                    recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
                    #ingredients
                    ingredients_list = []
                    recipe_ingred = driver.find_elements_by_tag_name('td')
                    for x in np.arange(len(recipe_ingred)-1):
                        if x % 2 != 0:
                            ingredients_list.append(recipe_ingred[x].text)
                        else:
                            pass
                    recipe_dict["ingredients"] = ingredients_list
                    #time_preparation and calories
                    time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
                    try:
                        recipe_dict["time_preparation"] = time_calor_scrap[1].text
                    except:
                        pass
                    #calories
                    try:
                        recipe_dict["calories"] = time_calor_scrap[2].text
                    except:
                        pass
                    #intolerances
                    try:
                        intolerances = driver.find_elements_by_class_name("intolerances-item")
                        intolerances_list = [intolerance.text for intolerance in intolerances]
                        recipe_dict["intolerances"] = intolerances_list
                    except:
                        recipe_dict["intolerances"] = None
                    #recipe_url
                    recipe_dict["recipe_url"] = driver.current_url
                    #images_url
                    images = driver.find_elements_by_tag_name('img')
                    images_list = [image.get_attribute('src') for image in images]
                    recipe_image_url = images_list[1]
                    recipe_dict["recipe_image_url"] = images_list[1]
                    #recipe_list append
                    recipes_list.append(recipe_dict)
                    driver.back()
                    time.sleep(2)
                print("No more pages left")
                break
            else:
                recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                for x in np.arange(len(recipe_sumup_scrap)-1):
                    recipe_dict = {}
                    time.sleep(2)
                    recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                    driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
                    time.sleep(3)
                    #recipe name
                    recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
                    #ingredients
                    ingredients_list = []
                    recipe_ingred = driver.find_elements_by_tag_name('td')
                    for x in np.arange(len(recipe_ingred)-1):
                        if x % 2 != 0:
                            ingredients_list.append(recipe_ingred[x].text)
                        else:
                            pass
                    recipe_dict["ingredients"] = ingredients_list
                    #time_preparation and calories
                    time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
                    try:
                        recipe_dict["time_preparation"] = time_calor_scrap[1].text
                    except:
                        pass
                    #calories
                    try:
                        recipe_dict["calories"] = time_calor_scrap[2].text
                    except:
                        pass
                    #intolerances
                    try:
                        intolerances = driver.find_elements_by_class_name("intolerances-item")
                        intolerances_list = [intolerance.text for intolerance in intolerances]
                        recipe_dict["intolerances"] = intolerances_list
                    except:
                        recipe_dict["intolerances"] = None
                    #recipe_url
                    recipe_dict["recipe_url"] = driver.current_url
                    #images_url
                    images = driver.find_elements_by_tag_name('img')
                    images_list = [image.get_attribute('src') for image in images]
                    recipe_image_url = images_list[1]
                    recipe_dict["recipe_image_url"] = images_list[1]
                    #recipe_list append
                    recipes_list.append(recipe_dict)
                    driver.back()
                    time.sleep(2)
                next_page_btn = driver.find_elements_by_css_selector(".next [href]")
                driver.execute_script("arguments[0].click()", next_page_btn[0])
                time.sleep(2)
        main_page = driver.find_elements_by_css_selector(".left [href]")
        driver.execute_script("arguments[0].click()", main_page[1])
        time.sleep(2)
    except:
        current_link = driver.current_url 
        fail_link = "https://www.lecturas.com/recetas/postres-dulces?_page=15"
        if current_link == fail_link:
            next_page = "https://www.lecturas.com/recetas/postres-dulces?_page=16"
            driver.get(next_page)
            driver.set_page_load_timeout(10)
            while True:
                next_page_btn = driver.find_elements_by_class_name('next')
                if len(next_page_btn) < 1:
                    recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                    for x in np.arange(len(recipe_sumup_scrap)-1):
                        recipe_dict = {}
                        time.sleep(2)
                        recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                        driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
                        time.sleep(3)
                        #recipe name
                        recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
                        #ingredients
                        ingredients_list = []
                        recipe_ingred = driver.find_elements_by_tag_name('td')
                        for x in np.arange(len(recipe_ingred)-1):
                            if x % 2 != 0:
                                ingredients_list.append(recipe_ingred[x].text)
                            else:
                                pass
                        recipe_dict["ingredients"] = ingredients_list
                        #time_preparation and calories
                        time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
                        try:
                            recipe_dict["time_preparation"] = time_calor_scrap[1].text
                        except:
                            pass
                        #calories
                        try:
                            recipe_dict["calories"] = time_calor_scrap[2].text
                        except:
                            pass
                        #intolerances
                        try:
                            intolerances = driver.find_elements_by_class_name("intolerances-item")
                            intolerances_list = [intolerance.text for intolerance in intolerances]
                            recipe_dict["intolerances"] = intolerances_list
                        except:
                            recipe_dict["intolerances"] = None
                        #recipe_url
                        recipe_dict["recipe_url"] = driver.current_url
                        #images_url
                        images = driver.find_elements_by_tag_name('img')
                        images_list = [image.get_attribute('src') for image in images]
                        recipe_image_url = images_list[1]
                        recipe_dict["recipe_image_url"] = images_list[1]
                        #recipe_list append
                        recipes_list.append(recipe_dict)
                        driver.back()
                        time.sleep(2)
                    print("No more pages left")
                    break
                else:
                    recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                    for x in np.arange(len(recipe_sumup_scrap)-1):
                        recipe_dict = {}
                        time.sleep(2)
                        recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                        driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
                        time.sleep(3)
                        #recipe name
                        recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
                        #ingredients
                        ingredients_list = []
                        recipe_ingred = driver.find_elements_by_tag_name('td')
                        for x in np.arange(len(recipe_ingred)-1):
                            if x % 2 != 0:
                                ingredients_list.append(recipe_ingred[x].text)
                            else:
                                pass
                        recipe_dict["ingredients"] = ingredients_list
                        #time_preparation and calories
                        time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
                        try:
                            recipe_dict["time_preparation"] = time_calor_scrap[1].text
                        except:
                            pass
                        #calories
                        try:
                            recipe_dict["calories"] = time_calor_scrap[2].text
                        except:
                            pass
                        #intolerances
                        try:
                            intolerances = driver.find_elements_by_class_name("intolerances-item")
                            intolerances_list = [intolerance.text for intolerance in intolerances]
                            recipe_dict["intolerances"] = intolerances_list
                        except:
                            recipe_dict["intolerances"] = None
                        #recipe_url
                        recipe_dict["recipe_url"] = driver.current_url
                        #images_url
                        images = driver.find_elements_by_tag_name('img')
                        images_list = [image.get_attribute('src') for image in images]
                        recipe_image_url = images_list[1]
                        recipe_dict["recipe_image_url"] = images_list[1]
                        #recipe_list append
                        recipes_list.append(recipe_dict)
                        driver.back()
                        time.sleep(2)
                    next_page_btn = driver.find_elements_by_css_selector(".next [href]")
                    driver.execute_script("arguments[0].click()", next_page_btn[0])
                    time.sleep(2)
            main_page = driver.find_elements_by_css_selector(".left [href]")
            driver.execute_script("arguments[0].click()", main_page[1])
            time.sleep(2)
            
        else:
            print(f"TimeoutError at {current_link}")
            driver.get(current_link)
            driver.set_page_load_timeout(10)
            try:
                while True:
                    next_page_btn = driver.find_elements_by_class_name('next')
                    if len(next_page_btn) < 1:
                        recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                        for x in np.arange(len(recipe_sumup_scrap)-1):
                            recipe_dict = {}
                            time.sleep(2)
                            recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                            driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
                            time.sleep(3)
                            #recipe name
                            recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
                            #ingredients
                            ingredients_list = []
                            recipe_ingred = driver.find_elements_by_tag_name('td')
                            for x in np.arange(len(recipe_ingred)-1):
                                if x % 2 != 0:
                                    ingredients_list.append(recipe_ingred[x].text)
                                else:
                                    pass
                            recipe_dict["ingredients"] = ingredients_list
                            #time_preparation and calories
                            time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
                            try:
                                recipe_dict["time_preparation"] = time_calor_scrap[1].text
                            except:
                                pass
                            #calories
                            try:
                                recipe_dict["calories"] = time_calor_scrap[2].text
                            except:
                                pass
                            #intolerances
                            try:
                                intolerances = driver.find_elements_by_class_name("intolerances-item")
                                intolerances_list = [intolerance.text for intolerance in intolerances]
                                recipe_dict["intolerances"] = intolerances_list
                            except:
                                recipe_dict["intolerances"] = None
                            #recipe_url
                            recipe_dict["recipe_url"] = driver.current_url
                            #images_url
                            images = driver.find_elements_by_tag_name('img')
                            images_list = [image.get_attribute('src') for image in images]
                            recipe_image_url = images_list[1]
                            recipe_dict["recipe_image_url"] = images_list[1]
                            #recipe_list append
                            recipes_list.append(recipe_dict)
                            driver.back()
                            time.sleep(2)
                        print("No more pages left")
                        break
                    else:
                        recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                        for x in np.arange(len(recipe_sumup_scrap)-1):
                            recipe_dict = {}
                            time.sleep(2)
                            recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                            driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
                            time.sleep(3)
                            #recipe name
                            recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
                            #ingredients
                            ingredients_list = []
                            recipe_ingred = driver.find_elements_by_tag_name('td')
                            for x in np.arange(len(recipe_ingred)-1):
                                if x % 2 != 0:
                                    ingredients_list.append(recipe_ingred[x].text)
                                else:
                                    pass
                            recipe_dict["ingredients"] = ingredients_list
                            #time_preparation and calories
                            time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
                            try:
                                recipe_dict["time_preparation"] = time_calor_scrap[1].text
                            except:
                                pass
                            #calories
                            try:
                                recipe_dict["calories"] = time_calor_scrap[2].text
                            except:
                                pass
                            #intolerances
                            try:
                                intolerances = driver.find_elements_by_class_name("intolerances-item")
                                intolerances_list = [intolerance.text for intolerance in intolerances]
                                recipe_dict["intolerances"] = intolerances_list
                            except:
                                recipe_dict["intolerances"] = None
                            #recipe_url
                            recipe_dict["recipe_url"] = driver.current_url
                            #images_url
                            images = driver.find_elements_by_tag_name('img')
                            images_list = [image.get_attribute('src') for image in images]
                            recipe_image_url = images_list[1]
                            recipe_dict["recipe_image_url"] = images_list[1]
                            #recipe_list append
                            recipes_list.append(recipe_dict)
                            driver.back()
                            time.sleep(2)
                        next_page_btn = driver.find_elements_by_css_selector(".next [href]")
                        driver.execute_script("arguments[0].click()", next_page_btn[0])
                        time.sleep(2)
                main_page = driver.find_elements_by_css_selector(".left [href]")
                driver.execute_script("arguments[0].click()", main_page[1])
                time.sleep(2)
            except:
                driver.back()
                driver.set_page_load_timeout(10)
                time.sleep(2)
                while True:
                    next_page_btn = driver.find_elements_by_class_name('next')
                    if len(next_page_btn) < 1:
                        recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                        for x in np.arange(len(recipe_sumup_scrap)-1):
                            recipe_dict = {}
                            time.sleep(2)
                            recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                            driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
                            time.sleep(3)
                            #recipe name
                            recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
                            #ingredients
                            ingredients_list = []
                            recipe_ingred = driver.find_elements_by_tag_name('td')
                            for x in np.arange(len(recipe_ingred)-1):
                                if x % 2 != 0:
                                    ingredients_list.append(recipe_ingred[x].text)
                                else:
                                    pass
                            recipe_dict["ingredients"] = ingredients_list
                            #time_preparation and calories
                            time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
                            try:
                                recipe_dict["time_preparation"] = time_calor_scrap[1].text
                            except:
                                pass
                            #calories
                            try:
                                recipe_dict["calories"] = time_calor_scrap[2].text
                            except:
                                pass
                            #intolerances
                            try:
                                intolerances = driver.find_elements_by_class_name("intolerances-item")
                                intolerances_list = [intolerance.text for intolerance in intolerances]
                                recipe_dict["intolerances"] = intolerances_list
                            except:
                                recipe_dict["intolerances"] = None
                            #recipe_url
                            recipe_dict["recipe_url"] = driver.current_url
                            #images_url
                            images = driver.find_elements_by_tag_name('img')
                            images_list = [image.get_attribute('src') for image in images]
                            recipe_image_url = images_list[1]
                            recipe_dict["recipe_image_url"] = images_list[1]
                            #recipe_list append
                            recipes_list.append(recipe_dict)
                            driver.back()
                            time.sleep(2)
                        print("No more pages left")
                        break
                    else:
                        recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                        for x in np.arange(len(recipe_sumup_scrap)-1):
                            recipe_dict = {}
                            time.sleep(2)
                            recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                            driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
                            time.sleep(3)
                            #recipe name
                            recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
                            #ingredients
                            ingredients_list = []
                            recipe_ingred = driver.find_elements_by_tag_name('td')
                            for x in np.arange(len(recipe_ingred)-1):
                                if x % 2 != 0:
                                    ingredients_list.append(recipe_ingred[x].text)
                                else:
                                    pass
                            recipe_dict["ingredients"] = ingredients_list
                            #time_preparation and calories
                            time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
                            try:
                                recipe_dict["time_preparation"] = time_calor_scrap[1].text
                            except:
                                pass
                            #calories
                            try:
                                recipe_dict["calories"] = time_calor_scrap[2].text
                            except:
                                pass
                            #intolerances
                            try:
                                intolerances = driver.find_elements_by_class_name("intolerances-item")
                                intolerances_list = [intolerance.text for intolerance in intolerances]
                                recipe_dict["intolerances"] = intolerances_list
                            except:
                                recipe_dict["intolerances"] = None
                            #recipe_url
                            recipe_dict["recipe_url"] = driver.current_url
                            #images_url
                            images = driver.find_elements_by_tag_name('img')
                            images_list = [image.get_attribute('src') for image in images]
                            recipe_image_url = images_list[1]
                            recipe_dict["recipe_image_url"] = images_list[1]
                            #recipe_list append
                            recipes_list.append(recipe_dict)
                            driver.back()
                            time.sleep(2)
                        next_page_btn = driver.find_elements_by_css_selector(".next [href]")
                        driver.execute_script("arguments[0].click()", next_page_btn[0])
                        time.sleep(2)
                main_page = driver.find_elements_by_css_selector(".left [href]")
                driver.execute_script("arguments[0].click()", main_page[1])
                time.sleep(2)
    else:
        pass
# Out:
# No more pages left
# No more pages left
# TimeoutError at https://www.lecturas.com/recetas/verduras?_page=19
# No more pages left
# No more pages left
# No more pages left
# No more pages left
# No more pages left
# No more pages left
# No more pages left
# No more pages left
# TimeoutError at https://www.lecturas.com/recetas/pescados-mariscos?_page=11
# No more pages left
# TimeoutError at https://www.lecturas.com/recetas/crujiente-setas-y-huevo_8347.html
# No more pages left
# No more pages left
# No more pages left
# TimeoutError at https://www.lecturas.com/recetas/relampagos-crema-cafe_3021.html
# No more pages left
# No more pages left
# No more pages left
# No more pages left

# %%
df_recipes = pd.DataFrame(recipes_list)

df_recipes
# Out:
#                                        recipe_name  \
# 0                                 Ensalada niçoise
# 1                            Ensalada del périgord
# 2                           Xató con salsa romesco
# 3     Ensalada de ceviche de langostinos y cebolla
# 4           Ensalada de pollo, remolacha y manzana
# ...                                            ...
# 5986            Curry en polvo de chennai (Madrás)
# 5987                           Pasta de curry rojo
# 5988                                  Salsa hoisin
# 5989                                Salsa boloñesa
# 5990                                Salsa bechamel
#
#                                             ingredients time_preparation  \
# 0     [patatas pequeñas rojas, huevos, judías verdes...           60 min
# 1     [foie micuit, beicon gruesas, champiñones, ber...           25 min
# 2     [bacalao desalado, cebolleta, escarolas, aceit...           35 min
# 3     [langostinos, pimienta, limas, tomates, ceboll...           25 min
# 4     [pechugas de pollo, manzanas ácida, col lombar...           40 min
# ...                                                 ...              ...
# 5986  [pimienta negra en grano, semillas de cilantro...            5 min
# 5987  [semillas de cilantro, comino, semillas de mos...            8 min
# 5988  [ajo, guindilla, judía azuki cocida y triturad...            5 min
# 5989  [carne de ternera picada, tomate triturado, ce...           35 min
# 5990  [leche, mantequilla, harina, nuez moscada, pim...           20 min
#
#      calories                                       intolerances  \
# 0     252 Cal                                                 []
# 1     386 Cal                                                 []
# 2         NaN                                                 []
# 3     176 Cal                                                 []
# 4     203 Cal                                                 []
# ...       ...                                                ...
# 5986      NaN  [Baja en sodio, Sin gluten, Sin lactosa, Sin s...
# 5987      NaN  [Sin gluten, Sin lactosa, Sin sacarosa o fruct...
# 5988      NaN                                                 []
# 5989  208 Cal                                                 []
# 5990      NaN                                                 []
#
#                                              recipe_url  \
# 0     https://www.lecturas.com/recetas/ensalada-nico...
# 1     https://www.lecturas.com/recetas/ensalada-peri...
# 2     https://www.lecturas.com/recetas/xato-salsa-ro...
# 3     https://www.lecturas.com/recetas/ensalada-cevi...
# 4     https://www.lecturas.com/recetas/ensalada-poll...
# ...                                                 ...
# 5986  https://www.lecturas.com/recetas/curry-polvo-c...
# 5987  https://www.lecturas.com/recetas/pasta-curry-r...
# 5988  https://www.lecturas.com/recetas/salsa-hoisin_...
# 5989  https://www.lecturas.com/recetas/salsa-bolones...
# 5990  https://www.lecturas.com/recetas/salsa-bechame...
#
#                                        recipe_image_url
# 0     https://content-recetas.lecturas.com/medio/201...
# 1     https://content-recetas.lecturas.com/medio/201...
# 2     https://content-recetas.lecturas.com/medio/202...
# 3     https://content-recetas.lecturas.com/medio/201...
# 4     https://content-recetas.lecturas.com/medio/201...
# ...                                                 ...
# 5986  ......
# 5987  ......
# 5988  ......
# 5989  ......
# 5990  ......
#
# [5991 rows x 7 columns]

# %%
df_recipes["recipe_name"].value_counts()
# Out:
# Tarta de queso con lunares de chocolate           85
# Mousse de frambuesa y chocolate negro rallado     85
# Pastelitos de nata y chocolate                    85
# Lubina rellena de puerros y espárragos            28
# Caballa a la plancha con ensalada de patata       28
#                                                   ..
# Ensalada de brotes, tomatitos y mozzarella         1
# Bizcochos individuales con nata y frutas rojas     1
# Potaje de soja verde con arroz y verduras          1
# Éclairs con jamón y queso                          1
# Barquitas de huevo y verduras                      1
# Name: recipe_name, Length: 5172, dtype: int64

# %%
with open('../data/raw/web_scraping_recipes.json', 'w') as json_file:
    json.dump(recipes_list, json_file)

# %%
driver.quit()
