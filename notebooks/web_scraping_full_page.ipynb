# %%
from selenium import webdriver
from selenium.common.exceptions import TimeoutException
import time
import numpy as np
import pandas as pd
import json

# %%
# Opening the Chrome and going to the Web

recipe_link = 'https://www.lecturas.com/recetas/'
chromedriver = "/home/veronica/Ironhack/Final Project/Chrome Driver/chromedriver"
driver = webdriver.Chrome(chromedriver)
driver.get(recipe_link)

# %%
# Enabling cookies

time.sleep(3)
element = driver.find_elements_by_class_name('qc-cmp-button')
element[1].click()

# %%
# Selecting cat

time.sleep(3)
categories = driver.find_elements_by_tag_name('h4')

# %%
categories_list = []
for x in np.arange(len(categories)-1):
    categories_list.append(categories[x].text)

print(len(categories_list))
categories_list
# Out:
# 17
# ['Ensaladas',
#  'Sopas y cremas',
#  'Verduras',
#  'Legumbres',
#  'Arroces y cereales',
#  'Pastas',
#  'Huevos y tortillas',
#  'Potajes y cocidos',
#  'Carnes',
#  'Aves',
#  'Pescados y mariscos',
#  'Quiche, creps y pasteles salados',
#  'Postres y dulces',
#  'Pizzas y empanadas',
#  'Bocadillos y canapés',
#  'Mermeladas y confituras',
#  'Salsas']

# %% [raw]
# # Looping throught the categories
#
# recipes_list = []
# driver.set_page_load_timeout(10)
#
# for x in np.arange(len(categories)-1):
#     categories = driver.find_elements_by_tag_name('h4')
#     driver.execute_script("arguments[0].click()", categories[x])
#     time.sleep(2)
#     while True:
#         next_page_btn = driver.find_elements_by_class_name('next')
#         if len(next_page_btn) < 1:
#             recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
#             for x in np.arange(len(recipe_sumup_scrap)-1):
#                 recipe_dict = {}
#                 time.sleep(2)
#                 recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
#                 driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
#                 time.sleep(3)
#                 #recipe name
#                 recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
#                 #ingredients
#                 ingredients_list = []
#                 recipe_ingred = driver.find_elements_by_tag_name('td')
#                 for x in np.arange(len(recipe_ingred)-1):
#                     if x % 2 != 0:
#                         ingredients_list.append(recipe_ingred[x].text)
#                     else:
#                         pass
#                 recipe_dict["ingredients"] = ingredients_list
#                 #time_preparation and calories
#                 time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
#                 try:
#                     recipe_dict["time_preparation"] = time_calor_scrap[1].text
#                 except:
#                     pass
#                 #calories
#                 try:
#                     recipe_dict["calories"] = time_calor_scrap[2].text
#                 except:
#                     pass
#                 #intolerances
#                 try:
#                     intolerances = driver.find_elements_by_class_name("intolerances-item")
#                     intolerances_list = [intolerance.text for intolerance in intolerances]
#                     recipe_dict["intolerances"] = intolerances_list
#                 except:
#                     recipe_dict["intolerances"] = None
#                 #recipe_url
#                 recipe_dict["recipe_url"] = driver.current_url
#                 #images_url
#                 images = driver.find_elements_by_tag_name('img')
#                 images_list = [image.get_attribute('src') for image in images]
#                 recipe_image_url = images_list[1]
#                 recipe_dict["recipe_image_url"] = images_list[1]
#                 #recipe_list append
#                 recipes_list.append(recipe_dict)
#                 driver.back()
#                 time.sleep(2)
#             print("No more pages left")
#             break
#         else:
#             recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
#             for x in np.arange(len(recipe_sumup_scrap)-1):
#                 recipe_dict = {}
#                 time.sleep(2)
#                 recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
#                 driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
#                 time.sleep(3)
#                 #recipe name
#                 recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
#                 #ingredients
#                 ingredients_list = []
#                 recipe_ingred = driver.find_elements_by_tag_name('td')
#                 for x in np.arange(len(recipe_ingred)-1):
#                     if x % 2 != 0:
#                         ingredients_list.append(recipe_ingred[x].text)
#                     else:
#                         pass
#                 recipe_dict["ingredients"] = ingredients_list
#                 #time_preparation and calories
#                 time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
#                 try:
#                     recipe_dict["time_preparation"] = time_calor_scrap[1].text
#                 except:
#                     pass
#                 #calories
#                 try:
#                     recipe_dict["calories"] = time_calor_scrap[2].text
#                 except:
#                     pass
#                 #intolerances
#                 try:
#                     intolerances = driver.find_elements_by_class_name("intolerances-item")
#                     intolerances_list = [intolerance.text for intolerance in intolerances]
#                     recipe_dict["intolerances"] = intolerances_list
#                 except:
#                     recipe_dict["intolerances"] = None
#                 #recipe_url
#                 recipe_dict["recipe_url"] = driver.current_url
#                 #images_url
#                 images = driver.find_elements_by_tag_name('img')
#                 images_list = [image.get_attribute('src') for image in images]
#                 recipe_image_url = images_list[1]
#                 recipe_dict["recipe_image_url"] = images_list[1]
#                 #recipe_list append
#                 recipes_list.append(recipe_dict)
#                 driver.back()
#                 time.sleep(2)
#             next_page_btn = driver.find_elements_by_css_selector(".next [href]")
#             driver.execute_script("arguments[0].click()", next_page_btn[0])
#             time.sleep(2)
#     main_page = driver.find_elements_by_css_selector(".left [href]")
#     driver.execute_script("arguments[0].click()", main_page[1])
#     time.sleep(2)

# %%
# Looping throught the categories

recipes_list = []
driver.set_page_load_timeout(10)

for x in np.arange(len(categories)-1):
    try:
        categories = driver.find_elements_by_tag_name('h4')
        driver.execute_script("arguments[0].click()", categories[x])
        time.sleep(2)
        while True:
            next_page_btn = driver.find_elements_by_class_name('next')
            if len(next_page_btn) < 1:
                recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                for x in np.arange(len(recipe_sumup_scrap)-1):
                    recipe_dict = {}
                    time.sleep(2)
                    recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                    driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
                    time.sleep(3)
                    #recipe name
                    recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
                    #ingredients
                    ingredients_list = []
                    recipe_ingred = driver.find_elements_by_tag_name('td')
                    for x in np.arange(len(recipe_ingred)-1):
                        if x % 2 != 0:
                            ingredients_list.append(recipe_ingred[x].text)
                        else:
                            pass
                    recipe_dict["ingredients"] = ingredients_list
                    #time_preparation and calories
                    time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
                    try:
                        recipe_dict["time_preparation"] = time_calor_scrap[1].text
                    except:
                        pass
                    #calories
                    try:
                        recipe_dict["calories"] = time_calor_scrap[2].text
                    except:
                        pass
                    #intolerances
                    try:
                        intolerances = driver.find_elements_by_class_name("intolerances-item")
                        intolerances_list = [intolerance.text for intolerance in intolerances]
                        recipe_dict["intolerances"] = intolerances_list
                    except:
                        recipe_dict["intolerances"] = None
                    #recipe_url
                    recipe_dict["recipe_url"] = driver.current_url
                    #images_url
                    images = driver.find_elements_by_tag_name('img')
                    images_list = [image.get_attribute('src') for image in images]
                    recipe_image_url = images_list[1]
                    recipe_dict["recipe_image_url"] = images_list[1]
                    #recipe_list append
                    recipes_list.append(recipe_dict)
                    driver.back()
                    time.sleep(2)
                print("No more pages left")
                break
            else:
                recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                for x in np.arange(len(recipe_sumup_scrap)-1):
                    recipe_dict = {}
                    time.sleep(2)
                    recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                    driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
                    time.sleep(3)
                    #recipe name
                    recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
                    #ingredients
                    ingredients_list = []
                    recipe_ingred = driver.find_elements_by_tag_name('td')
                    for x in np.arange(len(recipe_ingred)-1):
                        if x % 2 != 0:
                            ingredients_list.append(recipe_ingred[x].text)
                        else:
                            pass
                    recipe_dict["ingredients"] = ingredients_list
                    #time_preparation and calories
                    time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
                    try:
                        recipe_dict["time_preparation"] = time_calor_scrap[1].text
                    except:
                        pass
                    #calories
                    try:
                        recipe_dict["calories"] = time_calor_scrap[2].text
                    except:
                        pass
                    #intolerances
                    try:
                        intolerances = driver.find_elements_by_class_name("intolerances-item")
                        intolerances_list = [intolerance.text for intolerance in intolerances]
                        recipe_dict["intolerances"] = intolerances_list
                    except:
                        recipe_dict["intolerances"] = None
                    #recipe_url
                    recipe_dict["recipe_url"] = driver.current_url
                    #images_url
                    images = driver.find_elements_by_tag_name('img')
                    images_list = [image.get_attribute('src') for image in images]
                    recipe_image_url = images_list[1]
                    recipe_dict["recipe_image_url"] = images_list[1]
                    #recipe_list append
                    recipes_list.append(recipe_dict)
                    driver.back()
                    time.sleep(2)
                next_page_btn = driver.find_elements_by_css_selector(".next [href]")
                driver.execute_script("arguments[0].click()", next_page_btn[0])
                time.sleep(2)
        main_page = driver.find_elements_by_css_selector(".left [href]")
        driver.execute_script("arguments[0].click()", main_page[1])
        time.sleep(2)
    except:
        current_link = driver.current_url 
        fail_link = "https://www.lecturas.com/recetas/postres-dulces?_page=15"
        if current_link == fail_link:
            next_page = "https://www.lecturas.com/recetas/postres-dulces?_page=16"
            driver.get(next_page)
            driver.set_page_load_timeout(10)
            while True:
                next_page_btn = driver.find_elements_by_class_name('next')
                if len(next_page_btn) < 1:
                    recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                    for x in np.arange(len(recipe_sumup_scrap)-1):
                        recipe_dict = {}
                        time.sleep(2)
                        recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                        driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
                        time.sleep(3)
                        #recipe name
                        recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
                        #ingredients
                        ingredients_list = []
                        recipe_ingred = driver.find_elements_by_tag_name('td')
                        for x in np.arange(len(recipe_ingred)-1):
                            if x % 2 != 0:
                                ingredients_list.append(recipe_ingred[x].text)
                            else:
                                pass
                        recipe_dict["ingredients"] = ingredients_list
                        #time_preparation and calories
                        time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
                        try:
                            recipe_dict["time_preparation"] = time_calor_scrap[1].text
                        except:
                            pass
                        #calories
                        try:
                            recipe_dict["calories"] = time_calor_scrap[2].text
                        except:
                            pass
                        #intolerances
                        try:
                            intolerances = driver.find_elements_by_class_name("intolerances-item")
                            intolerances_list = [intolerance.text for intolerance in intolerances]
                            recipe_dict["intolerances"] = intolerances_list
                        except:
                            recipe_dict["intolerances"] = None
                        #recipe_url
                        recipe_dict["recipe_url"] = driver.current_url
                        #images_url
                        images = driver.find_elements_by_tag_name('img')
                        images_list = [image.get_attribute('src') for image in images]
                        recipe_image_url = images_list[1]
                        recipe_dict["recipe_image_url"] = images_list[1]
                        #recipe_list append
                        recipes_list.append(recipe_dict)
                        driver.back()
                        time.sleep(2)
                    print("No more pages left")
                    break
                else:
                    recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                    for x in np.arange(len(recipe_sumup_scrap)-1):
                        recipe_dict = {}
                        time.sleep(2)
                        recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                        driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
                        time.sleep(3)
                        #recipe name
                        recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
                        #ingredients
                        ingredients_list = []
                        recipe_ingred = driver.find_elements_by_tag_name('td')
                        for x in np.arange(len(recipe_ingred)-1):
                            if x % 2 != 0:
                                ingredients_list.append(recipe_ingred[x].text)
                            else:
                                pass
                        recipe_dict["ingredients"] = ingredients_list
                        #time_preparation and calories
                        time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
                        try:
                            recipe_dict["time_preparation"] = time_calor_scrap[1].text
                        except:
                            pass
                        #calories
                        try:
                            recipe_dict["calories"] = time_calor_scrap[2].text
                        except:
                            pass
                        #intolerances
                        try:
                            intolerances = driver.find_elements_by_class_name("intolerances-item")
                            intolerances_list = [intolerance.text for intolerance in intolerances]
                            recipe_dict["intolerances"] = intolerances_list
                        except:
                            recipe_dict["intolerances"] = None
                        #recipe_url
                        recipe_dict["recipe_url"] = driver.current_url
                        #images_url
                        images = driver.find_elements_by_tag_name('img')
                        images_list = [image.get_attribute('src') for image in images]
                        recipe_image_url = images_list[1]
                        recipe_dict["recipe_image_url"] = images_list[1]
                        #recipe_list append
                        recipes_list.append(recipe_dict)
                        driver.back()
                        time.sleep(2)
                    next_page_btn = driver.find_elements_by_css_selector(".next [href]")
                    driver.execute_script("arguments[0].click()", next_page_btn[0])
                    time.sleep(2)
            main_page = driver.find_elements_by_css_selector(".left [href]")
            driver.execute_script("arguments[0].click()", main_page[1])
            time.sleep(2)
            
        else:
            print(f"TimeoutError at {current_link}")
            driver.get(current_link)
            driver.set_page_load_timeout(10)
            try:
                while True:
                    next_page_btn = driver.find_elements_by_class_name('next')
                    if len(next_page_btn) < 1:
                        recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                        for x in np.arange(len(recipe_sumup_scrap)-1):
                            recipe_dict = {}
                            time.sleep(2)
                            recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                            driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
                            time.sleep(3)
                            #recipe name
                            recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
                            #ingredients
                            ingredients_list = []
                            recipe_ingred = driver.find_elements_by_tag_name('td')
                            for x in np.arange(len(recipe_ingred)-1):
                                if x % 2 != 0:
                                    ingredients_list.append(recipe_ingred[x].text)
                                else:
                                    pass
                            recipe_dict["ingredients"] = ingredients_list
                            #time_preparation and calories
                            time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
                            try:
                                recipe_dict["time_preparation"] = time_calor_scrap[1].text
                            except:
                                pass
                            #calories
                            try:
                                recipe_dict["calories"] = time_calor_scrap[2].text
                            except:
                                pass
                            #intolerances
                            try:
                                intolerances = driver.find_elements_by_class_name("intolerances-item")
                                intolerances_list = [intolerance.text for intolerance in intolerances]
                                recipe_dict["intolerances"] = intolerances_list
                            except:
                                recipe_dict["intolerances"] = None
                            #recipe_url
                            recipe_dict["recipe_url"] = driver.current_url
                            #images_url
                            images = driver.find_elements_by_tag_name('img')
                            images_list = [image.get_attribute('src') for image in images]
                            recipe_image_url = images_list[1]
                            recipe_dict["recipe_image_url"] = images_list[1]
                            #recipe_list append
                            recipes_list.append(recipe_dict)
                            driver.back()
                            time.sleep(2)
                        print("No more pages left")
                        break
                    else:
                        recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                        for x in np.arange(len(recipe_sumup_scrap)-1):
                            recipe_dict = {}
                            time.sleep(2)
                            recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                            driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
                            time.sleep(3)
                            #recipe name
                            recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
                            #ingredients
                            ingredients_list = []
                            recipe_ingred = driver.find_elements_by_tag_name('td')
                            for x in np.arange(len(recipe_ingred)-1):
                                if x % 2 != 0:
                                    ingredients_list.append(recipe_ingred[x].text)
                                else:
                                    pass
                            recipe_dict["ingredients"] = ingredients_list
                            #time_preparation and calories
                            time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
                            try:
                                recipe_dict["time_preparation"] = time_calor_scrap[1].text
                            except:
                                pass
                            #calories
                            try:
                                recipe_dict["calories"] = time_calor_scrap[2].text
                            except:
                                pass
                            #intolerances
                            try:
                                intolerances = driver.find_elements_by_class_name("intolerances-item")
                                intolerances_list = [intolerance.text for intolerance in intolerances]
                                recipe_dict["intolerances"] = intolerances_list
                            except:
                                recipe_dict["intolerances"] = None
                            #recipe_url
                            recipe_dict["recipe_url"] = driver.current_url
                            #images_url
                            images = driver.find_elements_by_tag_name('img')
                            images_list = [image.get_attribute('src') for image in images]
                            recipe_image_url = images_list[1]
                            recipe_dict["recipe_image_url"] = images_list[1]
                            #recipe_list append
                            recipes_list.append(recipe_dict)
                            driver.back()
                            time.sleep(2)
                        next_page_btn = driver.find_elements_by_css_selector(".next [href]")
                        driver.execute_script("arguments[0].click()", next_page_btn[0])
                        time.sleep(2)
                main_page = driver.find_elements_by_css_selector(".left [href]")
                driver.execute_script("arguments[0].click()", main_page[1])
                time.sleep(2)
            except:
                driver.back()
                driver.set_page_load_timeout(10)
                time.sleep(2)
                while True:
                    next_page_btn = driver.find_elements_by_class_name('next')
                    if len(next_page_btn) < 1:
                        recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                        for x in np.arange(len(recipe_sumup_scrap)-1):
                            recipe_dict = {}
                            time.sleep(2)
                            recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                            driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
                            time.sleep(3)
                            #recipe name
                            recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
                            #ingredients
                            ingredients_list = []
                            recipe_ingred = driver.find_elements_by_tag_name('td')
                            for x in np.arange(len(recipe_ingred)-1):
                                if x % 2 != 0:
                                    ingredients_list.append(recipe_ingred[x].text)
                                else:
                                    pass
                            recipe_dict["ingredients"] = ingredients_list
                            #time_preparation and calories
                            time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
                            try:
                                recipe_dict["time_preparation"] = time_calor_scrap[1].text
                            except:
                                pass
                            #calories
                            try:
                                recipe_dict["calories"] = time_calor_scrap[2].text
                            except:
                                pass
                            #intolerances
                            try:
                                intolerances = driver.find_elements_by_class_name("intolerances-item")
                                intolerances_list = [intolerance.text for intolerance in intolerances]
                                recipe_dict["intolerances"] = intolerances_list
                            except:
                                recipe_dict["intolerances"] = None
                            #recipe_url
                            recipe_dict["recipe_url"] = driver.current_url
                            #images_url
                            images = driver.find_elements_by_tag_name('img')
                            images_list = [image.get_attribute('src') for image in images]
                            recipe_image_url = images_list[1]
                            recipe_dict["recipe_image_url"] = images_list[1]
                            #recipe_list append
                            recipes_list.append(recipe_dict)
                            driver.back()
                            time.sleep(2)
                        print("No more pages left")
                        break
                    else:
                        recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                        for x in np.arange(len(recipe_sumup_scrap)-1):
                            recipe_dict = {}
                            time.sleep(2)
                            recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                            driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
                            time.sleep(3)
                            #recipe name
                            recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
                            #ingredients
                            ingredients_list = []
                            recipe_ingred = driver.find_elements_by_tag_name('td')
                            for x in np.arange(len(recipe_ingred)-1):
                                if x % 2 != 0:
                                    ingredients_list.append(recipe_ingred[x].text)
                                else:
                                    pass
                            recipe_dict["ingredients"] = ingredients_list
                            #time_preparation and calories
                            time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
                            try:
                                recipe_dict["time_preparation"] = time_calor_scrap[1].text
                            except:
                                pass
                            #calories
                            try:
                                recipe_dict["calories"] = time_calor_scrap[2].text
                            except:
                                pass
                            #intolerances
                            try:
                                intolerances = driver.find_elements_by_class_name("intolerances-item")
                                intolerances_list = [intolerance.text for intolerance in intolerances]
                                recipe_dict["intolerances"] = intolerances_list
                            except:
                                recipe_dict["intolerances"] = None
                            #recipe_url
                            recipe_dict["recipe_url"] = driver.current_url
                            #images_url
                            images = driver.find_elements_by_tag_name('img')
                            images_list = [image.get_attribute('src') for image in images]
                            recipe_image_url = images_list[1]
                            recipe_dict["recipe_image_url"] = images_list[1]
                            #recipe_list append
                            recipes_list.append(recipe_dict)
                            driver.back()
                            time.sleep(2)
                        next_page_btn = driver.find_elements_by_css_selector(".next [href]")
                        driver.execute_script("arguments[0].click()", next_page_btn[0])
                        time.sleep(2)
                main_page = driver.find_elements_by_css_selector(".left [href]")
                driver.execute_script("arguments[0].click()", main_page[1])
                time.sleep(2)
# Out:
# No more pages left
# TimeoutError at https://www.lecturas.com/recetas/crema-guisantes_3406.html
# No more pages left
# No more pages left
# No more pages left
# No more pages left
# No more pages left
# No more pages left
# No more pages left
# No more pages left
# No more pages left
# TimeoutError at https://www.lecturas.com/recetas/calamares-a-hortelana_436.html
# No more pages left
# No more pages left
# No more pages left
# No more pages left
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-01e3f57a7467> in <module>
#     114         main_page = driver.find_elements_by_css_selector(".left [href]")
# --> 115         driver.execute_script("arguments[0].click()", main_page[1])
#     116         time.sleep(2)
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-01e3f57a7467> in <module>
#     226                     time.sleep(2)
#     227             main_page = driver.find_elements_by_css_selector(".left [href]")
# --> 228             driver.execute_script("arguments[0].click()", main_page[1])
#     229             time.sleep(2)
#     230
#
# IndexError: list index out of range

# %% [raw]
# except:
#         current_link = driver.current_url
#         print(f"TimeoutError at {current_link}")
#         driver.get(current_link)
#         driver.set_page_load_timeout(10)
#         try:
#             while True:
#                 next_page_btn = driver.find_elements_by_class_name('next')
#                 if len(next_page_btn) < 1:
#                     recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
#                     for x in np.arange(len(recipe_sumup_scrap)-1):
#                         recipe_dict = {}
#                         time.sleep(2)
#                         recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
#                         driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
#                         time.sleep(3)
#                         #recipe name
#                         recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
#                         #ingredients
#                         ingredients_list = []
#                         recipe_ingred = driver.find_elements_by_tag_name('td')
#                         for x in np.arange(len(recipe_ingred)-1):
#                             if x % 2 != 0:
#                                 ingredients_list.append(recipe_ingred[x].text)
#                             else:
#                                 pass
#                         recipe_dict["ingredients"] = ingredients_list
#                         #time_preparation and calories
#                         time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
#                         try:
#                             recipe_dict["time_preparation"] = time_calor_scrap[1].text
#                         except:
#                             pass
#                         #calories
#                         try:
#                             recipe_dict["calories"] = time_calor_scrap[2].text
#                         except:
#                             pass
#                         #intolerances
#                         try:
#                             intolerances = driver.find_elements_by_class_name("intolerances-item")
#                             intolerances_list = [intolerance.text for intolerance in intolerances]
#                             recipe_dict["intolerances"] = intolerances_list
#                         except:
#                             recipe_dict["intolerances"] = None
#                         #recipe_url
#                         recipe_dict["recipe_url"] = driver.current_url
#                         #images_url
#                         images = driver.find_elements_by_tag_name('img')
#                         images_list = [image.get_attribute('src') for image in images]
#                         recipe_image_url = images_list[1]
#                         recipe_dict["recipe_image_url"] = images_list[1]
#                         #recipe_list append
#                         recipes_list.append(recipe_dict)
#                         driver.back()
#                         time.sleep(2)
#                     print("No more pages left")
#                     break
#                 else:
#                     recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
#                     for x in np.arange(len(recipe_sumup_scrap)-1):
#                         recipe_dict = {}
#                         time.sleep(2)
#                         recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
#                         driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
#                         time.sleep(3)
#                         #recipe name
#                         recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
#                         #ingredients
#                         ingredients_list = []
#                         recipe_ingred = driver.find_elements_by_tag_name('td')
#                         for x in np.arange(len(recipe_ingred)-1):
#                             if x % 2 != 0:
#                                 ingredients_list.append(recipe_ingred[x].text)
#                             else:
#                                 pass
#                         recipe_dict["ingredients"] = ingredients_list
#                         #time_preparation and calories
#                         time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
#                         try:
#                             recipe_dict["time_preparation"] = time_calor_scrap[1].text
#                         except:
#                             pass
#                         #calories
#                         try:
#                             recipe_dict["calories"] = time_calor_scrap[2].text
#                         except:
#                             pass
#                         #intolerances
#                         try:
#                             intolerances = driver.find_elements_by_class_name("intolerances-item")
#                             intolerances_list = [intolerance.text for intolerance in intolerances]
#                             recipe_dict["intolerances"] = intolerances_list
#                         except:
#                             recipe_dict["intolerances"] = None
#                         #recipe_url
#                         recipe_dict["recipe_url"] = driver.current_url
#                         #images_url
#                         images = driver.find_elements_by_tag_name('img')
#                         images_list = [image.get_attribute('src') for image in images]
#                         recipe_image_url = images_list[1]
#                         recipe_dict["recipe_image_url"] = images_list[1]
#                         #recipe_list append
#                         recipes_list.append(recipe_dict)
#                         driver.back()
#                         time.sleep(2)
#                     next_page_btn = driver.find_elements_by_css_selector(".next [href]")
#                     driver.execute_script("arguments[0].click()", next_page_btn[0])
#                     time.sleep(2)
#             main_page = driver.find_elements_by_css_selector(".left [href]")
#             driver.execute_script("arguments[0].click()", main_page[1])
#             time.sleep(2)
#         except:
#             #recipe name
#             recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
#             #ingredients
#             ingredients_list = []
#             recipe_ingred = driver.find_elements_by_tag_name('td')
#             for x in np.arange(len(recipe_ingred)-1):
#                 if x % 2 != 0:
#                     ingredients_list.append(recipe_ingred[x].text)
#                 else:
#                     pass
#             recipe_dict["ingredients"] = ingredients_list
#             #time_preparation and calories
#             time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
#             try:
#                 recipe_dict["time_preparation"] = time_calor_scrap[1].text
#             except:
#                 pass
#             #calories
#             try:
#                 recipe_dict["calories"] = time_calor_scrap[2].text
#             except:
#                 pass
#             #intolerances
#             try:
#                 intolerances = driver.find_elements_by_class_name("intolerances-item")
#                 intolerances_list = [intolerance.text for intolerance in intolerances]
#                 recipe_dict["intolerances"] = intolerances_list
#             except:
#                 recipe_dict["intolerances"] = None
#             #recipe_url
#             recipe_dict["recipe_url"] = driver.current_url
#             #images_url
#             images = driver.find_elements_by_tag_name('img')
#             images_list = [image.get_attribute('src') for image in images]
#             recipe_image_url = images_list[1]
#             recipe_dict["recipe_image_url"] = images_list[1]
#             #recipe_list append
#             recipes_list.append(recipe_dict)
#             driver.back()
#             time.sleep(2)

# %% [raw]
# categories = driver.find_elements_by_tag_name('h4')
# driver.execute_script("arguments[0].click()", categories[0])

# %% [raw]
# main_page = driver.find_elements_by_css_selector(".left [href]")
# driver.execute_script("arguments[0].click()", main_page[1])

# %%
df_recipes = pd.DataFrame(recipes_list)

df_recipes
# Out:
#                                            recipe_name  \
# 0                                     Ensalada niçoise
# 1                                Ensalada del périgord
# 2                               Xató con salsa romesco
# 3         Ensalada de ceviche de langostinos y cebolla
# 4               Ensalada de pollo, remolacha y manzana
# ...                                                ...
# 5085                     Tarta de galletas y chocolate
# 5086  Natillas al caramelo con bastoncitos de hojaldre
# 5087                           Cheesecake de chocolate
# 5088     Mousse de frambuesa y chocolate negro rallado
# 5089           Tarta de queso con lunares de chocolate
#
#                                             ingredients time_preparation  \
# 0     [patatas pequeñas rojas, huevos, judías verdes...           60 min
# 1     [foie micuit, beicon gruesas, champiñones, ber...           25 min
# 2     [bacalao desalado, cebolleta, escarolas, aceit...           35 min
# 3     [langostinos, pimienta, limas, tomates, ceboll...           25 min
# 4     [pechugas de pollo, manzanas ácida, col lombar...           40 min
# ...                                                 ...              ...
# 5085  [galleta paquetes, leche, chocolate fondant, n...           25 min
# 5086  [leche, yema de huevo, azúcar, huevo, limón la...           40 min
# 5087  [galletas maría, mantequilla, cacao en polvo, ...          120 min
# 5088  [frambuesas, gelatina, azúcar, nata para monta...           30 min
# 5089  [mantequilla, galletas de chocolate, queso bla...           90 min
#
#      calories                  intolerances  \
# 0     252 Cal                            []
# 1     386 Cal                            []
# 2         NaN                            []
# 3     176 Cal                            []
# 4     203 Cal                            []
# ...       ...                           ...
# 5085      NaN                            []
# 5086  333 Cal                            []
# 5087      NaN                            []
# 5088      NaN  [Preparación con antelación]
# 5089      NaN                            []
#
#                                              recipe_url  \
# 0     https://www.lecturas.com/recetas/ensalada-nico...
# 1     https://www.lecturas.com/recetas/ensalada-peri...
# 2     https://www.lecturas.com/recetas/xato-salsa-ro...
# 3     https://www.lecturas.com/recetas/ensalada-cevi...
# 4     https://www.lecturas.com/recetas/ensalada-poll...
# ...                                                 ...
# 5085  https://www.lecturas.com/recetas/tarta-galleta...
# 5086  https://www.lecturas.com/recetas/natillas-cara...
# 5087  https://www.lecturas.com/recetas/cheesecake-ch...
# 5088  https://www.lecturas.com/recetas/mousse-frambu...
# 5089  https://www.lecturas.com/recetas/tarta-queso-l...
#
#                                        recipe_image_url
# 0     https://content-recetas.lecturas.com/medio/201...
# 1     https://content-recetas.lecturas.com/medio/201...
# 2     https://content-recetas.lecturas.com/medio/202...
# 3     https://content-recetas.lecturas.com/medio/201...
# 4     https://content-recetas.lecturas.com/medio/201...
# ...                                                 ...
# 5085  ......
# 5086  ......
# 5087  ......
# 5088  ......
# 5089  ......
#
# [5090 rows x 7 columns]

# %%
df_recipes["recipe_name"].value_counts()
# Out:
# Cheesecake de chocolate                          68
# Mousse de frambuesa y chocolate negro rallado    68
# Tarta de queso con lunares de chocolate          67
# Caballa a la plancha con ensalada de patata      24
# Bogavante al whisky con almejas                  24
#                                                  ..
# Estofado de alitas de pollo                       1
# Timbal de cuscús con hortalizas y huevo poché     1
# Guisantes con bacalao y patatas                   1
# Crema de boletus                                  1
# Tarta de mondoñedo                                1
# Name: recipe_name, Length: 4442, dtype: int64

# %%
with open('web_scraping_recipes.json', 'w') as json_file:
    json.dump(recipes_list, json_file)

# %% [raw]
# https://www.lecturas.com/recetas/postres-dulces?_page=15

# %% [raw]
# <div class="left"><p id="breadcrumb"><a
# href="/" title="Inicio">Inicio</a> / <a
# href="/recetas" title="recetas">recetas</a> / <a
# href="/recetas/ensaladas" title="Ensaladas">Ensaladas</a></p></div>
