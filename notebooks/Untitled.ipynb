# %%
from selenium import webdriver
from selenium.common.exceptions import TimeoutException
import time
import numpy as np
import pandas as pd
import json

# Opening the Chrome and going to the Web

recipe_link = 'https://www.lecturas.com/recetas/'
chromedriver = "/home/veronica/Ironhack/Final Project/Chrome Driver/chromedriver"
driver = webdriver.Chrome(chromedriver)
driver.get(recipe_link)


# Enabling cookies

time.sleep(3)
element = driver.find_elements_by_class_name('qc-cmp-button')
element[1].click()


# Selecting cat

time.sleep(3)
categories = driver.find_elements_by_tag_name('h4')


# Looping throught the categories

recipes_list = []
driver.set_page_load_timeout(10)

for x in np.arange(len(categories)-1):
    try:
        categories = driver.find_elements_by_tag_name('h4')
        driver.execute_script("arguments[0].click()", categories[x])
        #category = categories[x].text
        time.sleep(2)
        while True:
            next_page_btn = driver.find_elements_by_class_name('next')
            if len(next_page_btn) < 1:
                recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                for x in np.arange(len(recipe_sumup_scrap)):
                    recipe_dict = {}
                    time.sleep(2)
                    recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                    driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
                    time.sleep(3)
                    #recipe name
                    recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
                    #ingredients
                    ingredients_list = []
                    quantity_list = []
                    recipe_ingred = driver.find_elements_by_tag_name('td')
                    for x in np.arange(len(recipe_ingred)):
                        if x % 2 != 0:
                            ingredients_list.append(recipe_ingred[x].text)
                        else:
                            quantity_list.append(recipe_ingred[x].text)
                    recipe_dict["ingredients"] = ingredients_list
                    recipe_dict["ingred_quantity"] = quantity_list
                    #time_preparation and calories
                    time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
                    try:
                        recipe_dict["time_preparation"] = time_calor_scrap[1].text
                    except:
                        pass
                    #calories
                    try:
                        recipe_dict["calories"] = time_calor_scrap[2].text
                    except:
                        pass
                    #intolerances
                    try:
                        intolerances = driver.find_elements_by_class_name("intolerances-item")
                        intolerances_list = [intolerance.text for intolerance in intolerances]
                        recipe_dict["intolerances"] = intolerances_list
                    except:
                        recipe_dict["intolerances"] = None
                    #recipe_url
                    recipe_dict["recipe_url"] = driver.current_url
                    #images_url
                    images = driver.find_elements_by_tag_name('img')
                    images_list = [image.get_attribute('src') for image in images]
                    recipe_dict["recipe_image_url"] = images_list[1]
                    #category
                    category = driver.find_element_by_tag_name('h2').text
                    recipe_dict["category"] = category
                    #extra_info
                    more_info = driver.find_elements_by_xpath('(/html/body/form/main/article/div[1]/div[2]/div[2]/div/div/div/span)')
                    more_info_list = [info.text for info in more_info]
                    recipe_dict["more_info"] = more_info_list
                    #steps
                    steps = driver.find_elements_by_xpath('(/html/body/form/main/article/div[2]/div/div[3]/div[2]/div/figure/figcaption/div)')
                    steps_list = [step.text for step in steps]
                    recipe_dict["recipe_steps"] = steps_list
                    #recipe_list append
                    recipes_list.append(recipe_dict)
                    driver.back()
                    time.sleep(2)
                print(f"{category} finished")
                break
            else:
                recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                for x in np.arange(len(recipe_sumup_scrap)):
                    recipe_dict = {}
                    time.sleep(2)
                    recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                    driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
                    time.sleep(3)
                    #recipe name
                    recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
                    #ingredients
                    ingredients_list = []
                    quantity_list = []
                    recipe_ingred = driver.find_elements_by_tag_name('td')
                    for x in np.arange(len(recipe_ingred)):
                        if x % 2 != 0:
                            ingredients_list.append(recipe_ingred[x].text)
                        else:
                            quantity_list.append(recipe_ingred[x].text)
                    recipe_dict["ingredients"] = ingredients_list
                    recipe_dict["ingred_quantity"] = quantity_list
                    #time_preparation and calories
                    time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
                    try:
                        recipe_dict["time_preparation"] = time_calor_scrap[1].text
                    except:
                        pass
                    #calories
                    try:
                        recipe_dict["calories"] = time_calor_scrap[2].text
                    except:
                        pass
                    #intolerances
                    try:
                        intolerances = driver.find_elements_by_class_name("intolerances-item")
                        intolerances_list = [intolerance.text for intolerance in intolerances]
                        recipe_dict["intolerances"] = intolerances_list
                    except:
                        recipe_dict["intolerances"] = None
                    #recipe_url
                    recipe_dict["recipe_url"] = driver.current_url
                    #images_url
                    images = driver.find_elements_by_tag_name('img')
                    images_list = [image.get_attribute('src') for image in images]
                    recipe_dict["recipe_image_url"] = images_list[1]
                    #category
                    category = driver.find_element_by_tag_name('h2').text
                    recipe_dict["category"] = category
                    #extra_info
                    more_info = driver.find_elements_by_xpath('(/html/body/form/main/article/div[1]/div[2]/div[2]/div/div/div/span)')
                    more_info_list = [info.text for info in more_info]
                    recipe_dict["more_info"] = more_info_list
                    #steps
                    steps = driver.find_elements_by_xpath('(/html/body/form/main/article/div[2]/div/div[3]/div[2]/div/figure/figcaption/div)')
                    steps_list = [step.text for step in steps]
                    recipe_dict["recipe_steps"] = steps_list
                    #recipe_list append
                    recipes_list.append(recipe_dict)
                    driver.back()
                    time.sleep(2)
                next_page_btn = driver.find_elements_by_css_selector(".next [href]")
                driver.execute_script("arguments[0].click()", next_page_btn[0])
                time.sleep(2)
        main_page = driver.find_elements_by_css_selector(".left [href]")
        driver.execute_script("arguments[0].click()", main_page[1])
        time.sleep(2)
    except:
        current_link = driver.current_url
        if current_link == "https://www.lecturas.com/recetas/postres-dulces?_page=15":
            next_page = "https://www.lecturas.com/recetas/postres-dulces?_page=16"
            driver.get(next_page)
            driver.set_page_load_timeout(10)
            while True:
                next_page_btn = driver.find_elements_by_class_name('next')
                if len(next_page_btn) < 1:
                    recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                    for x in np.arange(len(recipe_sumup_scrap)):
                        recipe_dict = {}
                        time.sleep(2)
                        recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                        driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
                        time.sleep(3)
                        #recipe name
                        recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
                        #ingredients
                        ingredients_list = []
                        quantity_list = []
                        recipe_ingred = driver.find_elements_by_tag_name('td')
                        for x in np.arange(len(recipe_ingred)):
                            if x % 2 != 0:
                                ingredients_list.append(recipe_ingred[x].text)
                            else:
                                quantity_list.append(recipe_ingred[x].text)
                        recipe_dict["ingredients"] = ingredients_list
                        recipe_dict["ingred_quantity"] = quantity_list
                        #time_preparation and calories
                        time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
                        try:
                            recipe_dict["time_preparation"] = time_calor_scrap[1].text
                        except:
                            pass
                        #calories
                        try:
                            recipe_dict["calories"] = time_calor_scrap[2].text
                        except:
                            pass
                        #intolerances
                        try:
                            intolerances = driver.find_elements_by_class_name("intolerances-item")
                            intolerances_list = [intolerance.text for intolerance in intolerances]
                            recipe_dict["intolerances"] = intolerances_list
                        except:
                            recipe_dict["intolerances"] = None
                        #recipe_url
                        recipe_dict["recipe_url"] = driver.current_url
                        #images_url
                        images = driver.find_elements_by_tag_name('img')
                        images_list = [image.get_attribute('src') for image in images]
                        recipe_dict["recipe_image_url"] = images_list[1]
                        #category
                        category = driver.find_element_by_tag_name('h2').text
                        recipe_dict["category"] = category
                        #extra_info
                        more_info = driver.find_elements_by_xpath('(/html/body/form/main/article/div[1]/div[2]/div[2]/div/div/div/span)')
                        more_info_list = [info.text for info in more_info]
                        recipe_dict["more_info"] = more_info_list
                        #steps
                        steps = driver.find_elements_by_xpath('(/html/body/form/main/article/div[2]/div/div[3]/div[2]/div/figure/figcaption/div)')
                        steps_list = [step.text for step in steps]
                        recipe_dict["recipe_steps"] = steps_list
                        #recipe_list append
                        recipes_list.append(recipe_dict)
                        driver.back()
                        time.sleep(2)
                    print(f"{category} finished")
                    break
                else:
                    recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                    for x in np.arange(len(recipe_sumup_scrap)):
                        recipe_dict = {}
                        time.sleep(2)
                        recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                        driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
                        time.sleep(3)
                        #recipe name
                        recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
                        #ingredients
                        ingredients_list = []
                        quantity_list = []
                        recipe_ingred = driver.find_elements_by_tag_name('td')
                        for x in np.arange(len(recipe_ingred)):
                            if x % 2 != 0:
                                ingredients_list.append(recipe_ingred[x].text)
                            else:
                                quantity_list.append(recipe_ingred[x].text)
                        recipe_dict["ingredients"] = ingredients_list
                        recipe_dict["ingred_quantity"] = quantity_list
                        #time_preparation and calories
                        time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
                        try:
                            recipe_dict["time_preparation"] = time_calor_scrap[1].text
                        except:
                            pass
                        #calories
                        try:
                            recipe_dict["calories"] = time_calor_scrap[2].text
                        except:
                            pass
                        #intolerances
                        try:
                            intolerances = driver.find_elements_by_class_name("intolerances-item")
                            intolerances_list = [intolerance.text for intolerance in intolerances]
                            recipe_dict["intolerances"] = intolerances_list
                        except:
                            recipe_dict["intolerances"] = None
                        #recipe_url
                        recipe_dict["recipe_url"] = driver.current_url
                        #images_url
                        images = driver.find_elements_by_tag_name('img')
                        images_list = [image.get_attribute('src') for image in images]
                        recipe_dict["recipe_image_url"] = images_list[1]
                        #category
                        category = driver.find_element_by_tag_name('h2').text
                        recipe_dict["category"] = category
                        #extra_info
                        more_info = driver.find_elements_by_xpath('(/html/body/form/main/article/div[1]/div[2]/div[2]/div/div/div/span)')
                        more_info_list = [info.text for info in more_info]
                        recipe_dict["more_info"] = more_info_list
                        #steps
                        steps = driver.find_elements_by_xpath('(/html/body/form/main/article/div[2]/div/div[3]/div[2]/div/figure/figcaption/div)')
                        steps_list = [step.text for step in steps]
                        recipe_dict["recipe_steps"] = steps_list
                        #recipe_list append
                        recipes_list.append(recipe_dict)
                        driver.back()
                        time.sleep(2)
                    next_page_btn = driver.find_elements_by_css_selector(".next [href]")
                    driver.execute_script("arguments[0].click()", next_page_btn[0])
                    time.sleep(2)
            main_page = driver.find_elements_by_css_selector(".left [href]")
            driver.execute_script("arguments[0].click()", main_page[1])
            time.sleep(2)
        elif current_link == "https://www.lecturas.com/recetas/crema-pollo-y-verduras-teja-parmesano_4601.html":
            next_page = "https://www.lecturas.com/recetas/sopas-cremas?_page=8"
            driver.get(next_page)
            driver.set_page_load_timeout(10)
            while True:
                next_page_btn = driver.find_elements_by_class_name('next')
                if len(next_page_btn) < 1:
                    recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                    for x in np.arange(len(recipe_sumup_scrap)):
                        recipe_dict = {}
                        time.sleep(2)
                        recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                        driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
                        time.sleep(3)
                        #recipe name
                        recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
                        #ingredients
                        ingredients_list = []
                        quantity_list = []
                        recipe_ingred = driver.find_elements_by_tag_name('td')
                        for x in np.arange(len(recipe_ingred)):
                            if x % 2 != 0:
                                ingredients_list.append(recipe_ingred[x].text)
                            else:
                                quantity_list.append(recipe_ingred[x].text)
                        recipe_dict["ingredients"] = ingredients_list
                        recipe_dict["ingred_quantity"] = quantity_list
                        #time_preparation and calories
                        time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
                        try:
                            recipe_dict["time_preparation"] = time_calor_scrap[1].text
                        except:
                            pass
                        #calories
                        try:
                            recipe_dict["calories"] = time_calor_scrap[2].text
                        except:
                            pass
                        #intolerances
                        try:
                            intolerances = driver.find_elements_by_class_name("intolerances-item")
                            intolerances_list = [intolerance.text for intolerance in intolerances]
                            recipe_dict["intolerances"] = intolerances_list
                        except:
                            recipe_dict["intolerances"] = None
                        #recipe_url
                        recipe_dict["recipe_url"] = driver.current_url
                        #images_url
                        images = driver.find_elements_by_tag_name('img')
                        images_list = [image.get_attribute('src') for image in images]
                        recipe_dict["recipe_image_url"] = images_list[1]
                        #category
                        category = driver.find_element_by_tag_name('h2').text
                        recipe_dict["category"] = category
                        #extra_info
                        more_info = driver.find_elements_by_xpath('(/html/body/form/main/article/div[1]/div[2]/div[2]/div/div/div/span)')
                        more_info_list = [info.text for info in more_info]
                        recipe_dict["more_info"] = more_info_list
                        #steps
                        steps = driver.find_elements_by_xpath('(/html/body/form/main/article/div[2]/div/div[3]/div[2]/div/figure/figcaption/div)')
                        steps_list = [step.text for step in steps]
                        recipe_dict["recipe_steps"] = steps_list
                        #recipe_list append
                        recipes_list.append(recipe_dict)
                        driver.back()
                        time.sleep(2)
                    print(f"{category} finished")
                    break
                else:
                    recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                    for x in np.arange(len(recipe_sumup_scrap)):
                        recipe_dict = {}
                        time.sleep(2)
                        recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                        driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
                        time.sleep(3)
                        #recipe name
                        recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
                        #ingredients
                        ingredients_list = []
                        quantity_list = []
                        recipe_ingred = driver.find_elements_by_tag_name('td')
                        for x in np.arange(len(recipe_ingred)):
                            if x % 2 != 0:
                                ingredients_list.append(recipe_ingred[x].text)
                            else:
                                quantity_list.append(recipe_ingred[x].text)
                        recipe_dict["ingredients"] = ingredients_list
                        recipe_dict["ingred_quantity"] = quantity_list
                        #time_preparation and calories
                        time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
                        try:
                            recipe_dict["time_preparation"] = time_calor_scrap[1].text
                        except:
                            pass
                        #calories
                        try:
                            recipe_dict["calories"] = time_calor_scrap[2].text
                        except:
                            pass
                        #intolerances
                        try:
                            intolerances = driver.find_elements_by_class_name("intolerances-item")
                            intolerances_list = [intolerance.text for intolerance in intolerances]
                            recipe_dict["intolerances"] = intolerances_list
                        except:
                            recipe_dict["intolerances"] = None
                        #recipe_url
                        recipe_dict["recipe_url"] = driver.current_url
                        #images_url
                        images = driver.find_elements_by_tag_name('img')
                        images_list = [image.get_attribute('src') for image in images]
                        recipe_dict["recipe_image_url"] = images_list[1]
                        #category
                        category = driver.find_element_by_tag_name('h2').text
                        recipe_dict["category"] = category
                        #extra_info
                        more_info = driver.find_elements_by_xpath('(/html/body/form/main/article/div[1]/div[2]/div[2]/div/div/div/span)')
                        more_info_list = [info.text for info in more_info]
                        recipe_dict["more_info"] = more_info_list
                        #steps
                        steps = driver.find_elements_by_xpath('(/html/body/form/main/article/div[2]/div/div[3]/div[2]/div/figure/figcaption/div)')
                        steps_list = [step.text for step in steps]
                        recipe_dict["recipe_steps"] = steps_list
                        #recipe_list append
                        recipes_list.append(recipe_dict)
                        driver.back()
                        time.sleep(2)
                    next_page_btn = driver.find_elements_by_css_selector(".next [href]")
                    driver.execute_script("arguments[0].click()", next_page_btn[0])
                    time.sleep(2)
            main_page = driver.find_elements_by_css_selector(".left [href]")
            driver.execute_script("arguments[0].click()", main_page[1])
            time.sleep(2)
        elif current_link == "https://www.lecturas.com/recetas/sopa-clasica-cebolla-gratinada-horno_4605.html":
            next_page = "https://www.lecturas.com/recetas/sopas-cremas?_page=8"
            driver.get(next_page)
            driver.set_page_load_timeout(10)
            while True:
                next_page_btn = driver.find_elements_by_class_name('next')
                if len(next_page_btn) < 1:
                    recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                    for x in np.arange(len(recipe_sumup_scrap)):
                        recipe_dict = {}
                        time.sleep(2)
                        recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                        driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
                        time.sleep(3)
                        #recipe name
                        recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
                        #ingredients
                        ingredients_list = []
                        quantity_list = []
                        recipe_ingred = driver.find_elements_by_tag_name('td')
                        for x in np.arange(len(recipe_ingred)):
                            if x % 2 != 0:
                                ingredients_list.append(recipe_ingred[x].text)
                            else:
                                quantity_list.append(recipe_ingred[x].text)
                        recipe_dict["ingredients"] = ingredients_list
                        recipe_dict["ingred_quantity"] = quantity_list
                        #time_preparation and calories
                        time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
                        try:
                            recipe_dict["time_preparation"] = time_calor_scrap[1].text
                        except:
                            pass
                        #calories
                        try:
                            recipe_dict["calories"] = time_calor_scrap[2].text
                        except:
                            pass
                        #intolerances
                        try:
                            intolerances = driver.find_elements_by_class_name("intolerances-item")
                            intolerances_list = [intolerance.text for intolerance in intolerances]
                            recipe_dict["intolerances"] = intolerances_list
                        except:
                            recipe_dict["intolerances"] = None
                        #recipe_url
                        recipe_dict["recipe_url"] = driver.current_url
                        #images_url
                        images = driver.find_elements_by_tag_name('img')
                        images_list = [image.get_attribute('src') for image in images]
                        recipe_dict["recipe_image_url"] = images_list[1]
                        #category
                        category = driver.find_element_by_tag_name('h2').text
                        recipe_dict["category"] = category
                        #extra_info
                        more_info = driver.find_elements_by_xpath('(/html/body/form/main/article/div[1]/div[2]/div[2]/div/div/div/span)')
                        more_info_list = [info.text for info in more_info]
                        recipe_dict["more_info"] = more_info_list
                        #steps
                        steps = driver.find_elements_by_xpath('(/html/body/form/main/article/div[2]/div/div[3]/div[2]/div/figure/figcaption/div)')
                        steps_list = [step.text for step in steps]
                        recipe_dict["recipe_steps"] = steps_list
                        #recipe_list append
                        recipes_list.append(recipe_dict)
                        driver.back()
                        time.sleep(2)
                    print(f"{category} finished")
                    break
                else:
                    recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                    for x in np.arange(len(recipe_sumup_scrap)):
                        recipe_dict = {}
                        time.sleep(2)
                        recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                        driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
                        time.sleep(3)
                        #recipe name
                        recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
                        #ingredients
                        ingredients_list = []
                        quantity_list = []
                        recipe_ingred = driver.find_elements_by_tag_name('td')
                        for x in np.arange(len(recipe_ingred)):
                            if x % 2 != 0:
                                ingredients_list.append(recipe_ingred[x].text)
                            else:
                                quantity_list.append(recipe_ingred[x].text)
                        recipe_dict["ingredients"] = ingredients_list
                        recipe_dict["ingred_quantity"] = quantity_list
                        #time_preparation and calories
                        time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
                        try:
                            recipe_dict["time_preparation"] = time_calor_scrap[1].text
                        except:
                            pass
                        #calories
                        try:
                            recipe_dict["calories"] = time_calor_scrap[2].text
                        except:
                            pass
                        #intolerances
                        try:
                            intolerances = driver.find_elements_by_class_name("intolerances-item")
                            intolerances_list = [intolerance.text for intolerance in intolerances]
                            recipe_dict["intolerances"] = intolerances_list
                        except:
                            recipe_dict["intolerances"] = None
                        #recipe_url
                        recipe_dict["recipe_url"] = driver.current_url
                        #images_url
                        images = driver.find_elements_by_tag_name('img')
                        images_list = [image.get_attribute('src') for image in images]
                        recipe_dict["recipe_image_url"] = images_list[1]
                        #category
                        category = driver.find_element_by_tag_name('h2').text
                        recipe_dict["category"] = category
                        #extra_info
                        more_info = driver.find_elements_by_xpath('(/html/body/form/main/article/div[1]/div[2]/div[2]/div/div/div/span)')
                        more_info_list = [info.text for info in more_info]
                        recipe_dict["more_info"] = more_info_list
                        #steps
                        steps = driver.find_elements_by_xpath('(/html/body/form/main/article/div[2]/div/div[3]/div[2]/div/figure/figcaption/div)')
                        steps_list = [step.text for step in steps]
                        recipe_dict["recipe_steps"] = steps_list
                        #recipe_list append
                        recipes_list.append(recipe_dict)
                        driver.back()
                        time.sleep(2)
                    next_page_btn = driver.find_elements_by_css_selector(".next [href]")
                    driver.execute_script("arguments[0].click()", next_page_btn[0])
                    time.sleep(2)
            main_page = driver.find_elements_by_css_selector(".left [href]")
            driver.execute_script("arguments[0].click()", main_page[1])
            time.sleep(2)
        else:
            print(f"TimeoutError at {current_link}")
            driver.get(current_link)
            driver.set_page_load_timeout(10)
            try:
                while True:
                    next_page_btn = driver.find_elements_by_class_name('next')
                    if len(next_page_btn) < 1:
                        recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                        for x in np.arange(len(recipe_sumup_scrap)):
                            recipe_dict = {}
                            time.sleep(2)
                            recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                            driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
                            time.sleep(3)
                            #recipe name
                            recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
                            #ingredients
                            ingredients_list = []
                            quantity_list = []
                            recipe_ingred = driver.find_elements_by_tag_name('td')
                            for x in np.arange(len(recipe_ingred)):
                                if x % 2 != 0:
                                    ingredients_list.append(recipe_ingred[x].text)
                                else:
                                    quantity_list.append(recipe_ingred[x].text)
                            recipe_dict["ingredients"] = ingredients_list
                            recipe_dict["ingred_quantity"] = quantity_list
                            #time_preparation and calories
                            time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
                            try:
                                recipe_dict["time_preparation"] = time_calor_scrap[1].text
                            except:
                                pass
                            #calories
                            try:
                                recipe_dict["calories"] = time_calor_scrap[2].text
                            except:
                                pass
                            #intolerances
                            try:
                                intolerances = driver.find_elements_by_class_name("intolerances-item")
                                intolerances_list = [intolerance.text for intolerance in intolerances]
                                recipe_dict["intolerances"] = intolerances_list
                            except:
                                recipe_dict["intolerances"] = None
                            #recipe_url
                            recipe_dict["recipe_url"] = driver.current_url
                            #images_url
                            images = driver.find_elements_by_tag_name('img')
                            images_list = [image.get_attribute('src') for image in images]
                            recipe_dict["recipe_image_url"] = images_list[1]
                            #category
                            category = driver.find_element_by_tag_name('h2').text
                            recipe_dict["category"] = category
                            #extra_info
                            more_info = driver.find_elements_by_xpath('(/html/body/form/main/article/div[1]/div[2]/div[2]/div/div/div/span)')
                            more_info_list = [info.text for info in more_info]
                            recipe_dict["more_info"] = more_info_list
                            #steps
                            steps = driver.find_elements_by_xpath('(/html/body/form/main/article/div[2]/div/div[3]/div[2]/div/figure/figcaption/div)')
                            steps_list = [step.text for step in steps]
                            recipe_dict["recipe_steps"] = steps_list
                            #recipe_list append
                            recipes_list.append(recipe_dict)
                            driver.back()
                            time.sleep(2)
                        print(f"{category} finished")
                        break
                    else:
                        recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                        for x in np.arange(len(recipe_sumup_scrap)):
                            recipe_dict = {}
                            time.sleep(2)
                            recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                            driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
                            time.sleep(3)
                            #recipe name
                            recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
                            #ingredients
                            ingredients_list = []
                            quantity_list = []
                            recipe_ingred = driver.find_elements_by_tag_name('td')
                            for x in np.arange(len(recipe_ingred)):
                                if x % 2 != 0:
                                    ingredients_list.append(recipe_ingred[x].text)
                                else:
                                    quantity_list.append(recipe_ingred[x].text)
                            recipe_dict["ingredients"] = ingredients_list
                            recipe_dict["ingred_quantity"] = quantity_list
                            #time_preparation and calories
                            time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
                            try:
                                recipe_dict["time_preparation"] = time_calor_scrap[1].text
                            except:
                                pass
                            #calories
                            try:
                                recipe_dict["calories"] = time_calor_scrap[2].text
                            except:
                                pass
                            #intolerances
                            try:
                                intolerances = driver.find_elements_by_class_name("intolerances-item")
                                intolerances_list = [intolerance.text for intolerance in intolerances]
                                recipe_dict["intolerances"] = intolerances_list
                            except:
                                recipe_dict["intolerances"] = None
                            #recipe_url
                            recipe_dict["recipe_url"] = driver.current_url
                            #images_url
                            images = driver.find_elements_by_tag_name('img')
                            images_list = [image.get_attribute('src') for image in images]
                            recipe_dict["recipe_image_url"] = images_list[1]
                            #category
                            category = driver.find_element_by_tag_name('h2').text
                            recipe_dict["category"] = category
                            #extra_info
                            more_info = driver.find_elements_by_xpath('(/html/body/form/main/article/div[1]/div[2]/div[2]/div/div/div/span)')
                            more_info_list = [info.text for info in more_info]
                            recipe_dict["more_info"] = more_info_list
                            #steps
                            steps = driver.find_elements_by_xpath('(/html/body/form/main/article/div[2]/div/div[3]/div[2]/div/figure/figcaption/div)')
                            steps_list = [step.text for step in steps]
                            recipe_dict["recipe_steps"] = steps_list
                            #recipe_list append
                            recipes_list.append(recipe_dict)
                            driver.back()
                            time.sleep(2)
                        next_page_btn = driver.find_elements_by_css_selector(".next [href]")
                        driver.execute_script("arguments[0].click()", next_page_btn[0])
                        time.sleep(2)
                main_page = driver.find_elements_by_css_selector(".left [href]")
                driver.execute_script("arguments[0].click()", main_page[1])
                time.sleep(2)
            except:
                driver.back()
                driver.set_page_load_timeout(10)
                time.sleep(2)
                while True:
                    next_page_btn = driver.find_elements_by_class_name('next')
                    if len(next_page_btn) < 1:
                        recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                        for x in np.arange(len(recipe_sumup_scrap)):
                            recipe_dict = {}
                            time.sleep(2)
                            recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                            driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
                            time.sleep(3)
                            #recipe name
                            recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
                            #ingredients
                            ingredients_list = []
                            quantity_list = []
                            recipe_ingred = driver.find_elements_by_tag_name('td')
                            for x in np.arange(len(recipe_ingred)):
                                if x % 2 != 0:
                                    ingredients_list.append(recipe_ingred[x].text)
                                else:
                                    quantity_list.append(recipe_ingred[x].text)
                            recipe_dict["ingredients"] = ingredients_list
                            recipe_dict["ingred_quantity"] = quantity_list
                            #time_preparation and calories
                            time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
                            try:
                                recipe_dict["time_preparation"] = time_calor_scrap[1].text
                            except:
                                pass
                            #calories
                            try:
                                recipe_dict["calories"] = time_calor_scrap[2].text
                            except:
                                pass
                            #intolerances
                            try:
                                intolerances = driver.find_elements_by_class_name("intolerances-item")
                                intolerances_list = [intolerance.text for intolerance in intolerances]
                                recipe_dict["intolerances"] = intolerances_list
                            except:
                                recipe_dict["intolerances"] = None
                            #recipe_url
                            recipe_dict["recipe_url"] = driver.current_url
                            #images_url
                            images = driver.find_elements_by_tag_name('img')
                            images_list = [image.get_attribute('src') for image in images]
                            recipe_dict["recipe_image_url"] = images_list[1]
                            #category
                            category = driver.find_element_by_tag_name('h2').text
                            recipe_dict["category"] = category
                            #extra_info
                            more_info = driver.find_elements_by_xpath('(/html/body/form/main/article/div[1]/div[2]/div[2]/div/div/div/span)')
                            more_info_list = [info.text for info in more_info]
                            recipe_dict["more_info"] = more_info_list
                            #steps
                            steps = driver.find_elements_by_xpath('(/html/body/form/main/article/div[2]/div/div[3]/div[2]/div/figure/figcaption/div)')
                            steps_list = [step.text for step in steps]
                            recipe_dict["recipe_steps"] = steps_list
                            #recipe_list append
                            recipes_list.append(recipe_dict)
                            driver.back()
                            time.sleep(2)
                        print(f"{category} finished")
                        break
                    else:
                        recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                        for x in np.arange(len(recipe_sumup_scrap)-1):
                            recipe_dict = {}
                            time.sleep(2)
                            recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                            driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
                            time.sleep(3)
                            #recipe name
                            recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
                            #ingredients
                            ingredients_list = []
                            quantity_list = []
                            recipe_ingred = driver.find_elements_by_tag_name('td')
                            for x in np.arange(len(recipe_ingred)):
                                if x % 2 != 0:
                                    ingredients_list.append(recipe_ingred[x].text)
                                else:
                                    quantity_list.append(recipe_ingred[x].text)
                            recipe_dict["ingredients"] = ingredients_list
                            recipe_dict["ingred_quantity"] = quantity_list
                            #time_preparation and calories
                            time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
                            try:
                                recipe_dict["time_preparation"] = time_calor_scrap[1].text
                            except:
                                pass
                            #calories
                            try:
                                recipe_dict["calories"] = time_calor_scrap[2].text
                            except:
                                pass
                            #intolerances
                            try:
                                intolerances = driver.find_elements_by_class_name("intolerances-item")
                                intolerances_list = [intolerance.text for intolerance in intolerances]
                                recipe_dict["intolerances"] = intolerances_list
                            except:
                                recipe_dict["intolerances"] = None
                            #recipe_url
                            recipe_dict["recipe_url"] = driver.current_url
                            #images_url
                            images = driver.find_elements_by_tag_name('img')
                            images_list = [image.get_attribute('src') for image in images]
                            recipe_dict["recipe_image_url"] = images_list[1]
                            #category
                            category = driver.find_element_by_tag_name('h2').text
                            recipe_dict["category"] = category
                            #extra_info
                            more_info = driver.find_elements_by_xpath('(/html/body/form/main/article/div[1]/div[2]/div[2]/div/div/div/span)')
                            more_info_list = [info.text for info in more_info]
                            recipe_dict["more_info"] = more_info_list
                            #steps
                            steps = driver.find_elements_by_xpath('(/html/body/form/main/article/div[2]/div/div[3]/div[2]/div/figure/figcaption/div)')
                            steps_list = [step.text for step in steps]
                            recipe_dict["recipe_steps"] = steps_list
                            #recipe_list append
                            recipes_list.append(recipe_dict)
                            driver.back()
                            time.sleep(2)
                        next_page_btn = driver.find_elements_by_css_selector(".next [href]")
                        driver.execute_script("arguments[0].click()", next_page_btn[0])
                        time.sleep(2)
                main_page = driver.find_elements_by_css_selector(".left [href]")
                driver.execute_script("arguments[0].click()", main_page[1])
                time.sleep(2)
    else:
        current_link = driver.current_url
        print(f"check if error at {current_link}")
        pass

# %%
df_recipes = pd.DataFrame(recipes_list)

df_recipes
# Out:
#                                       recipe_name  \
# 0                                Ensalada niçoise
# 1                           Ensalada del périgord
# 2                          Xató con salsa romesco
# 3    Ensalada de ceviche de langostinos y cebolla
# 4          Ensalada de pollo, remolacha y manzana
# ..                                            ...
# 479                   Crema y cubitos de verduras
# 480                               Sopa de cebolla
# 481                 Chupitos de crema de coliflor
# 482                    Sopa minestrone con fideos
# 483           Sopa bullabesa de pescado y marisco
#
#                                            ingredients time_preparation  \
# 0    [patatas pequeñas rojas, huevos, judías verdes...           60 min
# 1    [foie micuit, beicon gruesas, champiñones, ber...           25 min
# 2    [bacalao desalado, cebolleta, escarolas, aceit...           35 min
# 3    [langostinos, pimienta, limas, tomates, ceboll...           25 min
# 4    [pechugas de pollo, manzanas ácida, col lombar...           40 min
# ..                                                 ...              ...
# 479  [zanahorias, calabaza, puerros, cebollas, apio...           60 min
# 480  [cebollas blancas o dulces, caldo de pollo o d...           60 min
# 481  [coliflor, nata líquida, seta variadas, pereji...           25 min
# 482  [cebolla, apios, zanahorias, judías verdes, di...           45 min
# 483  [colas de rape, salmonetes enteros, colas de g...           60 min
#
#     calories intolerances                                         recipe_url  \
# 0    252 Cal           []  https://www.lecturas.com/recetas/ensalada-nico...
# 1    386 Cal           []  https://www.lecturas.com/recetas/ensalada-peri...
# 2        NaN           []  https://www.lecturas.com/recetas/xato-salsa-ro...
# 3    176 Cal           []  https://www.lecturas.com/recetas/ensalada-cevi...
# 4    203 Cal           []  https://www.lecturas.com/recetas/ensalada-poll...
# ..       ...          ...                                                ...
# 479      NaN           []  https://www.lecturas.com/recetas/crema-y-cubit...
# 480  223 Cal           []  https://www.lecturas.com/recetas/sopa-cebolla_...
# 481   64 Cal           []  https://www.lecturas.com/recetas/chupitos-crem...
# 482  124 Cal           []  https://www.lecturas.com/recetas/sopa-minestro...
# 483  435 Cal           []  https://www.lecturas.com/recetas/sopa-bullabes...
#
#                                       recipe_image_url        category  \
# 0    https://content-recetas.lecturas.com/medio/201...       ENSALADAS
# 1    https://content-recetas.lecturas.com/medio/201...       ENSALADAS
# 2    https://content-recetas.lecturas.com/medio/202...       ENSALADAS
# 3    https://content-recetas.lecturas.com/medio/201...       ENSALADAS
# 4    https://content-recetas.lecturas.com/medio/201...       ENSALADAS
# ..                                                 ...             ...
# 479  https://content-recetas.lecturas.com/medio/201...  SOPAS Y CREMAS
# 480  https://content-recetas.lecturas.com/medio/201...  SOPAS Y CREMAS
# 481  https://content-recetas.lecturas.com/medio/201...  SOPAS Y CREMAS
# 482  https://content-recetas.lecturas.com/medio/201...  SOPAS Y CREMAS
# 483  https://content-recetas.lecturas.com/medio/201...  SOPAS Y CREMAS
#
#                                              more_info
# 0    [<selenium.webdriver.remote.webelement.WebElem...
# 1    [<selenium.webdriver.remote.webelement.WebElem...
# 2    [<selenium.webdriver.remote.webelement.WebElem...
# 3    [<selenium.webdriver.remote.webelement.WebElem...
# 4    [<selenium.webdriver.remote.webelement.WebElem...
# ..                                                 ...
# 479  [<selenium.webdriver.remote.webelement.WebElem...
# 480  [<selenium.webdriver.remote.webelement.WebElem...
# 481  [<selenium.webdriver.remote.webelement.WebElem...
# 482  [<selenium.webdriver.remote.webelement.WebElem...
# 483  [<selenium.webdriver.remote.webelement.WebElem...
#
# [484 rows x 9 columns]

# %%
with open('../data/raw/web_scraping_recipes_new.json', 'w') as json_file:
    json.dump(recipes_list, json_file)
