# %%
from selenium import webdriver
from selenium.common.exceptions import TimeoutException
import time
import numpy as np
import pandas as pd
import json

# Opening the Chrome and going to the Web

recipe_link = 'https://www.lecturas.com/recetas/'
chromedriver = "/home/veronica/Ironhack/Final Project/Chrome Driver/chromedriver"
driver = webdriver.Chrome(chromedriver)
driver.get(recipe_link)


# Enabling cookies

time.sleep(3)
element = driver.find_elements_by_class_name('qc-cmp-button')
element[1].click()


# Selecting cat

time.sleep(3)
categories = driver.find_elements_by_tag_name('h4')


# Looping throught the categories

recipes_list = []
driver.set_page_load_timeout(10)

for x in np.arange(len(categories)-1):
    time.sleep(3)
    categories = driver.find_elements_by_tag_name('h4')
    category = categories[x].text
    try:
        categories = driver.find_elements_by_tag_name('h4')
        driver.execute_script("arguments[0].click()", categories[x])
        #category = categories[x].text
        time.sleep(2)
        while True:
            next_page_btn = driver.find_elements_by_class_name('next')
            if len(next_page_btn) < 1:
                recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                for x in np.arange(len(recipe_sumup_scrap)-1):
                    recipe_dict = {}
                    time.sleep(2)
                    recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                    driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
                    time.sleep(3)
                    #recipe name
                    recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
                    #ingredients
                    ingredients_list = []
                    recipe_ingred = driver.find_elements_by_tag_name('td')
                    for x in np.arange(len(recipe_ingred)):
                        if x % 2 != 0:
                            ingredients_list.append(recipe_ingred[x].text)
                        else:
                            pass
                    recipe_dict["ingredients"] = ingredients_list
                    #time_preparation and calories
                    time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
                    try:
                        recipe_dict["time_preparation"] = time_calor_scrap[1].text
                    except:
                        pass
                    #calories
                    try:
                        recipe_dict["calories"] = time_calor_scrap[2].text
                    except:
                        pass
                    #intolerances
                    try:
                        intolerances = driver.find_elements_by_class_name("intolerances-item")
                        intolerances_list = [intolerance.text for intolerance in intolerances]
                        recipe_dict["intolerances"] = intolerances_list
                    except:
                        recipe_dict["intolerances"] = None
                    #recipe_url
                    recipe_dict["recipe_url"] = driver.current_url
                    #images_url
                    images = driver.find_elements_by_tag_name('img')
                    images_list = [image.get_attribute('src') for image in images]
                    recipe_image_url = images_list[1]
                    recipe_dict["recipe_image_url"] = images_list[1]
                    #category
                    recipe_dict["category"] = category
                    #recipe_list append
                    recipes_list.append(recipe_dict)
                    driver.back()
                    time.sleep(2)
                print("No more pages left")
                break
            else:
                recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                for x in np.arange(len(recipe_sumup_scrap)-1):
                    recipe_dict = {}
                    time.sleep(2)
                    recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                    driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
                    time.sleep(3)
                    #recipe name
                    recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
                    #ingredients
                    ingredients_list = []
                    recipe_ingred = driver.find_elements_by_tag_name('td')
                    for x in np.arange(len(recipe_ingred)):
                        if x % 2 != 0:
                            ingredients_list.append(recipe_ingred[x].text)
                        else:
                            pass
                    recipe_dict["ingredients"] = ingredients_list
                    #time_preparation and calories
                    time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
                    try:
                        recipe_dict["time_preparation"] = time_calor_scrap[1].text
                    except:
                        pass
                    #calories
                    try:
                        recipe_dict["calories"] = time_calor_scrap[2].text
                    except:
                        pass
                    #intolerances
                    try:
                        intolerances = driver.find_elements_by_class_name("intolerances-item")
                        intolerances_list = [intolerance.text for intolerance in intolerances]
                        recipe_dict["intolerances"] = intolerances_list
                    except:
                        recipe_dict["intolerances"] = None
                    #recipe_url
                    recipe_dict["recipe_url"] = driver.current_url
                    #images_url
                    images = driver.find_elements_by_tag_name('img')
                    images_list = [image.get_attribute('src') for image in images]
                    recipe_image_url = images_list[1]
                    recipe_dict["recipe_image_url"] = images_list[1]
                    #category
                    recipe_dict["category"] = category
                    #recipe_list append
                    recipes_list.append(recipe_dict)
                    driver.back()
                    time.sleep(2)
                next_page_btn = driver.find_elements_by_css_selector(".next [href]")
                driver.execute_script("arguments[0].click()", next_page_btn[0])
                time.sleep(2)
        main_page = driver.find_elements_by_css_selector(".left [href]")
        driver.execute_script("arguments[0].click()", main_page[1])
        time.sleep(2)
    except:
        current_link = driver.current_url 
        fail_link = "https://www.lecturas.com/recetas/postres-dulces?_page=15"
        if current_link == fail_link:
            next_page = "https://www.lecturas.com/recetas/postres-dulces?_page=16"
            driver.get(next_page)
            driver.set_page_load_timeout(10)
            while True:
                next_page_btn = driver.find_elements_by_class_name('next')
                if len(next_page_btn) < 1:
                    recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                    for x in np.arange(len(recipe_sumup_scrap)-1):
                        recipe_dict = {}
                        time.sleep(2)
                        recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                        driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
                        time.sleep(3)
                        #recipe name
                        recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
                        #ingredients
                        ingredients_list = []
                        recipe_ingred = driver.find_elements_by_tag_name('td')
                        for x in np.arange(len(recipe_ingred)):
                            if x % 2 != 0:
                                ingredients_list.append(recipe_ingred[x].text)
                            else:
                                pass
                        recipe_dict["ingredients"] = ingredients_list
                        #time_preparation and calories
                        time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
                        try:
                            recipe_dict["time_preparation"] = time_calor_scrap[1].text
                        except:
                            pass
                        #calories
                        try:
                            recipe_dict["calories"] = time_calor_scrap[2].text
                        except:
                            pass
                        #intolerances
                        try:
                            intolerances = driver.find_elements_by_class_name("intolerances-item")
                            intolerances_list = [intolerance.text for intolerance in intolerances]
                            recipe_dict["intolerances"] = intolerances_list
                        except:
                            recipe_dict["intolerances"] = None
                        #recipe_url
                        recipe_dict["recipe_url"] = driver.current_url
                        #images_url
                        images = driver.find_elements_by_tag_name('img')
                        images_list = [image.get_attribute('src') for image in images]
                        recipe_image_url = images_list[1]
                        recipe_dict["recipe_image_url"] = images_list[1]
                        #category
                        recipe_dict["category"] = category
                        #recipe_list append
                        recipes_list.append(recipe_dict)
                        driver.back()
                        time.sleep(2)
                    print("No more pages left")
                    break
                else:
                    recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                    for x in np.arange(len(recipe_sumup_scrap)-1):
                        recipe_dict = {}
                        time.sleep(2)
                        recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                        driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
                        time.sleep(3)
                        #recipe name
                        recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
                        #ingredients
                        ingredients_list = []
                        recipe_ingred = driver.find_elements_by_tag_name('td')
                        for x in np.arange(len(recipe_ingred)):
                            if x % 2 != 0:
                                ingredients_list.append(recipe_ingred[x].text)
                            else:
                                pass
                        recipe_dict["ingredients"] = ingredients_list
                        #time_preparation and calories
                        time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
                        try:
                            recipe_dict["time_preparation"] = time_calor_scrap[1].text
                        except:
                            pass
                        #calories
                        try:
                            recipe_dict["calories"] = time_calor_scrap[2].text
                        except:
                            pass
                        #intolerances
                        try:
                            intolerances = driver.find_elements_by_class_name("intolerances-item")
                            intolerances_list = [intolerance.text for intolerance in intolerances]
                            recipe_dict["intolerances"] = intolerances_list
                        except:
                            recipe_dict["intolerances"] = None
                        #recipe_url
                        recipe_dict["recipe_url"] = driver.current_url
                        #images_url
                        images = driver.find_elements_by_tag_name('img')
                        images_list = [image.get_attribute('src') for image in images]
                        recipe_image_url = images_list[1]
                        recipe_dict["recipe_image_url"] = images_list[1]
                        #category
                        recipe_dict["category"] = category
                        #recipe_list append
                        recipes_list.append(recipe_dict)
                        driver.back()
                        time.sleep(2)
                    next_page_btn = driver.find_elements_by_css_selector(".next [href]")
                    driver.execute_script("arguments[0].click()", next_page_btn[0])
                    time.sleep(2)
            main_page = driver.find_elements_by_css_selector(".left [href]")
            driver.execute_script("arguments[0].click()", main_page[1])
            time.sleep(2)
            
        else:
            print(f"TimeoutError at {current_link}")
            driver.get(current_link)
            driver.set_page_load_timeout(10)
            try:
                while True:
                    next_page_btn = driver.find_elements_by_class_name('next')
                    if len(next_page_btn) < 1:
                        recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                        for x in np.arange(len(recipe_sumup_scrap)-1):
                            recipe_dict = {}
                            time.sleep(2)
                            recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                            driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
                            time.sleep(3)
                            #recipe name
                            recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
                            #ingredients
                            ingredients_list = []
                            recipe_ingred = driver.find_elements_by_tag_name('td')
                            for x in np.arange(len(recipe_ingred)):
                                if x % 2 != 0:
                                    ingredients_list.append(recipe_ingred[x].text)
                                else:
                                    pass
                            recipe_dict["ingredients"] = ingredients_list
                            #time_preparation and calories
                            time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
                            try:
                                recipe_dict["time_preparation"] = time_calor_scrap[1].text
                            except:
                                pass
                            #calories
                            try:
                                recipe_dict["calories"] = time_calor_scrap[2].text
                            except:
                                pass
                            #intolerances
                            try:
                                intolerances = driver.find_elements_by_class_name("intolerances-item")
                                intolerances_list = [intolerance.text for intolerance in intolerances]
                                recipe_dict["intolerances"] = intolerances_list
                            except:
                                recipe_dict["intolerances"] = None
                            #recipe_url
                            recipe_dict["recipe_url"] = driver.current_url
                            #images_url
                            images = driver.find_elements_by_tag_name('img')
                            images_list = [image.get_attribute('src') for image in images]
                            recipe_image_url = images_list[1]
                            recipe_dict["recipe_image_url"] = images_list[1]
                            #category
                            recipe_dict["category"] = category
                            #recipe_list append
                            recipes_list.append(recipe_dict)
                            driver.back()
                            time.sleep(2)
                        print("No more pages left")
                        break
                    else:
                        recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                        for x in np.arange(len(recipe_sumup_scrap)):
                            recipe_dict = {}
                            time.sleep(2)
                            recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                            driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
                            time.sleep(3)
                            #recipe name
                            recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
                            #ingredients
                            ingredients_list = []
                            recipe_ingred = driver.find_elements_by_tag_name('td')
                            for x in np.arange(len(recipe_ingred)):
                                if x % 2 != 0:
                                    ingredients_list.append(recipe_ingred[x].text)
                                else:
                                    pass
                            recipe_dict["ingredients"] = ingredients_list
                            #time_preparation and calories
                            time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
                            try:
                                recipe_dict["time_preparation"] = time_calor_scrap[1].text
                            except:
                                pass
                            #calories
                            try:
                                recipe_dict["calories"] = time_calor_scrap[2].text
                            except:
                                pass
                            #intolerances
                            try:
                                intolerances = driver.find_elements_by_class_name("intolerances-item")
                                intolerances_list = [intolerance.text for intolerance in intolerances]
                                recipe_dict["intolerances"] = intolerances_list
                            except:
                                recipe_dict["intolerances"] = None
                            #recipe_url
                            recipe_dict["recipe_url"] = driver.current_url
                            #images_url
                            images = driver.find_elements_by_tag_name('img')
                            images_list = [image.get_attribute('src') for image in images]
                            recipe_image_url = images_list[1]
                            recipe_dict["recipe_image_url"] = images_list[1]
                            #category
                            recipe_dict["category"] = category
                            #recipe_list append
                            recipes_list.append(recipe_dict)
                            driver.back()
                            time.sleep(2)
                        next_page_btn = driver.find_elements_by_css_selector(".next [href]")
                        driver.execute_script("arguments[0].click()", next_page_btn[0])
                        time.sleep(2)
                main_page = driver.find_elements_by_css_selector(".left [href]")
                driver.execute_script("arguments[0].click()", main_page[1])
                time.sleep(2)
            except:
                driver.back()
                driver.set_page_load_timeout(10)
                time.sleep(2)
                while True:
                    next_page_btn = driver.find_elements_by_class_name('next')
                    if len(next_page_btn) < 1:
                        recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                        for x in np.arange(len(recipe_sumup_scrap)-1):
                            recipe_dict = {}
                            time.sleep(2)
                            recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                            driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
                            time.sleep(3)
                            #recipe name
                            recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
                            #ingredients
                            ingredients_list = []
                            recipe_ingred = driver.find_elements_by_tag_name('td')
                            for x in np.arange(len(recipe_ingred)):
                                if x % 2 != 0:
                                    ingredients_list.append(recipe_ingred[x].text)
                                else:
                                    pass
                            recipe_dict["ingredients"] = ingredients_list
                            #time_preparation and calories
                            time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
                            try:
                                recipe_dict["time_preparation"] = time_calor_scrap[1].text
                            except:
                                pass
                            #calories
                            try:
                                recipe_dict["calories"] = time_calor_scrap[2].text
                            except:
                                pass
                            #intolerances
                            try:
                                intolerances = driver.find_elements_by_class_name("intolerances-item")
                                intolerances_list = [intolerance.text for intolerance in intolerances]
                                recipe_dict["intolerances"] = intolerances_list
                            except:
                                recipe_dict["intolerances"] = None
                            #recipe_url
                            recipe_dict["recipe_url"] = driver.current_url
                            #images_url
                            images = driver.find_elements_by_tag_name('img')
                            images_list = [image.get_attribute('src') for image in images]
                            recipe_image_url = images_list[1]
                            recipe_dict["recipe_image_url"] = images_list[1]
                            #category
                            recipe_dict["category"] = category
                            #recipe_list append
                            recipes_list.append(recipe_dict)
                            driver.back()
                            time.sleep(2)
                        print("No more pages left")
                        break
                    else:
                        recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                        for x in np.arange(len(recipe_sumup_scrap)-1):
                            recipe_dict = {}
                            time.sleep(2)
                            recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                            driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
                            time.sleep(3)
                            #recipe name
                            recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
                            #ingredients
                            ingredients_list = []
                            recipe_ingred = driver.find_elements_by_tag_name('td')
                            for x in np.arange(len(recipe_ingred)):
                                if x % 2 != 0:
                                    ingredients_list.append(recipe_ingred[x].text)
                                else:
                                    pass
                            recipe_dict["ingredients"] = ingredients_list
                            #time_preparation and calories
                            time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
                            try:
                                recipe_dict["time_preparation"] = time_calor_scrap[1].text
                            except:
                                pass
                            #calories
                            try:
                                recipe_dict["calories"] = time_calor_scrap[2].text
                            except:
                                pass
                            #intolerances
                            try:
                                intolerances = driver.find_elements_by_class_name("intolerances-item")
                                intolerances_list = [intolerance.text for intolerance in intolerances]
                                recipe_dict["intolerances"] = intolerances_list
                            except:
                                recipe_dict["intolerances"] = None
                            #recipe_url
                            recipe_dict["recipe_url"] = driver.current_url
                            #images_url
                            images = driver.find_elements_by_tag_name('img')
                            images_list = [image.get_attribute('src') for image in images]
                            recipe_image_url = images_list[1]
                            recipe_dict["recipe_image_url"] = images_list[1]
                            #category
                            recipe_dict["category"] = category
                            #recipe_list append
                            recipes_list.append(recipe_dict)
                            driver.back()
                            time.sleep(2)
                        next_page_btn = driver.find_elements_by_css_selector(".next [href]")
                        driver.execute_script("arguments[0].click()", next_page_btn[0])
                        time.sleep(2)
                main_page = driver.find_elements_by_css_selector(".left [href]")
                driver.execute_script("arguments[0].click()", main_page[1])
                time.sleep(2)
    else:
        pass
# Out:
# No more pages left
# No more pages left
# No more pages left
# No more pages left
# No more pages left
# No more pages left
# No more pages left
# No more pages left
# No more pages left
# No more pages left
# No more pages left
# No more pages left
# TimeoutError at https://www.lecturas.com/recetas/postres-dulces?_page=5
# No more pages left
# No more pages left
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# <ipython-input-1-d033de9f84c2> in <module>
#     102                     recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
# --> 103                     driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
#     104                     time.sleep(3)
#
# ~/miniconda3/envs/recipe_env/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute_script(self, script, *args)
#     635             'script': script,
# --> 636             'args': converted_args})['value']
#     637
#
# ~/miniconda3/envs/recipe_env/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#
# ~/miniconda3/envs/recipe_env/lib/python3.7/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# TimeoutException: Message: timeout: Timed out receiving message from renderer: -0,008
#   (Session info: chrome=80.0.3987.149)
#
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-1-d033de9f84c2> in <module>
#     383                 main_page = driver.find_elements_by_css_selector(".left [href]")
# --> 384                 driver.execute_script("arguments[0].click()", main_page[1])
#     385                 time.sleep(2)
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-1-d033de9f84c2> in <module>
#     496                         time.sleep(2)
#     497                 main_page = driver.find_elements_by_css_selector(".left [href]")
# --> 498                 driver.execute_script("arguments[0].click()", main_page[1])
#     499                 time.sleep(2)
#     500     else:
#
# IndexError: list index out of range

# %%
df_recipes = pd.DataFrame(recipes_list)

df_recipes
# Out:
#                                        recipe_name  \
# 0                                 Ensalada niçoise
# 1                            Ensalada del périgord
# 2                           Xató con salsa romesco
# 3     Ensalada de ceviche de langostinos y cebolla
# 4           Ensalada de pollo, remolacha y manzana
# ...                                            ...
# 3945                               Yemas glaseadas
# 3946                                   Hojaldrinas
# 3947       Tarta de queso con lunares de chocolate
# 3948                Pastelitos de nata y chocolate
# 3949                Tarta de chocolate con fondant
#
#                                             ingredients time_preparation  \
# 0     [patatas pequeñas rojas, huevos, judías verdes...           60 min
# 1     [foie micuit, beicon gruesas, champiñones, ber...           25 min
# 2     [bacalao desalado, cebolleta, escarolas, aceit...           35 min
# 3     [langostinos, pimienta, limas, tomates, ceboll...           25 min
# 4     [pechugas de pollo, manzanas ácida, col lombar...           40 min
# ...                                                 ...              ...
# 3945               [yema de huevo, azúcar, azúcar glas]           30 min
# 3946  [harina, manteca de cerdo, vino dulce blanco, ...           80 min
# 3947  [mantequilla, galletas de chocolate, queso bla...           90 min
# 3948  [galletas de chocolate, mantequilla, queso mas...           60 min
# 3949  [huevos, azúcar, harina, levadura, mantequilla...           90 min
#
#      calories                  intolerances  \
# 0     252 Cal                            []
# 1     386 Cal                            []
# 2         NaN                            []
# 3     176 Cal                            []
# 4     203 Cal                            []
# ...       ...                           ...
# 3945      NaN                            []
# 3946      NaN                   [Sin huevo]
# 3947      NaN                            []
# 3948      NaN  [Preparación con antelación]
# 3949      NaN                            []
#
#                                              recipe_url  \
# 0     https://www.lecturas.com/recetas/ensalada-nico...
# 1     https://www.lecturas.com/recetas/ensalada-peri...
# 2     https://www.lecturas.com/recetas/xato-salsa-ro...
# 3     https://www.lecturas.com/recetas/ensalada-cevi...
# 4     https://www.lecturas.com/recetas/ensalada-poll...
# ...                                                 ...
# 3945  https://www.lecturas.com/recetas/yemas-glasead...
# 3946  https://www.lecturas.com/recetas/hojaldrinas_6...
# 3947  https://www.lecturas.com/recetas/tarta-queso-l...
# 3948  https://www.lecturas.com/recetas/pastelitos-na...
# 3949  https://www.lecturas.com/recetas/tarta-chocola...
#
#                                        recipe_image_url          category
# 0     https://content-recetas.lecturas.com/medio/201...         Ensaladas
# 1     https://content-recetas.lecturas.com/medio/201...         Ensaladas
# 2     https://content-recetas.lecturas.com/medio/202...         Ensaladas
# 3     https://content-recetas.lecturas.com/medio/201...         Ensaladas
# 4     https://content-recetas.lecturas.com/medio/201...         Ensaladas
# ...                                                 ...               ...
# 3945  https://content-recetas.lecturas.com/medio/201...  Postres y dulces
# 3946  https://content-recetas.lecturas.com/medio/201...  Postres y dulces
# 3947  https://content-recetas.lecturas.com/medio/201...  Postres y dulces
# 3948  https://content-recetas.lecturas.com/medio/201...  Postres y dulces
# 3949  https://content-recetas.lecturas.com/medio/201...  Postres y dulces
#
# [3950 rows x 8 columns]

# %%
with open('../data/raw/web_scraping_recipes_3.json', 'w') as json_file:
    json.dump(recipes_list, json_file)
