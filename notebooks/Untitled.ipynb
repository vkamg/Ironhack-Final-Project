# %%
from selenium import webdriver
from selenium.common.exceptions import TimeoutException
import time
import numpy as np
import pandas as pd
import json

# Opening the Chrome and going to the Web

recipe_link = 'https://www.lecturas.com/recetas/'
chromedriver = "/home/veronica/Ironhack/Final Project/Chrome Driver/chromedriver"
driver = webdriver.Chrome(chromedriver)
driver.get(recipe_link)


# Enabling cookies

time.sleep(3)
element = driver.find_elements_by_class_name('qc-cmp-button')
element[1].click()


# Selecting cat

time.sleep(3)
categories = driver.find_elements_by_tag_name('h4')


# Looping throught the categories

recipes_list = []
driver.set_page_load_timeout(10)

for x in np.arange(len(categories)-1):
    try:
        categories = driver.find_elements_by_tag_name('h4')
        driver.execute_script("arguments[0].click()", categories[x])
        #category = categories[x].text
        time.sleep(2)
        while True:
            next_page_btn = driver.find_elements_by_class_name('next')
            if len(next_page_btn) < 1:
                recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                for x in np.arange(len(recipe_sumup_scrap)):
                    recipe_dict = {}
                    time.sleep(2)
                    recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                    driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
                    time.sleep(3)
                    #recipe name
                    recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
                    #ingredients
                    ingredients_list = []
                    quantity_list = []
                    recipe_ingred = driver.find_elements_by_tag_name('td')
                    for x in np.arange(len(recipe_ingred)):
                        if x % 2 != 0:
                            ingredients_list.append(recipe_ingred[x].text)
                        else:
                            quantity_list.append(recipe_ingred[x].text)
                    recipe_dict["ingredients"] = ingredients_list
                    recipe_dict["ingred_quantity"] = quantity_list
                    #time_preparation and calories
                    time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
                    try:
                        recipe_dict["time_preparation"] = time_calor_scrap[1].text
                    except:
                        pass
                    #calories
                    try:
                        recipe_dict["calories"] = time_calor_scrap[2].text
                    except:
                        pass
                    #intolerances
                    try:
                        intolerances = driver.find_elements_by_class_name("intolerances-item")
                        intolerances_list = [intolerance.text for intolerance in intolerances]
                        recipe_dict["intolerances"] = intolerances_list
                    except:
                        recipe_dict["intolerances"] = None
                    #recipe_url
                    recipe_dict["recipe_url"] = driver.current_url
                    #images_url
                    images = driver.find_elements_by_tag_name('img')
                    images_list = [image.get_attribute('src') for image in images]
                    recipe_dict["recipe_image_url"] = images_list[1]
                    #category
                    category = driver.find_element_by_tag_name('h2').text
                    recipe_dict["category"] = category
                    #extra_info
                    more_info = driver.find_elements_by_xpath('(/html/body/form/main/article/div[1]/div[2]/div[2]/div/div/div/span)')
                    more_info_list = [info.text for info in more_info]
                    recipe_dict["more_info"] = more_info_list
                    #steps
                    steps = driver.find_elements_by_xpath('(/html/body/form/main/article/div[2]/div/div[3]/div[2]/div/figure/figcaption/div/p)')
                    steps_list = [step.text for step in steps]
                    recipe_dict["recipe_steps"] = steps_list
                    #recipe_list append
                    recipes_list.append(recipe_dict)
                    driver.back()
                    time.sleep(2)
                print(f"{category} finished")
                break
            else:
                recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                for x in np.arange(len(recipe_sumup_scrap)):
                    recipe_dict = {}
                    time.sleep(2)
                    recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                    driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
                    time.sleep(3)
                    #recipe name
                    recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
                    #ingredients
                    ingredients_list = []
                    quantity_list = []
                    recipe_ingred = driver.find_elements_by_tag_name('td')
                    for x in np.arange(len(recipe_ingred)):
                        if x % 2 != 0:
                            ingredients_list.append(recipe_ingred[x].text)
                        else:
                            quantity_list.append(recipe_ingred[x].text)
                    recipe_dict["ingredients"] = ingredients_list
                    recipe_dict["ingred_quantity"] = quantity_list
                    #time_preparation and calories
                    time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
                    try:
                        recipe_dict["time_preparation"] = time_calor_scrap[1].text
                    except:
                        pass
                    #calories
                    try:
                        recipe_dict["calories"] = time_calor_scrap[2].text
                    except:
                        pass
                    #intolerances
                    try:
                        intolerances = driver.find_elements_by_class_name("intolerances-item")
                        intolerances_list = [intolerance.text for intolerance in intolerances]
                        recipe_dict["intolerances"] = intolerances_list
                    except:
                        recipe_dict["intolerances"] = None
                    #recipe_url
                    recipe_dict["recipe_url"] = driver.current_url
                    #images_url
                    images = driver.find_elements_by_tag_name('img')
                    images_list = [image.get_attribute('src') for image in images]
                    recipe_dict["recipe_image_url"] = images_list[1]
                    #category
                    category = driver.find_element_by_tag_name('h2').text
                    recipe_dict["category"] = category
                    #extra_info
                    more_info = driver.find_elements_by_xpath('(/html/body/form/main/article/div[1]/div[2]/div[2]/div/div/div/span)')
                    more_info_list = [info.text for info in more_info]
                    recipe_dict["more_info"] = more_info_list
                    #steps
                    steps = driver.find_elements_by_xpath('(/html/body/form/main/article/div[2]/div/div[3]/div[2]/div/figure/figcaption/div/p)')
                    steps_list = [step.text for step in steps]
                    recipe_dict["recipe_steps"] = steps_list
                    #recipe_list append
                    recipes_list.append(recipe_dict)
                    driver.back()
                    time.sleep(2)
                next_page_btn = driver.find_elements_by_css_selector(".next [href]")
                driver.execute_script("arguments[0].click()", next_page_btn[0])
                time.sleep(2)
        main_page = driver.find_elements_by_css_selector(".left [href]")
        driver.execute_script("arguments[0].click()", main_page[1])
        time.sleep(2)
    except:
        current_link = driver.current_url
        if current_link == "https://www.lecturas.com/recetas/postres-dulces?_page=15":
            next_page = "https://www.lecturas.com/recetas/postres-dulces?_page=16"
            driver.get(next_page)
            driver.set_page_load_timeout(10)
            while True:
                next_page_btn = driver.find_elements_by_class_name('next')
                if len(next_page_btn) < 1:
                    recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                    for x in np.arange(len(recipe_sumup_scrap)):
                        recipe_dict = {}
                        time.sleep(2)
                        recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                        driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
                        time.sleep(3)
                        #recipe name
                        recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
                        #ingredients
                        ingredients_list = []
                        quantity_list = []
                        recipe_ingred = driver.find_elements_by_tag_name('td')
                        for x in np.arange(len(recipe_ingred)):
                            if x % 2 != 0:
                                ingredients_list.append(recipe_ingred[x].text)
                            else:
                                quantity_list.append(recipe_ingred[x].text)
                        recipe_dict["ingredients"] = ingredients_list
                        recipe_dict["ingred_quantity"] = quantity_list
                        #time_preparation and calories
                        time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
                        try:
                            recipe_dict["time_preparation"] = time_calor_scrap[1].text
                        except:
                            pass
                        #calories
                        try:
                            recipe_dict["calories"] = time_calor_scrap[2].text
                        except:
                            pass
                        #intolerances
                        try:
                            intolerances = driver.find_elements_by_class_name("intolerances-item")
                            intolerances_list = [intolerance.text for intolerance in intolerances]
                            recipe_dict["intolerances"] = intolerances_list
                        except:
                            recipe_dict["intolerances"] = None
                        #recipe_url
                        recipe_dict["recipe_url"] = driver.current_url
                        #images_url
                        images = driver.find_elements_by_tag_name('img')
                        images_list = [image.get_attribute('src') for image in images]
                        recipe_dict["recipe_image_url"] = images_list[1]
                        #category
                        category = driver.find_element_by_tag_name('h2').text
                        recipe_dict["category"] = category
                        #extra_info
                        more_info = driver.find_elements_by_xpath('(/html/body/form/main/article/div[1]/div[2]/div[2]/div/div/div/span)')
                        more_info_list = [info.text for info in more_info]
                        recipe_dict["more_info"] = more_info_list
                        #steps
                        steps = driver.find_elements_by_xpath('(/html/body/form/main/article/div[2]/div/div[3]/div[2]/div/figure/figcaption/div/p)')
                        steps_list = [step.text for step in steps]
                        recipe_dict["recipe_steps"] = steps_list
                        #recipe_list append
                        recipes_list.append(recipe_dict)
                        driver.back()
                        time.sleep(2)
                    print(f"{category} finished")
                    break
                else:
                    recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                    for x in np.arange(len(recipe_sumup_scrap)):
                        recipe_dict = {}
                        time.sleep(2)
                        recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                        driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
                        time.sleep(3)
                        #recipe name
                        recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
                        #ingredients
                        ingredients_list = []
                        quantity_list = []
                        recipe_ingred = driver.find_elements_by_tag_name('td')
                        for x in np.arange(len(recipe_ingred)):
                            if x % 2 != 0:
                                ingredients_list.append(recipe_ingred[x].text)
                            else:
                                quantity_list.append(recipe_ingred[x].text)
                        recipe_dict["ingredients"] = ingredients_list
                        recipe_dict["ingred_quantity"] = quantity_list
                        #time_preparation and calories
                        time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
                        try:
                            recipe_dict["time_preparation"] = time_calor_scrap[1].text
                        except:
                            pass
                        #calories
                        try:
                            recipe_dict["calories"] = time_calor_scrap[2].text
                        except:
                            pass
                        #intolerances
                        try:
                            intolerances = driver.find_elements_by_class_name("intolerances-item")
                            intolerances_list = [intolerance.text for intolerance in intolerances]
                            recipe_dict["intolerances"] = intolerances_list
                        except:
                            recipe_dict["intolerances"] = None
                        #recipe_url
                        recipe_dict["recipe_url"] = driver.current_url
                        #images_url
                        images = driver.find_elements_by_tag_name('img')
                        images_list = [image.get_attribute('src') for image in images]
                        recipe_dict["recipe_image_url"] = images_list[1]
                        #category
                        category = driver.find_element_by_tag_name('h2').text
                        recipe_dict["category"] = category
                        #extra_info
                        more_info = driver.find_elements_by_xpath('(/html/body/form/main/article/div[1]/div[2]/div[2]/div/div/div/span)')
                        more_info_list = [info.text for info in more_info]
                        recipe_dict["more_info"] = more_info_list
                        #steps
                        steps = driver.find_elements_by_xpath('(/html/body/form/main/article/div[2]/div/div[3]/div[2]/div/figure/figcaption/div/p)')
                        steps_list = [step.text for step in steps]
                        recipe_dict["recipe_steps"] = steps_list
                        #recipe_list append
                        recipes_list.append(recipe_dict)
                        driver.back()
                        time.sleep(2)
                    next_page_btn = driver.find_elements_by_css_selector(".next [href]")
                    driver.execute_script("arguments[0].click()", next_page_btn[0])
                    time.sleep(2)
            main_page = driver.find_elements_by_css_selector(".left [href]")
            driver.execute_script("arguments[0].click()", main_page[1])
            time.sleep(2)
        elif current_link == "https://www.lecturas.com/recetas/crema-pollo-y-verduras-teja-parmesano_4601.html":
            next_page = "https://www.lecturas.com/recetas/sopas-cremas?_page=8"
            driver.get(next_page)
            driver.set_page_load_timeout(10)
            while True:
                next_page_btn = driver.find_elements_by_class_name('next')
                if len(next_page_btn) < 1:
                    recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                    for x in np.arange(len(recipe_sumup_scrap)):
                        recipe_dict = {}
                        time.sleep(2)
                        recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                        driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
                        time.sleep(3)
                        #recipe name
                        recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
                        #ingredients
                        ingredients_list = []
                        quantity_list = []
                        recipe_ingred = driver.find_elements_by_tag_name('td')
                        for x in np.arange(len(recipe_ingred)):
                            if x % 2 != 0:
                                ingredients_list.append(recipe_ingred[x].text)
                            else:
                                quantity_list.append(recipe_ingred[x].text)
                        recipe_dict["ingredients"] = ingredients_list
                        recipe_dict["ingred_quantity"] = quantity_list
                        #time_preparation and calories
                        time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
                        try:
                            recipe_dict["time_preparation"] = time_calor_scrap[1].text
                        except:
                            pass
                        #calories
                        try:
                            recipe_dict["calories"] = time_calor_scrap[2].text
                        except:
                            pass
                        #intolerances
                        try:
                            intolerances = driver.find_elements_by_class_name("intolerances-item")
                            intolerances_list = [intolerance.text for intolerance in intolerances]
                            recipe_dict["intolerances"] = intolerances_list
                        except:
                            recipe_dict["intolerances"] = None
                        #recipe_url
                        recipe_dict["recipe_url"] = driver.current_url
                        #images_url
                        images = driver.find_elements_by_tag_name('img')
                        images_list = [image.get_attribute('src') for image in images]
                        recipe_dict["recipe_image_url"] = images_list[1]
                        #category
                        category = driver.find_element_by_tag_name('h2').text
                        recipe_dict["category"] = category
                        #extra_info
                        more_info = driver.find_elements_by_xpath('(/html/body/form/main/article/div[1]/div[2]/div[2]/div/div/div/span)')
                        more_info_list = [info.text for info in more_info]
                        recipe_dict["more_info"] = more_info_list
                        #steps
                        steps = driver.find_elements_by_xpath('(/html/body/form/main/article/div[2]/div/div[3]/div[2]/div/figure/figcaption/div/p)')
                        steps_list = [step.text for step in steps]
                        recipe_dict["recipe_steps"] = steps_list
                        #recipe_list append
                        recipes_list.append(recipe_dict)
                        driver.back()
                        time.sleep(2)
                    print(f"{category} finished")
                    break
                else:
                    recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                    for x in np.arange(len(recipe_sumup_scrap)):
                        recipe_dict = {}
                        time.sleep(2)
                        recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                        driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
                        time.sleep(3)
                        #recipe name
                        recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
                        #ingredients
                        ingredients_list = []
                        quantity_list = []
                        recipe_ingred = driver.find_elements_by_tag_name('td')
                        for x in np.arange(len(recipe_ingred)):
                            if x % 2 != 0:
                                ingredients_list.append(recipe_ingred[x].text)
                            else:
                                quantity_list.append(recipe_ingred[x].text)
                        recipe_dict["ingredients"] = ingredients_list
                        recipe_dict["ingred_quantity"] = quantity_list
                        #time_preparation and calories
                        time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
                        try:
                            recipe_dict["time_preparation"] = time_calor_scrap[1].text
                        except:
                            pass
                        #calories
                        try:
                            recipe_dict["calories"] = time_calor_scrap[2].text
                        except:
                            pass
                        #intolerances
                        try:
                            intolerances = driver.find_elements_by_class_name("intolerances-item")
                            intolerances_list = [intolerance.text for intolerance in intolerances]
                            recipe_dict["intolerances"] = intolerances_list
                        except:
                            recipe_dict["intolerances"] = None
                        #recipe_url
                        recipe_dict["recipe_url"] = driver.current_url
                        #images_url
                        images = driver.find_elements_by_tag_name('img')
                        images_list = [image.get_attribute('src') for image in images]
                        recipe_dict["recipe_image_url"] = images_list[1]
                        #category
                        category = driver.find_element_by_tag_name('h2').text
                        recipe_dict["category"] = category
                        #extra_info
                        more_info = driver.find_elements_by_xpath('(/html/body/form/main/article/div[1]/div[2]/div[2]/div/div/div/span)')
                        more_info_list = [info.text for info in more_info]
                        recipe_dict["more_info"] = more_info_list
                        #steps
                        steps = driver.find_elements_by_xpath('(/html/body/form/main/article/div[2]/div/div[3]/div[2]/div/figure/figcaption/div/p)')
                        steps_list = [step.text for step in steps]
                        recipe_dict["recipe_steps"] = steps_list
                        #recipe_list append
                        recipes_list.append(recipe_dict)
                        driver.back()
                        time.sleep(2)
                    next_page_btn = driver.find_elements_by_css_selector(".next [href]")
                    driver.execute_script("arguments[0].click()", next_page_btn[0])
                    time.sleep(2)
            main_page = driver.find_elements_by_css_selector(".left [href]")
            driver.execute_script("arguments[0].click()", main_page[1])
            time.sleep(2)
        elif current_link == "https://www.lecturas.com/recetas/sopa-clasica-cebolla-gratinada-horno_4605.html":
            next_page = "https://www.lecturas.com/recetas/sopas-cremas?_page=8"
            driver.get(next_page)
            driver.set_page_load_timeout(10)
            while True:
                next_page_btn = driver.find_elements_by_class_name('next')
                if len(next_page_btn) < 1:
                    recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                    for x in np.arange(len(recipe_sumup_scrap)):
                        recipe_dict = {}
                        time.sleep(2)
                        recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                        driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
                        time.sleep(3)
                        #recipe name
                        recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
                        #ingredients
                        ingredients_list = []
                        quantity_list = []
                        recipe_ingred = driver.find_elements_by_tag_name('td')
                        for x in np.arange(len(recipe_ingred)):
                            if x % 2 != 0:
                                ingredients_list.append(recipe_ingred[x].text)
                            else:
                                quantity_list.append(recipe_ingred[x].text)
                        recipe_dict["ingredients"] = ingredients_list
                        recipe_dict["ingred_quantity"] = quantity_list
                        #time_preparation and calories
                        time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
                        try:
                            recipe_dict["time_preparation"] = time_calor_scrap[1].text
                        except:
                            pass
                        #calories
                        try:
                            recipe_dict["calories"] = time_calor_scrap[2].text
                        except:
                            pass
                        #intolerances
                        try:
                            intolerances = driver.find_elements_by_class_name("intolerances-item")
                            intolerances_list = [intolerance.text for intolerance in intolerances]
                            recipe_dict["intolerances"] = intolerances_list
                        except:
                            recipe_dict["intolerances"] = None
                        #recipe_url
                        recipe_dict["recipe_url"] = driver.current_url
                        #images_url
                        images = driver.find_elements_by_tag_name('img')
                        images_list = [image.get_attribute('src') for image in images]
                        recipe_dict["recipe_image_url"] = images_list[1]
                        #category
                        category = driver.find_element_by_tag_name('h2').text
                        recipe_dict["category"] = category
                        #extra_info
                        more_info = driver.find_elements_by_xpath('(/html/body/form/main/article/div[1]/div[2]/div[2]/div/div/div/span)')
                        more_info_list = [info.text for info in more_info]
                        recipe_dict["more_info"] = more_info_list
                        #steps
                        steps = driver.find_elements_by_xpath('(/html/body/form/main/article/div[2]/div/div[3]/div[2]/div/figure/figcaption/div/p)')
                        steps_list = [step.text for step in steps]
                        recipe_dict["recipe_steps"] = steps_list
                        #recipe_list append
                        recipes_list.append(recipe_dict)
                        driver.back()
                        time.sleep(2)
                    print(f"{category} finished")
                    break
                else:
                    recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                    for x in np.arange(len(recipe_sumup_scrap)):
                        recipe_dict = {}
                        time.sleep(2)
                        recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                        driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
                        time.sleep(3)
                        #recipe name
                        recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
                        #ingredients
                        ingredients_list = []
                        quantity_list = []
                        recipe_ingred = driver.find_elements_by_tag_name('td')
                        for x in np.arange(len(recipe_ingred)):
                            if x % 2 != 0:
                                ingredients_list.append(recipe_ingred[x].text)
                            else:
                                quantity_list.append(recipe_ingred[x].text)
                        recipe_dict["ingredients"] = ingredients_list
                        recipe_dict["ingred_quantity"] = quantity_list
                        #time_preparation and calories
                        time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
                        try:
                            recipe_dict["time_preparation"] = time_calor_scrap[1].text
                        except:
                            pass
                        #calories
                        try:
                            recipe_dict["calories"] = time_calor_scrap[2].text
                        except:
                            pass
                        #intolerances
                        try:
                            intolerances = driver.find_elements_by_class_name("intolerances-item")
                            intolerances_list = [intolerance.text for intolerance in intolerances]
                            recipe_dict["intolerances"] = intolerances_list
                        except:
                            recipe_dict["intolerances"] = None
                        #recipe_url
                        recipe_dict["recipe_url"] = driver.current_url
                        #images_url
                        images = driver.find_elements_by_tag_name('img')
                        images_list = [image.get_attribute('src') for image in images]
                        recipe_dict["recipe_image_url"] = images_list[1]
                        #category
                        category = driver.find_element_by_tag_name('h2').text
                        recipe_dict["category"] = category
                        #extra_info
                        more_info = driver.find_elements_by_xpath('(/html/body/form/main/article/div[1]/div[2]/div[2]/div/div/div/span)')
                        more_info_list = [info.text for info in more_info]
                        recipe_dict["more_info"] = more_info_list
                        #steps
                        steps = driver.find_elements_by_xpath('(/html/body/form/main/article/div[2]/div/div[3]/div[2]/div/figure/figcaption/div/p)')
                        steps_list = [step.text for step in steps]
                        recipe_dict["recipe_steps"] = steps_list
                        #recipe_list append
                        recipes_list.append(recipe_dict)
                        driver.back()
                        time.sleep(2)
                    next_page_btn = driver.find_elements_by_css_selector(".next [href]")
                    driver.execute_script("arguments[0].click()", next_page_btn[0])
                    time.sleep(2)
            main_page = driver.find_elements_by_css_selector(".left [href]")
            driver.execute_script("arguments[0].click()", main_page[1])
            time.sleep(2)
        else:
            print(f"TimeoutError at {current_link}")
            driver.get(current_link)
            driver.set_page_load_timeout(10)
            try:
                while True:
                    next_page_btn = driver.find_elements_by_class_name('next')
                    if len(next_page_btn) < 1:
                        recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                        for x in np.arange(len(recipe_sumup_scrap)):
                            recipe_dict = {}
                            time.sleep(2)
                            recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                            driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
                            time.sleep(3)
                            #recipe name
                            recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
                            #ingredients
                            ingredients_list = []
                            quantity_list = []
                            recipe_ingred = driver.find_elements_by_tag_name('td')
                            for x in np.arange(len(recipe_ingred)):
                                if x % 2 != 0:
                                    ingredients_list.append(recipe_ingred[x].text)
                                else:
                                    quantity_list.append(recipe_ingred[x].text)
                            recipe_dict["ingredients"] = ingredients_list
                            recipe_dict["ingred_quantity"] = quantity_list
                            #time_preparation and calories
                            time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
                            try:
                                recipe_dict["time_preparation"] = time_calor_scrap[1].text
                            except:
                                pass
                            #calories
                            try:
                                recipe_dict["calories"] = time_calor_scrap[2].text
                            except:
                                pass
                            #intolerances
                            try:
                                intolerances = driver.find_elements_by_class_name("intolerances-item")
                                intolerances_list = [intolerance.text for intolerance in intolerances]
                                recipe_dict["intolerances"] = intolerances_list
                            except:
                                recipe_dict["intolerances"] = None
                            #recipe_url
                            recipe_dict["recipe_url"] = driver.current_url
                            #images_url
                            images = driver.find_elements_by_tag_name('img')
                            images_list = [image.get_attribute('src') for image in images]
                            recipe_dict["recipe_image_url"] = images_list[1]
                            #category
                            category = driver.find_element_by_tag_name('h2').text
                            recipe_dict["category"] = category
                            #extra_info
                            more_info = driver.find_elements_by_xpath('(/html/body/form/main/article/div[1]/div[2]/div[2]/div/div/div/span)')
                            more_info_list = [info.text for info in more_info]
                            recipe_dict["more_info"] = more_info_list
                            #steps
                            steps = driver.find_elements_by_xpath('(/html/body/form/main/article/div[2]/div/div[3]/div[2]/div/figure/figcaption/div/p)')
                            steps_list = [step.text for step in steps]
                            recipe_dict["recipe_steps"] = steps_list
                            #recipe_list append
                            recipes_list.append(recipe_dict)
                            driver.back()
                            time.sleep(2)
                        print(f"{category} finished")
                        break
                    else:
                        recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                        for x in np.arange(len(recipe_sumup_scrap)):
                            recipe_dict = {}
                            time.sleep(2)
                            recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                            driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
                            time.sleep(3)
                            #recipe name
                            recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
                            #ingredients
                            ingredients_list = []
                            quantity_list = []
                            recipe_ingred = driver.find_elements_by_tag_name('td')
                            for x in np.arange(len(recipe_ingred)):
                                if x % 2 != 0:
                                    ingredients_list.append(recipe_ingred[x].text)
                                else:
                                    quantity_list.append(recipe_ingred[x].text)
                            recipe_dict["ingredients"] = ingredients_list
                            recipe_dict["ingred_quantity"] = quantity_list
                            #time_preparation and calories
                            time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
                            try:
                                recipe_dict["time_preparation"] = time_calor_scrap[1].text
                            except:
                                pass
                            #calories
                            try:
                                recipe_dict["calories"] = time_calor_scrap[2].text
                            except:
                                pass
                            #intolerances
                            try:
                                intolerances = driver.find_elements_by_class_name("intolerances-item")
                                intolerances_list = [intolerance.text for intolerance in intolerances]
                                recipe_dict["intolerances"] = intolerances_list
                            except:
                                recipe_dict["intolerances"] = None
                            #recipe_url
                            recipe_dict["recipe_url"] = driver.current_url
                            #images_url
                            images = driver.find_elements_by_tag_name('img')
                            images_list = [image.get_attribute('src') for image in images]
                            recipe_dict["recipe_image_url"] = images_list[1]
                            #category
                            category = driver.find_element_by_tag_name('h2').text
                            recipe_dict["category"] = category
                            #extra_info
                            more_info = driver.find_elements_by_xpath('(/html/body/form/main/article/div[1]/div[2]/div[2]/div/div/div/span)')
                            more_info_list = [info.text for info in more_info]
                            recipe_dict["more_info"] = more_info_list
                            #steps
                            steps = driver.find_elements_by_xpath('(/html/body/form/main/article/div[2]/div/div[3]/div[2]/div/figure/figcaption/div/p)')
                            steps_list = [step.text for step in steps]
                            recipe_dict["recipe_steps"] = steps_list
                            #recipe_list append
                            recipes_list.append(recipe_dict)
                            driver.back()
                            time.sleep(2)
                        next_page_btn = driver.find_elements_by_css_selector(".next [href]")
                        driver.execute_script("arguments[0].click()", next_page_btn[0])
                        time.sleep(2)
                main_page = driver.find_elements_by_css_selector(".left [href]")
                driver.execute_script("arguments[0].click()", main_page[1])
                time.sleep(2)
            except:
                driver.back()
                driver.set_page_load_timeout(10)
                time.sleep(2)
                while True:
                    next_page_btn = driver.find_elements_by_class_name('next')
                    if len(next_page_btn) < 1:
                        recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                        for x in np.arange(len(recipe_sumup_scrap)):
                            recipe_dict = {}
                            time.sleep(2)
                            recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                            driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
                            time.sleep(3)
                            #recipe name
                            recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
                            #ingredients
                            ingredients_list = []
                            quantity_list = []
                            recipe_ingred = driver.find_elements_by_tag_name('td')
                            for x in np.arange(len(recipe_ingred)):
                                if x % 2 != 0:
                                    ingredients_list.append(recipe_ingred[x].text)
                                else:
                                    quantity_list.append(recipe_ingred[x].text)
                            recipe_dict["ingredients"] = ingredients_list
                            recipe_dict["ingred_quantity"] = quantity_list
                            #time_preparation and calories
                            time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
                            try:
                                recipe_dict["time_preparation"] = time_calor_scrap[1].text
                            except:
                                pass
                            #calories
                            try:
                                recipe_dict["calories"] = time_calor_scrap[2].text
                            except:
                                pass
                            #intolerances
                            try:
                                intolerances = driver.find_elements_by_class_name("intolerances-item")
                                intolerances_list = [intolerance.text for intolerance in intolerances]
                                recipe_dict["intolerances"] = intolerances_list
                            except:
                                recipe_dict["intolerances"] = None
                            #recipe_url
                            recipe_dict["recipe_url"] = driver.current_url
                            #images_url
                            images = driver.find_elements_by_tag_name('img')
                            images_list = [image.get_attribute('src') for image in images]
                            recipe_dict["recipe_image_url"] = images_list[1]
                            #category
                            category = driver.find_element_by_tag_name('h2').text
                            recipe_dict["category"] = category
                            #extra_info
                            more_info = driver.find_elements_by_xpath('(/html/body/form/main/article/div[1]/div[2]/div[2]/div/div/div/span)')
                            more_info_list = [info.text for info in more_info]
                            recipe_dict["more_info"] = more_info_list
                            #steps
                            steps = driver.find_elements_by_xpath('(/html/body/form/main/article/div[2]/div/div[3]/div[2]/div/figure/figcaption/div/p)')
                            steps_list = [step.text for step in steps]
                            recipe_dict["recipe_steps"] = steps_list
                            #recipe_list append
                            recipes_list.append(recipe_dict)
                            driver.back()
                            time.sleep(2)
                        print(f"{category} finished")
                        break
                    else:
                        recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                        for x in np.arange(len(recipe_sumup_scrap)-1):
                            recipe_dict = {}
                            time.sleep(2)
                            recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
                            driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
                            time.sleep(3)
                            #recipe name
                            recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
                            #ingredients
                            ingredients_list = []
                            quantity_list = []
                            recipe_ingred = driver.find_elements_by_tag_name('td')
                            for x in np.arange(len(recipe_ingred)):
                                if x % 2 != 0:
                                    ingredients_list.append(recipe_ingred[x].text)
                                else:
                                    quantity_list.append(recipe_ingred[x].text)
                            recipe_dict["ingredients"] = ingredients_list
                            recipe_dict["ingred_quantity"] = quantity_list
                            #time_preparation and calories
                            time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
                            try:
                                recipe_dict["time_preparation"] = time_calor_scrap[1].text
                            except:
                                pass
                            #calories
                            try:
                                recipe_dict["calories"] = time_calor_scrap[2].text
                            except:
                                pass
                            #intolerances
                            try:
                                intolerances = driver.find_elements_by_class_name("intolerances-item")
                                intolerances_list = [intolerance.text for intolerance in intolerances]
                                recipe_dict["intolerances"] = intolerances_list
                            except:
                                recipe_dict["intolerances"] = None
                            #recipe_url
                            recipe_dict["recipe_url"] = driver.current_url
                            #images_url
                            images = driver.find_elements_by_tag_name('img')
                            images_list = [image.get_attribute('src') for image in images]
                            recipe_dict["recipe_image_url"] = images_list[1]
                            #category
                            category = driver.find_element_by_tag_name('h2').text
                            recipe_dict["category"] = category
                            #extra_info
                            more_info = driver.find_elements_by_xpath('(/html/body/form/main/article/div[1]/div[2]/div[2]/div/div/div/span)')
                            more_info_list = [info.text for info in more_info]
                            recipe_dict["more_info"] = more_info_list
                            #steps
                            steps = driver.find_elements_by_xpath('(/html/body/form/main/article/div[2]/div/div[3]/div[2]/div/figure/figcaption/div/p)')
                            steps_list = [step.text for step in steps]
                            recipe_dict["recipe_steps"] = steps_list
                            #recipe_list append
                            recipes_list.append(recipe_dict)
                            driver.back()
                            time.sleep(2)
                        next_page_btn = driver.find_elements_by_css_selector(".next [href]")
                        driver.execute_script("arguments[0].click()", next_page_btn[0])
                        time.sleep(2)
                main_page = driver.find_elements_by_css_selector(".left [href]")
                driver.execute_script("arguments[0].click()", main_page[1])
                time.sleep(2)
    else:
        current_link = driver.current_url
        print(f"check if error at {current_link}")
        pass
# Out:
# ENSALADAS finished
# check if error at https://www.lecturas.com/recetas
# SOPAS Y CREMAS finished
# TimeoutError at https://www.lecturas.com/recetas/verduras?_page=4
# VERDURAS finished
# LEGUMBRES finished
# check if error at https://www.lecturas.com/recetas
# ARROCES Y CEREALES finished
# check if error at https://www.lecturas.com/recetas
# PASTAS finished
# check if error at https://www.lecturas.com/recetas
# HUEVOS Y TORTILLAS finished
# check if error at https://www.lecturas.com/recetas
# POTAJES Y COCIDOS finished
# check if error at https://www.lecturas.com/recetas
# TimeoutError at https://www.lecturas.com/recetas/carnes
# CARNES finished
# TimeoutError at https://www.lecturas.com/recetas/aves
# AVES finished
# PESCADOS Y MARISCOS finished
# check if error at https://www.lecturas.com/recetas
# QUICHE, CREPS Y PASTELES SALADOS finished
# check if error at https://www.lecturas.com/recetas
# POSTRES Y DULCES finished
# POSTRES Y DULCES finished
# PIZZAS Y EMPANADAS finished
# check if error at https://www.lecturas.com/recetas
# BOCADILLOS Y CANAPÉS finished
# check if error at https://www.lecturas.com/recetas
# MERMELADAS Y CONFITURAS finished
# check if error at https://www.lecturas.com/recetas
# SALSAS finished
# check if error at https://www.lecturas.com/recetas

# %%
df_recipes = pd.DataFrame(recipes_list)

df_recipes
# Out:
#                                        recipe_name  \
# 0                                 Ensalada niçoise
# 1                            Ensalada del périgord
# 2                           Xató con salsa romesco
# 3     Ensalada de ceviche de langostinos y cebolla
# 4           Ensalada de pollo, remolacha y manzana
# ...                                            ...
# 6459                           Pasta de curry rojo
# 6460                                  Salsa hoisin
# 6461                                Salsa boloñesa
# 6462                                Salsa bechamel
# 6463            Curry en polvo de chennai (Madrás)
#
#                                             ingredients  \
# 0     [patatas pequeñas rojas, huevos, judías verdes...
# 1     [foie micuit, beicon gruesas, champiñones, ber...
# 2     [bacalao desalado, cebolleta, escarolas, aceit...
# 3     [langostinos, pimienta, limas, tomates, ceboll...
# 4     [pechugas de pollo, manzanas ácida, col lombar...
# ...                                                 ...
# 6459  [semillas de cilantro, comino, semillas de mos...
# 6460  [ajo, guindilla, judía azuki cocida y triturad...
# 6461  [carne de ternera picada, tomate triturado, ce...
# 6462  [leche, mantequilla, harina, nuez moscada, pim...
# 6463  [pimienta negra en grano, semillas de cilantro...
#
#                                         ingred_quantity time_preparation  \
# 0     [12, 4, 400 g, 4, 250 g, 200 g, 1, 1 cda, 100 ...           60 min
# 1     [150 g, 2 lonchas, 150 g, 80 g, 100 g, 6, 20 g...           25 min
# 2     [300 g, 1, 150 g, 80 g, 8, 2, 1, 2, 1 rebanada...           35 min
# 3     [16, , 8, 3, 1, ½, 1 cdta, 1, 1 manojo, , 100 ...           25 min
# 4     [650 g, 2, 1 trozo, 2, 1, 1, 80 g, 100 g, 1 cd...           40 min
# ...                                                 ...              ...
# 6459  [4 cda, 2 cda, 2 cdta, 1 trozo, 2 cdta, 2, 2 c...            8 min
# 6460                   [, ½, 100 g, 10 g, 10 g, 75 g, ]            5 min
# 6461                        [400 g, 2 kg, 1, 1, , , , ]           35 min
# 6462                            [1 l, 60 g, 60 g, , , ]           20 min
# 6463  [2 cdta, 3 cda, 2 cda, 2 cda, 2 cdta, 1 cdta, ...            5 min
#
#      calories                                       intolerances  \
# 0     252 Cal                                                 []
# 1     386 Cal                                                 []
# 2         NaN                                                 []
# 3     176 Cal                                                 []
# 4     203 Cal                                                 []
# ...       ...                                                ...
# 6459      NaN  [Sin gluten, Sin lactosa, Sin sacarosa o fruct...
# 6460      NaN                                                 []
# 6461  208 Cal                                                 []
# 6462      NaN                                                 []
# 6463      NaN  [Baja en sodio, Sin gluten, Sin lactosa, Sin s...
#
#                                              recipe_url  \
# 0     https://www.lecturas.com/recetas/ensalada-nico...
# 1     https://www.lecturas.com/recetas/ensalada-peri...
# 2     https://www.lecturas.com/recetas/xato-salsa-ro...
# 3     https://www.lecturas.com/recetas/ensalada-cevi...
# 4     https://www.lecturas.com/recetas/ensalada-poll...
# ...                                                 ...
# 6459  https://www.lecturas.com/recetas/pasta-curry-r...
# 6460  https://www.lecturas.com/recetas/salsa-hoisin_...
# 6461  https://www.lecturas.com/recetas/salsa-bolones...
# 6462  https://www.lecturas.com/recetas/salsa-bechame...
# 6463  https://www.lecturas.com/recetas/curry-polvo-c...
#
#                                        recipe_image_url   category  \
# 0     https://content-recetas.lecturas.com/medio/201...  ENSALADAS
# 1     https://content-recetas.lecturas.com/medio/201...  ENSALADAS
# 2     https://content-recetas.lecturas.com/medio/202...  ENSALADAS
# 3     https://content-recetas.lecturas.com/medio/201...  ENSALADAS
# 4     https://content-recetas.lecturas.com/medio/201...  ENSALADAS
# ...                                                 ...        ...
# 6459  https://content-recetas.lecturas.com/medio/201...     SALSAS
# 6460  https://content-recetas.lecturas.com/medio/201...     SALSAS
# 6461  https://content-recetas.lecturas.com/medio/201...     SALSAS
# 6462  https://content-recetas.lecturas.com/medio/201...     SALSAS
# 6463  https://content-recetas.lecturas.com/medio/201...     SALSAS
#
#                                               more_info recipe_steps
# 0     [Dieta:, Baja en calorías, Mediterránea, Tempo...           []
# 1     [Dieta:, Mediterránea, Temporada:, Todo el año...           []
# 2     [Dieta:, Mediterránea, Temporada:, Todo el año...           []
# 3     [Dieta:, Mediterránea, Temporada:, Todo el año...           []
# 4     [Dieta:, Mediterránea, Técnica:, Técnica mixta...           []
# ...                                                 ...          ...
# 6459  [Dieta:, Baja en calorías, Vegana, Temporada:,...           []
# 6460  [Dieta:, Vegana, Vegetariana, Temporada:, Todo...           []
# 6461  [Dieta:, Mediterránea, Temporada:, Todo el año...           []
# 6462  [Dieta:, Mediterránea, Temporada:, Todo el año...           []
# 6463  [Dieta:, Baja en calorías, Vegana, Temporada:,...           []
#
# [6464 rows x 11 columns]

# %%
with open('../data/raw/web_scraping_recipes_new.json', 'w') as json_file:
    json.dump(recipes_list, json_file)
