# %%
import pandas as pd
import re
import ast
import json

# %%
with open('../data/raw/web_scraping_recipes_recetasgratis_1.json') as json_file: 
    recetas_gratis_1 = json.load(json_file) 

with open('../data/raw/web_scraping_recipes_recetasgratis_2.json') as json_file: 
    recetas_gratis_2 = json.load(json_file) 

with open('../data/raw/web_scraping_recipes_recetasgratis_3.json') as json_file: 
    recetas_gratis_3 = json.load(json_file) 
    
with open('../data/raw/web_scraping_recipes_recetasgratis_4.json') as json_file: 
    recetas_gratis_4 = json.load(json_file) 
    
with open('../data/raw/web_scraping_recipes_recetasgratis_5.json') as json_file: 
    recetas_gratis_5 = json.load(json_file) 
    
with open('../data/raw/web_scraping_recipes_recetasgratis_6.json') as json_file: 
    recetas_gratis_6 = json.load(json_file) 
    
with open('../data/raw/web_scraping_recipes_recetasgratis_7.json') as json_file: 
    recetas_gratis_7 = json.load(json_file)
    
with open('../data/raw/web_scraping_recipes_recetasgratis_8.json') as json_file: 
    recetas_gratis_8 = json.load(json_file)
    
with open('../data/raw/web_scraping_recipes_recetasgratis_9.json') as json_file: 
    recetas_gratis_9 = json.load(json_file)
    
with open('../data/raw/web_scraping_recipes_recetasgratis_10.json') as json_file: 
    recetas_gratis_10 = json.load(json_file)

# %%
recetas_gratis = recetas_gratis_1 + recetas_gratis_2 + recetas_gratis_3 + recetas_gratis_4 + recetas_gratis_5 + recetas_gratis_6 + recetas_gratis_7 + recetas_gratis_8 + recetas_gratis_9 + recetas_gratis_10

# %%
df_recipes = pd.DataFrame(recetas_gratis)

df_recipes
# Out:
#                                              recipe_name  \
# 0                          Receta de Baleadas hondureñas
# 1                        Receta de Tacos de carne molida
# 2                            Receta de Burritos norteños
# 3      Receta de Croquetas de pollo caseras de la abuela
# 4                   Receta de Masa para empanadas fritas
# ...                                                  ...
# 13180                         Receta de Fritos de acelga
# 13181        Receta de Verduras salteadas en mantequilla
# 13182       Receta de Guisantes compuestos con Thermomix
# 13183         Receta de Papas a la crema con champiñones
# 13184                        Receta de Papas a la diabla
#
#                                              ingredients time_preparation  \
# 0      4 trotillas de harina\n2 tazas de frijoles neg...              10m
# 1      Para los tacos de carne molida\n500 gramos de ...              30m
# ...

# %%
with open('../data/raw/web_scraping_recipes_recetasgratis.json', 'w') as json_file:
    json.dump(recetas_gratis, json_file)
