# %%
from selenium import webdriver
from selenium.common.exceptions import TimeoutException
import time
import numpy as np
import pandas as pd
import json

# %%
# Opening the Chrome and going to the Web

recipe_link = "https://www.lecturas.com/recetas/postres-dulces?_page=16"
chromedriver = "/home/veronica/Ironhack/Final Project/Chrome Driver/chromedriver"
driver = webdriver.Chrome(chromedriver)
driver.get(recipe_link)


# Enabling cookies

time.sleep(3)
element = driver.find_elements_by_class_name('qc-cmp-button')
element[1].click()

recipes_list = []

while True:
    next_page_btn = driver.find_elements_by_class_name('next')
    if len(next_page_btn) < 1:
        recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
        for x in np.arange(len(recipe_sumup_scrap)-1):
            recipe_dict = {}
            time.sleep(2)
            recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
            driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
            time.sleep(3)
            #recipe name
            recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
            #ingredients
            ingredients_list = []
            recipe_ingred = driver.find_elements_by_tag_name('td')
            for x in np.arange(len(recipe_ingred)):
                if x % 2 != 0:
                    ingredients_list.append(recipe_ingred[x].text)
                else:
                    pass
            recipe_dict["ingredients"] = ingredients_list
            #time_preparation and calories
            time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
            try:
                recipe_dict["time_preparation"] = time_calor_scrap[1].text
            except:
                pass
            #calories
            try:
                recipe_dict["calories"] = time_calor_scrap[2].text
            except:
                pass
            #intolerances
            try:
                intolerances = driver.find_elements_by_class_name("intolerances-item")
                intolerances_list = [intolerance.text for intolerance in intolerances]
                recipe_dict["intolerances"] = intolerances_list
            except:
                recipe_dict["intolerances"] = None
            #recipe_url
            recipe_dict["recipe_url"] = driver.current_url
            #images_url
            images = driver.find_elements_by_tag_name('img')
            images_list = [image.get_attribute('src') for image in images]
            recipe_image_url = images_list[1]
            recipe_dict["recipe_image_url"] = images_list[1]
            #category
            recipe_dict["category"] = driver.find_element_by_tag_name('h2').text
            #recipe_list append
            recipes_list.append(recipe_dict)
            driver.back()
            time.sleep(2)
        print("No more pages left")
        break
    else:
        recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
        for x in np.arange(len(recipe_sumup_scrap)-1):
            recipe_dict = {}
            time.sleep(2)
            recipe_sumup_scrap = driver.find_elements_by_class_name("element-header")
            driver.execute_script("arguments[0].click()", recipe_sumup_scrap[x])
            time.sleep(3)
            #recipe name
            recipe_dict["recipe_name"] = driver.find_element_by_tag_name('h1').text
            #ingredients
            ingredients_list = []
            recipe_ingred = driver.find_elements_by_tag_name('td')
            for x in np.arange(len(recipe_ingred)):
                if x % 2 != 0:
                    ingredients_list.append(recipe_ingred[x].text)
                else:
                    pass
            recipe_dict["ingredients"] = ingredients_list
            #time_preparation and calories
            time_calor_scrap = driver.find_elements_by_class_name("metaheader-value")
            try:
                recipe_dict["time_preparation"] = time_calor_scrap[1].text
            except:
                pass
            #calories
            try:
                recipe_dict["calories"] = time_calor_scrap[2].text
            except:
                pass
            #intolerances
            try:
                intolerances = driver.find_elements_by_class_name("intolerances-item")
                intolerances_list = [intolerance.text for intolerance in intolerances]
                recipe_dict["intolerances"] = intolerances_list
            except:
                recipe_dict["intolerances"] = None
            #recipe_url
            recipe_dict["recipe_url"] = driver.current_url
            #images_url
            images = driver.find_elements_by_tag_name('img')
            images_list = [image.get_attribute('src') for image in images]
            recipe_image_url = images_list[1]
            recipe_dict["recipe_image_url"] = images_list[1]
            #category
            recipe_dict["category"] = driver.find_element_by_tag_name('h2').text
            #recipe_list append
            recipes_list.append(recipe_dict)
            driver.back()
            time.sleep(2)
        next_page_btn = driver.find_elements_by_css_selector(".next [href]")
        driver.execute_script("arguments[0].click()", next_page_btn[0])
        time.sleep(2)
# Out:
# No more pages left

# %%
df_recipes = pd.DataFrame(recipes_list)

df_recipes
# Out:
#                                      recipe_name  \
# 0                        Tiramisú con frambuesas
# 1       Triángulos helados de brownie y vainilla
# 2     Tiramisú de chocolate con queso mascarpone
# 3         Brownie tradicional de chocolate negro
# 4       Tiramisú con crema de queso al chocolate
# ...                                          ...
# 1864                         Galletas multicolor
# 1865      Sorbete de limón al cava con macedonia
# 1866     Tarta de queso con lunares de chocolate
# 1867              Pastelitos de nata y chocolate
# 1868              Tarta de chocolate con fondant
#
#                                             ingredients time_preparation  \
# 0     [frambuesa, queso mascarpone, huevo, bizcocho ...           30 min
# 1     [azúcar, chocolate negro, huevo, mantequilla, ...           45 min
# 2     [bizcocho de soletilla, nata para montar, ques...           40 min
# 3     [mantequilla, chocolate negro, huevo, azúcar, ...           40 min
# 4     [bizcocho de soletilla, queso mascarpone, azúc...           25 min
# ...                                                 ...              ...
# 1864  [harina, bicarbonato sódico, mantequilla, sal,...           40 min
# 1865  [sorbete de limón, cava, sandías, melocotones,...           25 min
# 1866  [mantequilla, galletas de chocolate, queso bla...           90 min
# 1867  [galletas de chocolate, mantequilla, queso mas...           60 min
# 1868  [huevos, azúcar, harina, levadura, mantequilla...           90 min
#
#                                            intolerances  \
# 0                                                    []
# 1                          [Preparación con antelación]
# 2                          [Preparación con antelación]
# 3                                                    []
# 4                          [Preparación con antelación]
# ...                                                 ...
# 1864                                                 []
# 1865  [Sin gluten, Sin lactosa, Preparación con ante...
# 1866                                                 []
# 1867                       [Preparación con antelación]
# 1868                                                 []
#
#                                              recipe_url  \
# 0     https://www.lecturas.com/recetas/tiramisu-fram...
# 1     https://www.lecturas.com/recetas/triangulos-he...
# 2     https://www.lecturas.com/recetas/tiramisu-choc...
# 3     https://www.lecturas.com/recetas/brownie-tradi...
# 4     https://www.lecturas.com/recetas/tiramisu-crem...
# ...                                                 ...
# 1864  https://www.lecturas.com/recetas/galletas-mult...
# 1865  https://www.lecturas.com/recetas/sorbete-limon...
# 1866  https://www.lecturas.com/recetas/tarta-queso-l...
# 1867  https://www.lecturas.com/recetas/pastelitos-na...
# 1868  https://www.lecturas.com/recetas/tarta-chocola...
#
#                                        recipe_image_url          category  \
# 0     https://content-recetas.lecturas.com/medio/201...  POSTRES Y DULCES
# 1     https://content-recetas.lecturas.com/medio/201...  POSTRES Y DULCES
# 2     https://content-recetas.lecturas.com/medio/201...  POSTRES Y DULCES
# 3     https://content-recetas.lecturas.com/medio/201...  POSTRES Y DULCES
# 4     https://content-recetas.lecturas.com/medio/201...  POSTRES Y DULCES
# ...                                                 ...               ...
# 1864  https://content-recetas.lecturas.com/medio/201...  POSTRES Y DULCES
# 1865  https://content-recetas.lecturas.com/medio/201...  POSTRES Y DULCES
# 1866  https://content-recetas.lecturas.com/medio/201...  POSTRES Y DULCES
# 1867  https://content-recetas.lecturas.com/medio/201...  POSTRES Y DULCES
# 1868  https://content-recetas.lecturas.com/medio/201...  POSTRES Y DULCES
#
#      calories
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ...       ...
# 1864      NaN
# 1865  110 Cal
# 1866      NaN
# 1867      NaN
# 1868      NaN
#
# [1869 rows x 8 columns]

# %%
with open('../data/raw/web_scraping_recipes_4.json', 'w') as json_file:
    json.dump(recipes_list, json_file)
